# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.0-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.2.2)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (4.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.10.1)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.4.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (67.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.22.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (2.8.4)
# Collecting funcy
#   Downloading funcy-1.18-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->pyLDAvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->pyLDAvis) (1.16.0)
# Installing collected packages: funcy, joblib, pyLDAvis
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# Successfully installed funcy-1.18 joblib-1.2.0 pyLDAvis-3.4.0

# %%
import pandas as pd
import numpy as np

import re
import string

import spacy

import gensim
from gensim import corpora

# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
with open("/content/drive/MyDrive/Deal_analytics_project/Amendment Contract.txt") as file:amendment_contract = file.read()
amendment_contract
# Out:
# 'Amendment to [AGREEMENT NAME] \n\nThis amendment to the [AGREEMENT NAME] dated [EFFECTIVE DATE OF AGREEMENT] (the \n"Agreement") is made on [AMENDMENT EFFECTIVE DATE] between [PARTY A NAME], a [CORPORATE \nJURISDICTION] corporation with its principal place of business at [PARTY A ADDRESS] (the "[PARTY A \nABBREVIATION]") and [PARTY B NAME], a [CORPORATE JURISDICTION] corporation with its principal \nplace of business at [PARTY B ADDRESS] (the "[PARTY B ABBREVIATION]"). \n\n1. Capitalized Terms. Unless otherwise defined in this amendment, capitalized terms used in this \namendment will have the same meaning they do in the Agreement. \n2. Substance of Amendment. The parties hereby amend the Agreement as follows: \n[LIST THE CHANGES, ADDITIONS, DELETIONS, ETC. TO BE MADE TO THE UNDERLYING AGREEMENT] \n\n3. Continuing Effect. Except as listed in section [SUBSTANCE OF AMENDMENT], the Agreement will \nbe unaffected and continue in full force and effect under its terms. \n4. Conflicting Amendments. If there is any conflict between the terms of this amendment and those \nof any earlier amendment to the Agreement, the terms of this amendment will control. \nThis agreement has been signed by the parties. \n[PARTY A NAME] [PARTY B NAME] \nName: [PARTY A SIGNATORY NAME] Name: [PARTY B SIGNATORY NAME] \nTitle: [PARTY A SIGNATORY TITLE] Title: [PARTY B SIGNATORY TITLE] \n\n1 of 1 \n\n\x0c\n'

# %%
with open("/content/drive/MyDrive/Deal_analytics_project/board resolution.txt") as file:board_text = file.read()
with open("/content/drive/MyDrive/Deal_analytics_project/Software License Agreement Contract.txt") as file:software_license_agreement = file.read()
with open("/content/drive/MyDrive/Deal_analytics_project/tenant lease.txt") as file:tenant_lease = file.read()

# %%
import nltk
nltk.download('punkt')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk import sent_tokenize

# %%
list_of_sentence = sent_tokenize(amendment_contract)
list_of_sentence1 = sent_tokenize(software_license_agreement)
list_of_sentence2 = sent_tokenize(board_text)
list_of_sentence3 = sent_tokenize(tenant_lease)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
list_of_sentence
# Out:
# ['Amendment to [AGREEMENT NAME] \n\nThis amendment to the [AGREEMENT NAME] dated [EFFECTIVE DATE OF AGREEMENT] (the \n"Agreement") is made on [AMENDMENT EFFECTIVE DATE] between [PARTY A NAME], a [CORPORATE \nJURISDICTION] corporation with its principal place of business at [PARTY A ADDRESS] (the "[PARTY A \nABBREVIATION]") and [PARTY B NAME], a [CORPORATE JURISDICTION] corporation with its principal \nplace of business at [PARTY B ADDRESS] (the "[PARTY B ABBREVIATION]").',
#  '1.',
#  'Capitalized Terms.',
#  'Unless otherwise defined in this amendment, capitalized terms used in this \namendment will have the same meaning they do in the Agreement.',
#  '2.',
#  'Substance of Amendment.',
#  'The parties hereby amend the Agreement as follows: \n[LIST THE CHANGES, ADDITIONS, DELETIONS, ETC.',
#  'TO BE MADE TO THE UNDERLYING AGREEMENT] \n\n3.',
#  'Continuing Effect.',
#  'Except as listed in section [SUBSTANCE OF AMENDMENT], the Agreement will \nbe unaffected and continue in full force and effect under its terms.',
#  '4.',
#  'Conflicting Amendments.',
#  'If there is any conflict between the terms of this amendment and those \nof any earlier amendment to the Agreement, the terms of this amendment will control.',
#  'This agreement has been signed by the parties.',
#  '[PARTY A NAME] [PARTY B NAME] \nName: [PARTY A SIGNATORY NAME] Name: [PARTY B SIGNATORY NAME] \nTitle: [PARTY A SIGNATORY TITLE] Title: [PARTY B SIGNATORY TITLE] \n\n1 of 1']

# %%
list_of_sentence1
# Out:
# ['Software License Agreement \n\nThis Software License Agreement is made on [AGREEMENT DATE] between [LICENSOR NAME], a \n[CORPORATE JURISDICTION] corporation with its principal place of business at [LICENSOR ADDRESS] \n("[PARTY A]") and [LICENSEE NAME], a [CORPORATE JURISDICTION] corporation with its principal \nplace of business at [LICENSEE ADDRESS] ("[PARTY B]").',
#  'The parties agree to the terms of this agreement.',
#  '1.',
#  'License Grant \n1.1 Software License.',
#  '[PARTY A] hereby grants to [PARTY B] [an exclusive / a non-exclusive], \n[transferable / non-transferable], [sublicensable / non-sublicensable], [revocable / irrevocable] \nlicense (the "[DELIVERABLE]") to use the Software.',
#  '1.2 No Other Rights.',
#  '[PARTY A] reserves for itself all other rights and interest not explicitly granted \nunder this agreement.',
#  '1.3 Software.',
#  '"Software" means [SHORT DESCRIPTION OF SOFTWARE] [the software described in the \n[ATTACHMENT], attached to this agreement].',
#  '2.',
#  'Make Software Available for Download.',
#  "On the later of the Effective Date and [PARTY B]'s first \npayment for the Software, [PARTY A] will make the Software available to [PARTY B] in an electronic, \ndownloadable format from [PARTY A]'s website, at [INSERT URL OF WEBSITE].",
#  '3.',
#  'Training and Support Services \n3.1 Training.',
#  "[PARTY A] shall, at [PARTY A]'s expense, provide [PARTY B]'s employees with the initial \ntraining services necessary and desirable to operate the Software, as further described in the \n[ATTACHMENT], attached to this agreement, at [PARTY B]'s offices and on days and times the parties \nagree to in writing.",
#  '3.2 Support \na.',
#  'Initial Support.',
#  "For the [12] month period beginning on the Effective Date, and at [PARTY \nA]'s own expense, [PARTY A] shall provide [PARTY B] with \ni. telephone or electronic support during [PARTY A]'s normal business hours in order to \nhelp [PARTY B] locate and correct problems with the Software, and \nii.",
#  'internet-based support system generally available seven days a week, twenty-four \nhours a day.',
#  'b.',
#  'Renewed Support.',
#  "After the initial [12] month support period, [PARTY B] may elect to \nrenew [PARTY A]'s support services under this paragraph [SUPPORT] for additional [12] \nmonth periods, at [PARTY A]'s then-current service rates.",
#  '4.',
#  'Updates and Maintenance Services \n4.1 Updates.',
#  "[PARTY A] shall provide [PARTY B], at [PARTY A]'s sole expense, with all updates, \nextensions, enhancement, modifications, and other changes [PARTY A] makes or adds to the \nSoftware and which [PARTY A] offers to other licensees of the Software.",
#  '1 of 11 \n\n\x0c\n4.2 Fixes and Patches.',
#  "[PARTY A] shall provide [PARTY B], at [PARTY A]'s sole expense, with bug fixes \nand code corrections to correct Software malfunctions and defects in order to bring the \nSoftware into substantial conformity with its operating specifications.",
#  '4.3 Exceptions.',
#  '[PARTY A] may, but will not be required to, provide these maintenance services if \n[PARTY B] has modified the Software or is in default.',
#  '5.',
#  'License Fees.',
#  '[PARTY B] will pay [PARTY A] the license fee [of $[LICENSE FEE] / listed in \n[ATTACHMENT]] (the "License Fee").',
#  '6.',
#  'License Fees \n6.1 License Fee Paid in Full.',
#  '[PARTY B] will pay the License Fee to [PARTY A] \na. in full, \nb. due on [DATE, MONTH], \nc. in immediately available funds, and \nd. to the account [PARTY A] lists immediately below: \nAccount Number: \n\nRouting Number: \n\n7.',
#  'Taxes.',
#  'Payment amounts under this agreement do not include Taxes.',
#  '[PARTY B] will pay all Taxes \napplicable to payments between the parties under this agreement.',
#  '8.',
#  'Interest on Late Payments.',
#  'Any amount not paid when due will bear interest from the due date \nuntil paid at a rate equal to [1]% per month ([12.68]% annually) or the maximum allowed by Law, \nwhichever is less.',
#  '9.',
#  'User Obligations \n9.1 Hardware Obligations.',
#  '[PARTY B] shall be responsible for \na. obtaining and maintaining all computer hardware, software, and communications \nequipment needed to internally access the Service, and \nb. paying all third party access charges incurred while using the Service.',
#  '9.2 Anti-Virus Obligations.',
#  '[PARTY B] shall be responsible for implementing, maintaining, and \nupdating all necessary and proper procedures and software for safeguarding against computer \ninfection, viruses, worms, Trojan horses, and other code that manifest contaminating or destructive \nproperties (collectively "Viruses").',
#  "9.3 [PARTY B]'s Use of Services.",
#  '[PARTY B] shall \na. abide by all local and international Laws and regulations applicable to its use of \nthe Service, \nb. use the Service only for legal purposes, and \nc. comply with all regulations, policies and procedures of networks connected to the \nService.',
#  '10.',
#  'Restricted Uses.',
#  '[PARTY B] will not \n2 of 11 \n\n\x0c\n10.1 distribute, license, loan, or sell the Software or other content that is contained or displayed in it, \n10.2 modify, alter, or create any derivative works from the Software, \n10.3 reverse engineer, decompile, decode, decrypt, disassemble, or derive any source code from the \nSoftware, \n10.4 remove, alter, or obscure any copyright, trademark, or other proprietary rights notice on or in \nthe Software.',
#  '11.',
#  'Permitted Uses \n11.1 Installation.',
#  '[PARTY B] may install and use the Software solely for [personal, noncommercial][\ninternal business] use.',
#  '11.2 Evaluation Use.',
#  'If [PARTY B] has ordered an evaluation license, [PARTY B] may use the Software \nonly for evaluation purposes and only during the applicable evaluation period.',
#  '11.3 Server Deployment.',
#  '[PARTY B] may install [NUMBER OF SERVER COPIES] of copies of the \nSoftware on an internal file server for purposes of downloading and installing the Software on \nlicensed computers within the same internal network.',
#  '11.4 Home Use.',
#  '[PARTY B] may install a copy of the Software on a personal or home computer, \nprovided both copies of the Software are not used at the same time.',
#  '11.5 Backup and Archival Copies.',
#  '[PARTY B] may make one copy of the Software solely for backup or \narchival purposes.',
#  '12.',
#  'Term.',
#  'This agreement begins on [the Effective Date / [DATE, MONTH]] and will continue until \nterminated (the "Term").',
#  '13.',
#  'Representations \n13.1 Mutual Representations \na.',
#  'Existence.',
#  'The parties are corporations incorporated and existing under the laws of the \njurisdictions of their respective incorporation.',
#  'b.',
#  'Authority and Capacity.',
#  'The parties have the authority and capacity to enter into this \nagreement.',
#  'c. Execution and Delivery.',
#  'The parties have duly executed and delivered this agreement.',
#  'd. Enforceability.',
#  'This agreement constitutes a legal, valid, and binding obligation, \nenforceable against the parties according to its terms.',
#  'e. No Conflicts.',
#  "Neither party is under any restriction or obligation that the party could \nreasonably expect might affect the party's performance of its obligations under this \nagreement.",
#  'f. No Breach.',
#  'Neither party’s execution, delivery, or performance of its obligations under \nthis agreement will breach or result in a default under \ni. its articles, bylaws, or any unanimous shareholders agreement, \nii.',
#  'any Law to which it is subject, \niii.',
#  'any judgment, Order, or decree of any Governmental Authority to which it is subject, \nor \niv.',
#  'any agreement to which it is a party or by which it is bound.',
#  '3 of 11 \n\n\x0c\ng. Permits, Consents, and Other Authorizations.',
#  'Each party holds all Permits and other \nauthorizations necessary to \ni. own, lease, and operate its properties, and \nii.',
#  'conduct its business as it is now carried on.',
#  'h. No Disputes or Proceedings.',
#  '[Except as disclosed in the parties respective Disclosure \nSchedules] There are no Legal Proceedings pending, threatened, or foreseeable against \neither party, which would affect that party’s ability to complete its obligations under this \nagreement.',
#  'i.',
#  'No Bankruptcy.',
#  'Neither party has taken or authorized any proceedings related to that \nparty’s bankruptcy, insolvency, liquidation, dissolution, or winding up.',
#  "13.2 [PARTY A]'s Representations \na.",
#  'Disclosure Schedule.',
#  "[PARTY A]'s Disclosure Schedule lists any exceptions to \nits representations.",
#  'b.',
#  'Ownership of Intellectual Property.',
#  "[Except as disclosed in [PARTY A]'s Disclosure \nSchedule] [PARTY A] \ni. is the owner of all Intellectual Property rights included in the Software and \ngranted under in the [DELIVERABLE], and \nii.",
#  'has the exclusive right to grant the [DELIVERABLE].',
#  'c. Maintenance of Intellectual Property.',
#  '[PARTY A] has properly maintained all its \nIntellectual Property rights licensed under the [DELIVERABLE], including paying all \napplicable registration and maintenance fees.',
#  'd. No Prior Grant or Transfer.',
#  '[PARTY A] has not granted and is not obligated to grant any \nlicense to any third party that would conflict with the [DELIVERABLE] under this \nagreement \ne. No Infringement.',
#  "[To [PARTY A]'s Knowledge,] The Software does not infringe the \nIntellectual Property rights or other rights of any third party.",
#  'f. No Third Party Infringement.',
#  "[Except as disclosed in [PARTY A]'s Disclosure Schedule] To \n[PARTY A]'s Knowledge, no third party is infringing its Intellectual Property rights in \nthe Software.",
#  'g. Not in Public Domain.',
#  'The Software is not in the public domain.',
#  '14.',
#  'No Warranty \n14.1 "As-Is".',
#  'The [Licensed] Software is provided "as is," with all faults, defects, bugs, and errors.',
#  '14.2 No Warranty.',
#  'Unless otherwise listed in this agreement, \na.',
#  '[PARTY A] does not make any warranty regarding the [Licensed] Software, which includes \nthat \nb.',
#  '[PARTY A] disclaims to the [fullest] extent authorized by Law any and all [other] \nwarranties, whether express or implied, including any implied warranties of [title, non-\ninfringement, quiet enjoyment, integration,] merchantability or fitness for a particular \n4 of 11 \n\n\x0c\npurpose.',
#  '15.',
#  'Intellectual Property.',
#  '[PARTY A] will retain exclusive interest in and ownership of its Intellectual \nProperty rights in and to the Software and expressly reserves all rights not expressly granted under \nthis agreement.',
#  '16.',
#  'Government End Users \n16.1 "Commercial Software".',
#  'If [Licensed] Software and related documentation are supplied to or \npurchased by or on behalf of the United States Government, \na. that [Licensed] Software will be deemed to be "commercial software", as that term is \nused in the Federal Acquisition Regulation system, and \nb. the rights of the United States will not exceed the minimum rights listed in FAR 52.227-19 \nfor "restricted computer software".',
#  '16.2 All Other Terms Apply.',
#  'All other terms and conditions of this agreement otherwise apply.',
#  '17.',
#  '[PARTY B] Data \n17.1 Collect and Use of Data.',
#  '[PARTY A] may collect and use technical information gathered as part \nof its maintenance, support, and training services, only for the purpose of improving its products and \nservices.',
#  '17.2 Non-Disclosure.',
#  "[PARTY A] will not disclose this any of this information in a form that personally \nidentifies [PARTY B] or [PARTY B]'s clients.",
#  '18.',
#  'Compliance with Laws.',
#  'Each party will \n18.1 comply with all applicable Laws [relating to [SUBJECT MATTER OF AGREEMENT]], and \n18.2 notify the other party if it becomes aware of any non-compliance in connection with this \nsection.',
#  '19.',
#  'Export Control Laws.',
#  'Each party shall obtain all Permits necessary to and otherwise comply with \nall Laws on export control applicable to this agreement and all transactions contemplated under this \nagreement.',
#  '20.',
#  'Source Code Escrow.',
#  'On [PARTY B]\'s written request, [PARTY A] shall place the source code for \nthe Software into escrow with [ESCROW COMPANY NAME] (the "Escrow Company") for [PARTY \nB]\'s benefit, subject to [PARTY B]\'s execution of (and the terms and conditions of) [PARTY A]\'s \nstandard form of Software Escrow Agreement with Escrow Company and [PARTY B]\'s payment of all \napplicable escrow fees.',
#  '21.',
#  'Confidentiality Obligations.',
#  'The parties continue to be bound by the terms of the non-disclosure \nagreement between the parties, dated [DATE] and attached to this agreement on [ATTACHMENT].',
#  '22.',
#  'Publicity \n22.1 Consent.',
#  "Neither party will use the other party's name, logo, or trademarks, or issue any press \nrelease or public announcement regarding this agreement, without the other party's written \nconsent, unless specifically permitted under this agreement or required by Law.",
#  '5 of 11 \n\n\x0c\n22.2 Cooperation.',
#  'The parties will cooperate to draft all appropriate press releases and other public \nannouncements relating to the subject matter of this agreement and the relationship between the \nparties.',
#  '22.3 No Unreasonable Delay.',
#  'The parties will not unreasonably withhold or delay their consent to \npress releases or public announcements.',
#  '23.',
#  'Termination \n23.1 Termination on Notice.',
#  'Either party may terminate this agreement for any reason on \n[TERMINATION NOTICE BUSINESS DAYS] Business Days’ \nnotice to the other party.',
#  '23.2 Termination for Material Breach.',
#  "Each party may terminate this agreement with immediate \neffect by delivering notice of the termination to the other party, if \na. the other party fails to perform, has made or makes any inaccuracy in, or otherwise \nmaterially breaches, any of its obligations, covenants, or representations, and \nb. the failure, inaccuracy, or breach continues for a period of [BREACH CONTINUATION \nDAYS] Business Days' after the injured party delivers notice to the breaching party \nreasonably detailing the breach.",
#  '24.',
#  'Effect of Termination \n24.1 Payment Obligations.',
#  'On the expiration or termination of this agreement, each party shall \na. pay any amounts it owes to the other party, including payment obligations for services \nalready rendered, work already performed, goods already delivered, or expenses already \nincurred, and \nb. refund any payments received but not yet earned, including payments for services not \nrendered, work not performed, or goods not delivered, expenses forwarded.',
#  '24.2 Termination of License Grant.',
#  'On the expiration or termination of this agreement the \n[DELIVERABLE] granted under this agreement will terminate with immediate effect.',
#  '25.',
#  'Return of Property.',
#  "On termination or expiration of this agreement, or on [PARTY A]'s request, \n[PARTY B] will \n25.1 return to [PARTY A] all originals of the information and other property, including Intellectual \nProperty, it received from [PARTY A], \n25.2 destroy all copies of such information and other property it has in its possession or control, and \n25.3 on [PARTY A]'s request, certify to [PARTY A] in writing that it destroyed all such copies.",
#  '26.',
#  'Indemnification \n26.1 Indemnification by [PARTY B].',
#  '[PARTY B] (as an indemnifying party) shall indemnify [PARTY \nA] (as an indemnified party) against all losses and expenses in connection with any \nproceeding arising out of \na.',
#  "[PARTY B]'s use of the Software, and \n6 of 11 \n\n\x0c\nb.",
#  "[PARTY B]'s unauthorized customization, modification, or other alterations to the \nSoftware, including claims that its customization, modification, or other alterations \ninfringe a third party's Intellectual Property rights, \n26.2 Mutual Indemnification.",
#  "Each party (as an indemnifying party) shall indemnify the other (as an \nindemnified party) against all losses in connection with any proceeding arising out of the \nindemnifying party's willful misconduct or gross negligence.",
#  '26.3 Notice and Failure to Notify \na.',
#  'Notice Requirement.',
#  'Before bringing a claim for indemnification, the indemnified \nparty shall \ni. notify the indemnifying party of the indemnifiable proceeding, and \nii.',
#  'deliver to the indemnifying party all legal pleadings and other documents reasonably \nnecessary to indemnify or defend the indemnifiable proceeding.',
#  'b.',
#  'Failure to Notify.',
#  "If the indemnified party fails to notify the indemnifying party of the \nindemnifiable proceeding, the indemnifying will be relieved of its indemnification \nobligations to the extent it was prejudiced by the indemnified party's failure.",
#  '26.4 Exclusive Remedy.',
#  "The parties' right to indemnification is the exclusive remedy available in \nconnection with the indemnifiable proceedings described in this section [INDEMNIFICATION].",
#  '27.',
#  'Limitation on Liability.',
#  'Neither party will be liable for breach-of-contract damages that are \nremote or speculative, or that the breaching party could not reasonably have foreseen on entry into \nthis agreement.',
#  '28.',
#  'Definitions \n"Books and Records" means all books and records, including books of account, ledgers and general, \nfinancial and accounting records, machinery and equipment maintenance files, lists of parties to and \nprospects for franchise agreements, supplier lists, production data, quality control records and \nprocedures, customer complaints, inquiry files, research, development files, records, data (including \nall correspondence with any Governmental Authority), sales material and records (including pricing \nhistory and sales and pricing policies and practices), strategic plans, marketing and promotional \nsurveys, and material, research, and files relating to Intellectual Property.',
#  '"Business Day" means a day other than a Saturday, a Sunday, or any other day on which the principal \nbanks located in New York, New York are not open for business.',
#  '"Disclosure Schedule" means the schedules delivered, before the execution of this agreement, by \neach party to the other party which list, among other things, items the disclosure of which is \nnecessary or appropriate either in response to an express disclosure requirement contained in a \nprovision of this agreement or as an exception to one or more of the representations or warranties \nmade by the party, or to one or more of the covenants of the party.',
#  '"Effective Date" is defined in the introduction to this agreement.',
#  '7 of 11 \n\n\x0c\n["Escrow Company" is defined in section [SOURCE CODE ESCROW] [INCLUDE ONLY IF INCLUDING \nOPTIONAL SOURCE CODE ESCROW CLAUSE]] \n\n"Governmental Authority" means \n\n(a) any federal, state, local, or foreign government, and any political subdivision of any of them, \n(b) any agency or instrumentality of any such government or political subdivision, \n(c) any self-regulated organization or other non-governmental regulatory authority or quasi-\ngovernmental authority (to the extent that its rules, regulations or orders have the force of law), and \n(d) any arbitrator, court or tribunal of competent jurisdiction.',
#  '"Intellectual Property" means any and all of the following in any jurisdiction throughout the world \n(a) trademarks and service marks, including all applications and registrations, and the goodwill \nconnected with the use of and symbolized by the foregoing, \n(b) copyrights, including all applications and registrations related to the foregoing, \n(c) trade secrets and confidential know-how, \n(d) patents and patent applications, \n(e) websites and internet domain name registrations, and \n(f) other intellectual property and related proprietary rights, interests and protections (including all \nrights to sue and recover and retain damages, costs and attorneys\' fees for past, present, and future \ninfringement, and any other rights relating to any of the foregoing).',
#  '"Law" means \n\n(a) any law (including the common law), statute, bylaw, rule, regulation, order, ordinance, treaty, \ndecree, judgment, and \n(b) any official directive, protocol, code, guideline, notice, approval, order, policy, or other \nrequirement of any Governmental Authority having the force of law.',
#  '"Legal Proceeding" means any claim, investigation, hearing, legal action, or other legal, \nadministrative, arbitral, or similar proceeding, whether civil or criminal (including any appeal or \nreview of any of the foregoing).',
#  '"License Fee" is defined in section [LICENSE FEES].',
#  '"[License Grant]" is defined in section [LICENSE GRANT].',
#  '8 of 11 \n\n\x0c\n"Order" means any decision, order, judgment, award, or similar order of any court of competent \njurisdiction, arbitration panel, or Governmental Authority with jurisdiction over the subject matter, \nwhether preliminary or final.',
#  '"Permits" means all material licenses, franchises, permits, certificates, approvals, and authorizations, \nfrom Governmental Authorities necessary for the ownership and operation of the party\'s business.',
#  '"Person" includes \n\n(a) any corporation, company, limited liability company, partnership, Governmental Authority, joint \nventure, fund, trust, association, syndicate, organization, or other entity or group of persons, \nwhether incorporated or not, and \n(b) any individual.',
#  '"Software" is defined in section [LICENSE GRANT].',
#  '"Taxes" includes all taxes, assessments, charges, duties, fees, levies, and other charges of a \nGovernmental Authority, including income, franchise, capital stock, real property, personal property, \ntangible, withholding, employment, payroll, social security, social contribution, unemployment \ncompensation, disability, transfer, sales, use, excise, gross receipts, value-added and all other taxes \nof any kind for which a party may have any liability imposed by any Governmental Authority, \nwhether disputed or not, any related charges, interest or penalties imposed by any Governmental \nAuthority, and any liability for any other person as a transferee or successor by Law, contract or \notherwise.',
#  '"Term" is defined in section [TERM].',
#  '29.',
#  'General Provisions \n29.1 Entire Agreement.',
#  "The parties intend that this agreement, together with all attachments, \nschedules, exhibits, and other documents that both are referenced in this agreement and refer to \nthis agreement, \na. represent the final expression of the parties' intent relating to the subject matter of this \nagreement, \nb. contain all the terms the parties agreed to relating to the subject matter, and \nc. replace all of the parties' previous discussions, understandings, and agreements relating \nto the subject matter of this agreement.",
#  '29.2 Counterparts \na.',
#  'Signed in Counterparts.',
#  'This agreement may be signed in any number of counterparts.',
#  'b.',
#  'All Counterparts Original.',
#  'Each counterpart is an original.',
#  'c. Counterparts Form One Document.',
#  'Together, all counterparts form one single document.',
#  '29.3 Amendment.',
#  'This agreement can be amended only by a writing signed by both parties.',
#  '9 of 11 \n\n\x0c\n29.4 Relationship of the Parties \na.',
#  'No Relationship.',
#  'Nothing in this agreement creates any special relationship between the \nparties, such as a partnership, joint venture, or employee/employer relationship between \nthe parties.',
#  'b.',
#  'No Authority.',
#  'Neither party has the authority to, and will not, act as agent for or on \nbehalf of the other party or represent or bind the other party in any manner.',
#  '29.5 Assignment.',
#  "Neither party may assign this agreement or any of their rights or obligations under \nthis agreement without the other party's written consent.",
#  '29.6 Notices \na.',
#  'Method of Notice.',
#  "The parties will give all notices and communications between the \nparties in writing by (i) personal delivery, (ii) a nationally-recognized, next-day courier \nservice, (iii) first-class registered or certified mail, postage prepaid to the address that a \nparty has notified to be that party's address for the purposes of this section.",
#  'b.',
#  'Receipt of Notice.',
#  "A notice given under this agreement will be effective on \ni. the other party's receipt of it, or \nii.",
#  "if mailed, the earlier of the other party's receipt of it and the fifth business day after \nmailing it.",
#  '29.7 Governing Law and Consent to Jurisdiction and Venue \na.',
#  'Governing Law.',
#  'This agreement, and any dispute arising out of the [SUBJECT MATTER OF \nTHE AGREEMENT], shall be governed by the laws of the State of [GOVERNING LAW \nSTATE].',
#  'b.',
#  'Consent to Jurisdiction.',
#  'Each party hereby irrevocably consents to the [exclusive, nonexclusive] \njurisdiction and venue of any [state or federal] court located within [VENUE \nCOUNTY] County, State of [VENUE STATE], in connection with any matter arising out of \nthis [agreement / plan] or the transactions contemplated under this [agreement / plan].',
#  'c. Consent to Service.',
#  'Each party hereby irrevocably \ni. agrees that process may be served on it in any manner authorized by the Laws of the \nState of [GOVERNING LAW STATE], and \nii.',
#  'waives any objection which it might otherwise have to service of process under the \nLaws of the State of [GOVERNING LAW STATE].',
#  '29.8 Dispute Resolution \na.',
#  'Arbitration.',
#  'Any dispute or controversy arising out of this agreement and [SUBJECT \nMATTER OF THE AGREEMENT] will be settled by arbitration in [STATE], according to the \nrules of the American Arbitration Association then in effect, and by [NUMBER OF \nARBITRATORS] arbitrators[s].',
#  'b.',
#  'Judgment.',
#  "Judgment may be entered on the arbitrator's award in any court having \njurisdiction.",
#  "10 of 11 \n\n\x0c\nc. Arbitrator's Authority.",
#  'The arbitrator will not have the power to award any punitive [or \nconsequential] damages.',
#  '29.9 Equitable Relief \na.',
#  'Acknowledgment of Irreparable Harm.',
#  'Each party acknowledges that their breach or \nthreatened breach of their obligations under this agreement would result in irreparable \nharm to the other party that cannot be adequately relieved by money damages alone.',
#  'b.',
#  'Intent to Allow for Equitable Remedies.',
#  'Accordingly, the parties hereby acknowledge \ntheir mutual intent that after any breach of the obligations listed in the paragraph directly \nabove, the non-breaching party may request any applicable equitable remedies from a \ncourt, including injunctive relief, without the need for that party to post any security.',
#  '29.10 Waiver \na.',
#  'Affirmative Waivers.',
#  "Neither party's failure or neglect to enforce any rights under this \nagreement will be deemed to be a waiver of that party's rights.",
#  'b.',
#  'Written Waivers.',
#  'A waiver or extension is only effective if it is in writing and signed by the \nparty granting it.',
#  'c. No General Waivers.',
#  "A party's failure or neglect to enforce any of its rights under this \nagreement will not be deemed to be a waiver of that or any other of its rights.",
#  'd. No Course of Dealing.',
#  'No single or partial exercise of any right or remedy will preclude \nany other or further exercise of any right or remedy.',
#  '29.11 Force Majeure.',
#  'Neither party will be liable for performance delays nor for non-performance \ndue to causes beyond its reasonable control, except for payment obligations.',
#  '29.12 Severability.',
#  'If any part of this agreement is declared unenforceable or invalid, the remainder \nwill continue to be valid and enforceable.',
#  '29.13 Survival.',
#  "The parties' obligations under sections [CONFIDENTIALITY OBLIGATIONS], [NONCOMPETITION \nOBLIGATION], and [EFFECT OF TERMINATION] will survive the [TERMINATION, \nEXPIRATION, CLOSING DATE] of this agreement.",
#  '29.14 Headings.',
#  'The section headings contained in this agreement are for reference purposes only \nand shall not affect the meaning or interpretation of this agreement.',
#  '29.15 Attorney Fees.',
#  "If either party brings an Action to enforce their rights under this agreement, the \nprevailing party may recover its expenses (including reasonable attorneys' fees) incurred in \nconnection with the Action and any appeal from the losing party.",
#  'This agreement has been signed by the parties.',
#  '[PARTY A NAME] [PARTY B NAME] \nName: [PARTY A SIGNATORY NAME] Name: [PARTY B SIGNATORY NAME] \nTitle: [PARTY A SIGNATORY TITLE] Title: [PARTY B SIGNATORY TITLE] \n\n11 of 11']

# %%
# !pip install import-ipynb

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Deal_analytics_project/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.9/dist-packages (from import-ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from import-ipynb) (5.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (2.14.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (67.6.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->import-ipynb) (2.16.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat->import-ipynb) (5.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (1.16.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat->import-ipynb) (3.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.2
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Deal_analytics_project

# %%
import web_scraping_module

# %%
from web_scraping_module import newsletter
from web_scraping_module import investmentletter

# %%
newsletter()
# Out:
# ['\n\t\t\t\t\t1mg\t\t\t\t',
#  '\n\t\t\t\t\t1mg aims to make healthcare accessible, understandable, and affordable for all Indians. It offers ePharmacy, eDiagnostics, and health information to enable consumers to better manage their health.\t\t\t\t',
#  '\n\t\t\t\t\t90 Seconds\t\t\t\t',
#  '\n\t\t\t\t\t90 Seconds is the world’s leading cloud video production platform, allowing brands to purchase, plan, shoot, edit and review video anywhere in the world, online and on mobile.\t\t\t\t',
#  '\n\t\t\t\t\t99.co\t\t\t\t',
#  '\n\t\t\t\t\t99.co is one of the fastest-growing property search companies in Southeast Asia.\t\t\t\t',
#  '\n\t\t\t\t\tAbsolute Foods\t\t\t\t',
#  '\n\t\t\t\t\tAbsolute Foods intersects technology, science, and agriculture to go beyond organic food – focusing on produce that is 100% natural and Non-GMO.\t\t\t\t',
#  '\n\t\t\t\t\tAerotime\t\t\t\t',
#  '\n\t\t\t\t\tAerotime helps users work in flow state by streamlining meetings and making it easier to prioritize tasks.\t\t\t\t',
#  '\n\t\t\t\t\tAI Rudder\t\t\t\t',
#  '\n\t\t\t\t\tAI Rudder aims to increase the scale, speed and quality of customer experience with a human-like AI voice assistant.\t\t\t\t',
#  '\n\t\t\t\t\tAirmeet\t\t\t\t',
#  '\n\t\t\t\t\tAirmeet is the fastest growing platform for hosting a rich variety of online events by crafting a virtual space for the world to connect and collaborate.\t\t\t\t',
#  '\n\t\t\t\t\tAkulaku\t\t\t\t',
#  '\n\t\t\t\t\tAkulaku is a Southeast Asian e-commerce platform that allows consumers to pay for products in instalments without a credit card.\t\t\t\t',
#  '\n\t\t\t\t\tAkumentis Healthcare\t\t\t\t',
#  '\n\t\t\t\t\tAkumentis Healthcare is one of the fastest-growing branded generics companies in India. It has a presence across multiple therapeutic areas and holds a strong market position in women’s health.\t\t\t\t',
#  '\n\t\t\t\t\tAnimall\t\t\t\t',
#  '\n\t\t\t\t\tAnimall aims to improve the lives of dairy farmers in a meaningful way by making dairy farming significantly more profitable.\t\t\t\t',
#  '\n\t\t\t\t\tApna\t\t\t\t',
#  '\n\t\t\t\t\tApna is a platform that creates better economic opportunities for the blue/grey collar workforce globally.\t\t\t\t',
#  '\n\t\t\t\t\tAppier\t\t\t\t',
#  '\n\t\t\t\t\tAppier builds AI-based cross-screen analytics and targeting platforms for businesses to reach and engage customers across multiple smart devices.\t\t\t\t',
#  '\n\t\t\t\t\tAptus\t\t\t\t',
#  '\n\t\t\t\t\tAptus Value Housing Finance India Ltd is a home loan company that addresses the housing finance needs of self-employed individuals belonging to low and middle-income families from semi-urban and rural markets.\t\t\t\t',
#  '\n\t\t\t\t\tArbo Works\t\t\t\t',
#  '\n\t\t\t\t\tArbo Works is determined to help people enjoy more successful financial lives.\t\t\t\t',
#  '\n\t\t\t\t\tArrow\t\t\t\t',
#  '\n\t\t\t\t\tArrow is a Singapore-based eCommerce solution that partners with merchants to create a fast and frictionless checkout experience for consumers – regardless of their location or the channel they are buying on.\t\t\t\t',
#  '\n\t\t\t\t\tAspire\t\t\t\t',
#  '\n\t\t\t\t\tAspire is the all-in-one finance operating system for growing businesses, helping companies pay, manage, and earn smarter.\t\t\t\t',
#  '\n\t\t\t\t\tAstro\t\t\t\t',
#  '\n\t\t\t\t\tAstro is Indonesia’s first and fastest-growing on-demand platform for groceries and essentials.\t\t\t\t',
#  '\n\t\t\t\t\tAtlan\t\t\t\t',
#  '\n\t\t\t\t\tAtlan is a modern data collaboration workspace, enabling teams to create a single source of truth for all their data assets, and collaborate across the modern data stack.\t\t\t\t',
#  '\n\t\t\t\t\tAvataar\t\t\t\t',
#  '\n\t\t\t\t\tAvataar is a 3D AI company that helps large enterprise customers create immersive and interactive shopping experiences for their end consumers.\t\t\t\t',
#  '\n\t\t\t\t\tAwfis\t\t\t\t',
#  '\n\t\t\t\t\tAwfis is one of South Asia’s largest networks of collaborative co-working spaces.\t\t\t\t',
#  '\n\t\t\t\t\tBand Protocol\t\t\t\t',
#  '\n\t\t\t\t\tBand Protocol is a cross-chain data oracle platform that aggregates and connects real-world data and APIs to smart contracts by building a decentralized bridge that enables secure inter-operabilities.\t\t\t\t',
#  '\n\t\t\t\t\tBankBazaar\t\t\t\t',
#  '\n\t\t\t\t\tBankBazaar helps consumers choose the right financial product for their needs.\t\t\t\t',
#  '\n\t\t\t\t\tBeam\t\t\t\t',
#  '\n\t\t\t\t\tBeam offers micro-mobility solutions to urban dwellers across APAC.\t\t\t\t',
#  '\n\t\t\t\t\tBelong\t\t\t\t',
#  '\n\t\t\t\t\tBelong is a predictive, outbound recruitment solution that helps businesses discover, engage and hire talented candidates.\t\t\t\t',
#  '\n\t\t\t\t\tBeta Finance\t\t\t\t',
#  '\n\t\t\t\t\tBeta Finance is a decentralized finance protocol that has developed a one-click solution for lending, borrowing and shorting of any crypto asset.\t\t\t\t',
#  '\n\t\t\t\t\tBharatPe\t\t\t\t',
#  '\n\t\t\t\t\tBharatPe is a FinTech company that empowers Indian merchants to accept UPI payments from their customers for free through the BharatPe QR.\t\t\t\t',
#  '\n\t\t\t\t\tBibit\t\t\t\t',
#  '\n\t\t\t\t\tBibit is a digital investing app with a robo-advisory service that helps first-time investors invest in mutual fund products.\t\t\t\t',
#  '\n\t\t\t\t\tBifrost\t\t\t\t',
#  '\n\t\t\t\t\tBifrost replaces the tedious process of data collection, curation, & labelling by generating physically-accurate 3D worlds & capturing perfectly labelled datasets.\t\t\t\t',
#  '\n\t\t\t\t\tBijnis\t\t\t\t',
#  '\n\t\t\t\t\tBijnis is revolutionising unorganised manufacturing industries by digitising factories. Its goal is to make the factory smarter, faster and cost effective that will enable factory owners to scale & grow their business.\t\t\t\t',
#  '\n\t\t\t\t\tBikayi\t\t\t\t',
#  '\n\t\t\t\t\tBikayi empowers entrepreneurs to build their online businesses by creating an online store with a fully customizable e-commerce website in less than 90 seconds.\t\t\t\t',
#  '\n\t\t\t\t\tBiofourmis\t\t\t\t',
#  '\n\t\t\t\t\tBiofourmis develops and delivers clinically validated software-based therapeutics.\t\t\t\t',
#  '\n\t\t\t\t\tBira\t\t\t\t',
#  '\n\t\t\t\t\tB9 Beverages is a fast-growing craft beer brand, available in draft and bottle formats.\t\t\t\t']

# %%
investmentletter()
# Out:
# [None,
#  ' ',
#  'Torsten Asmus/iStock via Getty Images',
#  'Sequoia Fund’s results for the quarter and year ended December 31, 2022 appear below with results of the S&P 500 Index for the same periods:',
#  'Through December 31, 2022',
#  'Sequoia Fund',
#  'S&P 500 Index*',
#  'Fourth Quarter',
#  '8.81%',
#  '7.56%',
#  '1 Year',
#  '-30.52%',
#  '-18.11%',
#  '3 Years (Annualized)',
#  '2.45%',
#  '7.66%',
#  '5 Years (Annualized)',
#  '6.22%',
#  '9.42%',
#  '10 Years (Annualized)',
#  '7.33%',
#  '12.56%',
#  'Since Inception (Annualized)**',
#  '12.92%',
#  '10.85%',
#  'The performance returns for the Sequoia Fund are presented net of investment advisory fees and all other fees and expenses, and reflect the reinvestment of dividends and other income / earnings. Past performance does not guarantee future results. Current performance may be lower or higher than the performance data quoted.',
#  '*The S&P 500 Index is an unmanaged capitalization-weighted index of the common stocks of 500 major US corporations. The Index does not incur expenses. It is not possible to invest directly in the Index.',
#  '**Inception Date: July 15, 1970.',
#  None,
#  'Things looked quite different just 12 months ago. In last year’s annual letter, we noted that both Sequoia and the S&P 500 had produced an essentially identical compound total return of 18.2% over the period from June 2016 through December 2021. We explained that we were generally pleased at having kept pace with a hot stock market, certain pockets of which we declared to be obviously speculative. We then expressed confidence that when Sequoia and the S&P 500 did finally and inevitably diverge, it would be to our benefit.',
#  'Unfortunately, Sequoia underperformed the S&P 500 this year. We are disappointed by this outcome, but we remain steadfast in our belief that a concentrated portfolio of thoroughly researched, high-quality businesses purchased at attractive prices will outperform over the long term. Further, we remain confident that Sequoia is just such a portfolio.',
#  'The market prices of many of Sequoia’s holdings declined significantly over the course of this year, but with a small handful of exceptions we do not detect diminution in the intrinsic value of the businesses themselves. We believe our businesses are on the whole highly advantaged, conservatively financed, and run by capable managers. Over a very unusual last few years, they have generally maintained or improved their competitive positions and grown their underlying earnings power. We will come back to this very important point.',
#  None,
#  'As we all know, investing for the long term is a bumpy road. Business fundamentals don’t progress in a straight line, and the market’s assessment of businesses can change, sometimes significantly, from one day to the next. Over sufficiently long periods of time, though, investment performance is driven by the progression of business fundamentals relative to price paid.',
#  'None of this means that bumps in the road, when encountered, should be casually dismissed. Sometimes a bump is just a bump. Other times, it’s an indication that something has in fact gone wrong with an investment. Distinguishing between the two in real-time isn’t always easy, but if you’re on top of your businesses and honest with yourself, you can get close enough to the truth.',
#  None,
#  'That we got this particular assessment wrong and other assessments wrong for a couple of our other holdings was not the problem. “Wrong” happens all the time in investing. As value investors, the crux of our endeavor is to pay prices that ensure the cost of being wrong is manageable. This is why Warren Buffett calls “margin of safety” the three most important words in investing.',
#  None,
#  'Thankfully, Sequoia’s long-term track record, and those of other highly respected firms with similar track records, prove that a sound and diligently executed investment strategy is resistant to mistakes. But resistant doesn’t mean immune. Mistakes of the sort just identified must be minimized. And the way to minimize them is to acknowledge them, learn from them, and then move on. That is what we are doing.',
#  'We recently refined in a few different ways the process by which we follow companies of interest and debate investments. We believe they will reduce the odds of our making the same sorts of mistakes in the future, while at the same time encouraging patterns of behavior that have worked for us over many years. Over time, if they simply help us to avoid a few mistakes and/or find our way to a few more winning investments, they can have a significant, beneficial impact on long- term performance. But there is no substitute for a disciplined mindset, and that, above all, is what we must seek to maintain. Process is important but ultimately subordinate. It exists to reinforce a disciplined mindset.',
#  'To recap, we are not satisfied with our performance this year. At the same time, we believe deeply in our strategy and our process. We strive to research our investments as thoroughly and tenaciously as anyone in the industry. We’ve already taken steps to refine other aspects of our process, and we will continue to improve it in the future. Most importantly, Sequoia owns a collection of very high-quality businesses that we believe are trading for very attractive prices.',
#  'Perhaps the best way to convey our thinking on this last point is to drill down into the businesses that Sequoia owns and that should ultimately drive its long-term performance. Our year-end letter doesn’t typically include this sort of review, but in a volatile time like this one we think there is value in laying out what we own and why. We’ll focus on our top ten holdings, which at year-end collectively accounted for a full 61.2% of Sequoia’s capital.',
#  'Schwab’s shares held up quite well this year in the face of the broad market drawdown. Business performance was excellent. For the full year, Schwab’s revenues and EPS are expected to be up approximately 13% and 21%, respectively. Versus 2019, the company’s revenues and EPS are expected to have compounded at annual rates of approximately 25% and 14%, respectively.',
#  'The most obvious development for Schwab this year was the rather sudden change in the interest rate environment. In a higher rate environment, Schwab earns more interest revenue on client cash balances. Rates aside, this is a company that has for decades executed a consistently client-friendly strategy. The result is massive scale, a trusted brand, and an ever- expanding portfolio of products and services.',
#  'At month-end September 2022, Schwab’s total client assets stood at $6.6 trillion, making it one of the largest wealth management platforms in the US. This scale allows the company to serve its customers well and at a virtually unrivaled cost, creating something of a virtuous circle. Schwab continues to gather client assets from higher-cost channels, where multiple trillions still reside, at an impressive pace. Through the first nine months of 2022, the company grew client assets 6% organically, consistent with trends over the past many years.',
#  'Schwab has taken the initiative over the last few years, sending shockwaves through the industry, when it reduced commissions to zero for most trades in 2019. It then quickly targeted TD Ameritrade, acquiring it for $26 billion the following year. The multi-year integration is ongoing, but we already feel comfortable declaring this deal a strategic success.',
#  'At the current share price, Schwab trades for approximately 16x expected EPS for 2023. Assuming no change in the interest rate environment and a continuation of business trends, Schwab is trading for a low double-digit multiple of what it’s likely to earn in three years. We consider the current share price an attractive one for a business that has for decades used its scale and client-centric approach to gather assets at a consistent and healthy pace, earns good-to-great returns on equity across a wide range of interest rate environments, and still has many years of growth ahead of it.',
#  'Shares of Liberty Media, the holding company through which we own the Formula One motorsport league, declined this year, though by significantly less than the S&P 500 Index. Business performance was superb. For full-year 2022, Liberty Media’s revenues are expected to be up almost 20%, with profits up even more. This robust growth is the result of a continued recovery from pandemic-related disruptions, but even after adjusting for this recovery the business grew nicely.',
#  'Versus 2019, Liberty Media’s revenues and per share earnings power are expected to have compounded at annual rates of approximately 7% and 23%, respectively.',
#  'Formula One has made very significant progress since Sequoia first acquired shares via a private placement in 2017. Formula One has for decades been the pinnacle of global motorsport, but under previous management it suffered from internecine fissures and short-sighted strategy that were negatively impacting the sport and the business. 2022 saw the full implementation of a new Concorde Agreement signed in 2020. The Concorde Agreement lays out the key economic, technical and sporting terms on which the teams participate, and this most recent one realigns the teams and the league in a manner that should pay off for all parties involved. The new Concorde Agreement has already had some positive impact on the sport and the business, and we believe the majority of the benefits have yet to be realized.',
#  'Already, the sport is healthier than it has been for a long time. TV viewership was up globally again this year, which helped Formula One secure a round of richer broadcast deals in Europe as well as in the US, where the new deal with ESPN/ABC is rumored to be almost 10x more remunerative than the last one. In 2022, US TV viewership was up almost 30% over last year, building on the momentum of previous years and driven by the latest season of Netflix’s Drive to Survive series and the calendar’s new Miami race. Liberty Media plans to add a third US race in 2023, in Las Vegas. Instead of relying on a promoter as it typically does, Liberty Media will run the Las Vegas race itself, which will require significant investment but should generate an attractive return.',
#  'Enticed by the growth and strength of the fan base, new sponsors are clamoring to sign up. This year saw a number of high- profile wins including Salesforce and Lenovo, as well as an expanded relationship with Amazon Web Services. Further, we are now seeing multiple well-funded and highly respected parties seeking to enter the sport, by either buying into an existing team or bringing a new team to the grid. Audi will partner with Team Sauber in 2026, and a duo consisting of General Motors and Andretti Motorsport has publicly announced its desire to enter the sport, while Porsche and Ford are both rumored to be exploring a possible entry.',
#  'At the current share price, Liberty Media is trading for approximately 30x expected per share earnings power for 2023 and a high-twenties multiple of expected free cash flow for 2023. We consider this a reasonable price for an impossible-to- replicate global sports league that is in undeniably rude health and that should drive mid-teens or better earnings growth for the next several years.',
#  'United was among Sequoia’s best performing stocks this year, thanks to typically strong financial results and increased appreciation for the business’ relative insensitivity to the broader economy. For the full year 2022, United’s revenues and EPS are expected to be up approximately 13% and 17%, respectively. Versus 2019, the company’s revenues and EPS are expected to have compounded at annual rates of approximately 10% and 14%, respectively.',
#  'UnitedHealth Group may not be a particularly beloved company, but it is one of the more entrenched businesses we’ve come across. Managed care, in its various forms – commercial risk, commercial fee, Medicare Advantage, and managed Medicaid – is an utterly essential component of our healthcare system. And in managed care, no one is bigger, more diversified or better run than United. In addition to its managed care business, United owns and operates the country’s third largest pharmacy benefit manger and is also the single largest owner by a wide margin of non-hospital care assets, including physician practices, urgent care centers, and ambulatory surgical centers.',
#  'While we are highly confident in the quality of United’s business, we also recognize the importance of context. United has a very strong position within a healthcare system that is highly imperfect. Practically speaking, this means we need to balance the quality of the business against inherent policy risk, which ebbs and flows but is always present.',
#  'While we can easily imagine scenarios in which policy developments negatively impact United’s business, we consider it highly unlikely that United and the other managed care companies would ever get fully disintermediated. In fact, there is a reasonable argument to be made that United and the other managed care companies, which have been aggressively expanding into capitated business lines, are increasingly part of the solution to the problem of rising healthcare costs. Ultimately, we made the decision to trim Sequoia’s investment in United this past year after the stock appreciated significantly. Policy risk, while bearable, is real. And the risk-reward, though still attractive, had become less asymmetric since our initial investment in 2019.',
#  'At the current share price, United trades for approximately 19x expected EPS for 2023. We consider this an attractive valuation for a business that is highly entrenched, nicely diversified, very well run, and capable of growing earnings in economically insensitive fashion and at a teens rate for many years to come.',
#  'Universal Music Group’s shares declined this year, though by significantly less than the S&P 500 Index. We saw solid underlying business performance and a continued bright outlook. We added modestly to our position during the year. For full-year 2022, revenues and EPS are both expected to be up double digits exclusive of the significant benefit from US dollar strengthening. Given past corporate actions and associated accounting complexity, we don’t have perfectly like-for- like financial figures going back to 2019, but we can safely say that Universal Music Group has grown both revenues and earnings at healthy double-digit rates over the past three years.',
#  None,
#  'The labels play a vital and entrenched role in the music ecosystem. By virtue of their expertise, scale, and relationships with producers, marketers, and distributors, labels offer musical artists the best shot at breaking out and sustaining a long career in the business. In return, the labels receive an interest in the artists’ music rights, often lasting decades, and they help maximize the monetization of those rights. The three major labels collectively have ownership interests in and control rights over almost all the music that has ever been made and commercialized in the West, giving them significant and valuable leverage when negotiating with distribution platforms.',
#  'The distribution landscape has changed markedly over the past two decades or so. The rise of internet-enabled piracy in the late 1990s decimated the industry. But with the subsequent emergence of digital download followed by streaming, the labels reestablished the value they could charge for their content. Industry-wide revenues have now recovered, recently returning to the nominal peak reached over two decades ago. We believe they are poised to reach new heights in the years to come.',
#  'Streaming now accounts for over half of Universal Music Group’s revenues, and streaming growth continued apace in 2022. What’s more, the company and its peers have built promising new revenue streams providing their music to accompany the video assets of major internet platforms like YouTube, TikTok, and Instagram. All of this, plus the return of live concerts and associated revenues, powered Universal Music Group’s growth this past year.',
#  'At the current share price, Universal Music Group trades for a mid-twenties multiple of expected EPS for 2023. We consider this an attractive price for a business with a clear and compelling value proposition, an extremely strong competitive position, and the ability to grow earnings at a teens rate over the next handful of years.',
#  'Though Intercontinental Exchange’s shares were down significantly this year, the business itself did fine on the whole. We added modestly to our position during the year. For the full-year 2022, the company’s revenues and EPS are expected to be up approximately 2% and 4%, respectively. Versus 2019, the company’s revenues and EPS are expected to have compounded at annual rates of approximately 12% and 11% respectively.',
#  'Focusing specifically on full-year 2022, business performance was strong across most of Intercontinental Exchange’s portfolio. Taking together the two largest segments – Exchange, in which the company operates a variety of derivative and equity exchanges that enjoy extremely strong, and in some cases monopoly-like, competitive positions, and Fixed Income & Data Services, in which the company offers a variety of data, analytics and related services that are often unique and in any case very sticky – revenues are expected to be up approximately 8%, with operating income likely up more. These two segments drive over 80% of total company revenue and operating income.',
#  'In contrast, revenues within Intercontinental Exchange’s Mortgage Technology segment are expected to be down approximately 19% in full-year 2022, with operating income likely down more. Mortgage Technology is sensitive to volumes, and the fact is industry-wide mortgage origination activity fell sharply this past year.',
#  None,
#  'At the current share price, Intercontinental Exchange trades for approximately 19x expected EPS for 2023. We consider this an attractive price for a set of businesses that possess obviously appealing financial characteristics, enjoy very strong competitive positions, are capable of driving double-digit EPS growth for years to come, and are overseen by CEO Jeff Sprecher, who built the company out of whole cloth and whose track record speaks for itself.',
#  'Eurofins was among Sequoia’s worst performing stocks this year. We added modestly to our position during the year. On the surface, it would appear the business struggled. For full-year 2022, Eurofins’ total revenues are expected to be flat, with operating income likely down over 20%. However, these full-year 2022 results reflect a significant and, in our view, predictable unwind of high-margin Covid-related testing activity. Our best guess is that Eurofins’ revenues exclusive of Covid-related testing activity will have compounded at an annual rate of roughly 10% versus 2019 levels, with profits having compounded noticeably faster. In short, the business is progressing in line with our high expectations.',
#  'Eurofins is a worldwide leader in food, environmental, and pharmaceutical testing. The company is run by Gilles Martin, who founded the company in France in 1987 with just three employees. At the risk of generalizing, testing is a very good business: the service has a low cost relative to the end-product, the tests are important and in many cases required as a matter of regulation, and the customer relationships are sticky.',
#  'Eurofins may live in a good neighborhood, but it never coasts. The company is a very high performer when it comes to strategy, operations and capital allocation. For all its history, Eurofins’ strategy has remained the same: Achieve the #1 or #2 position in attractive testing markets across numerous verticals and geographies. The company drives operational excellence via a long-term mindset coupled with a highly decentralized organizational approach that both empowers and holds accountable its local lab leaders. As for capital allocation, the company has a multi-decade track record of acquiring both aggressively and sensibly.',
#  'At the current share price, Eurofins trades for approximately 19x expected EPS for 2023. We consider this an attractive price for a high-performing and resilient testing business that is run by a fully aligned founder-owner CEO and that ought to grow profits at a double-digit rate, from a combination of both solid organic growth and internally funded M&A, for many years to come.',
#  'Alphabet’s share price declined significantly this year, and the business results were undeniably mixed. For full-year 2022, revenues are expected to be up approximately 10%, whereas EPS is expected to be down approximately 16%. However, when the business results are viewed over the past few years, the picture is anything but mixed. Versus 2019, Alphabet’s revenues and EPS are expected to have compounded at annual rates of approximately 21% and 24%, respectively. This is a substantially bigger business than it was going into the pandemic.',
#  'As we all know, Google remains synonymous with search. Search advertising continues to grow at a double-digit rate, driven by ongoing ecommerce penetration. The moats around Alphabet’s core business are wide and numerous. They include Google Chrome, which has a roughly 65% share in browsers; Android, which has a roughly 75% share in smartphones; and a variety of products and services – including Gmail, Maps, Chromebooks, Google Docs, and more – that tie users into the company’s ecosystem.',
#  'Adjacent businesses YouTube and Google Cloud continue to grow and have substantial room to improve their margins. Other ventures like Waymo, Nest and Verily remain early stage, but boast strong technical foundations.',
#  'Running through Alphabet’s various businesses are best-in-class capabilities around distributed hyperscale computing, advertising targeting technology, and artificial intelligence. Almost all of Alphabet’s products and services have already been suffused with artificial intelligence to some extent, and we believe the company’s efforts here will come increasingly to the fore in 2023 and beyond.',
#  'The most obvious risk facing Alphabet is regulation. Regulators and legislators across the globe continue to scrutinize Alphabet’s business practices as well as those of other large technology companies. We take it as a given that Alphabet will be forced to pay fines and to alter its business practices in various ways that could adversely impact revenues and profits. But it’s important to maintain perspective: regulators are taking an active stance precisely because Alphabet’s business is exceptionally powerful and well protected.',
#  'At the current share price, Alphabet trades for approximately 18x expected EPS for 2023. We consider this an attractive price for a globally dominant business capable of compounding EPS at a double-digit rate over the next several years.',
#  'Constellation’s shares declined this year, falling in USD terms a couple points less than the S&P 500 Index. Meanwhile, the business performed admirably. For full-year 2022, the company’s revenues and EPS are expected to be up approximately 28% and 14%, respectively. Organic growth, at approximately 2%, was typically modest. As is always the case with Constellation, growth was driven primarily by acquisitions, including the largest in the company’s history, the $700 million carve-out of the Allscripts hospital and physician practice software business. Versus 2019 levels, Constellation’s revenues and EPS are expected to have compounded at annual rates of 23% and 23%, respectively.',
#  'We are often wary of acquisition-driven growth strategies, but Constellation is an exceptional acquirer. For over twenty years, founder and CEO Mark Leonard has managed to maintain, in the face of ever-increasing scale, high rates of acquisition-led growth accompanied by high rates of return on acquisitions. Constellation’s track record puts it in rare company, alongside some of history’s greatest acquisition-led compounders.',
#  'The key question is whether Constellation can continue executing its strategy in a similarly successful fashion for long enough to render the current price attractive. We believe it can. Constellation is focused on vertical market software businesses, which are generally quite profitable and provide code that is essential to their customers. Constellation is working with very good raw material, and there are an awful lot of these vertical market software businesses out there. We do not believe Constellation is in any danger of running out of targets.',
#  'Further, Mark Leonard is a dedicated student of other high-performing conglomerates with similarities to Constellation. He is thoughtful about extending the company’s growth potential for as long as possible. For example, he has distributed M&A responsibility to scores of portfolio managers across the globe, developed a separate initiative to compete with private equity for large software deals, and explored new avenues for growth outside of software.',
#  'At the current share price, Constellation trades for approximately 29x expected EPS for 2023. We consider this is a reasonable price for a unique company with a proven ability to allocate significant amounts of capital at high rates of return. We believe the company will continue to do so, thereby compounding earnings at a mid-teens rate or better over the next several years.',
#  'Elevance’s stock was Sequoia’s best performing stock this year, for all the same reasons that United’s stock performed well. For full-year 2022, Elevance’s revenues and EPS are expected to be up approximately 14% and 12%, respectively. Versus 2019, the company’s revenues and EPS are expected to have compounded at annual rates of 14% and 15%, respectively.',
#  'Elevance (renamed from Anthem in 2022) is, like United, primarily a managed care company. In terms of revenues and profits, it is big, but not quite as big as United. Further, it is less scaled and less diversified than United in non-insurance business lines. However, Elevance has its own strengths. It is the largest operator of for-profit Blue Cross Blue Shield plans in the country. Built up over the course of decades, these plans have unrivaled brand recognition as well as a network of provider relationships that is unique in terms of market coverage and negotiated rates.',
#  'Elevance has long been an advantaged business, but it has not always been particularly well run. In 2017, Gail Boudreaux, formerly a senior executive at United, took over the reins. She is experienced and results-oriented. We believe Boudreaux can help Elevance make more of the enviable position it has long enjoyed.',
#  'On balance, we prefer United’s business to Elevance’s. But price matters, and Elevance trades at a significant discount to United. Ultimately, we feel comfortable owning both companies. As with United, we trimmed our investment in Elevance this year on account of ever-present policy risk and in light of the fact that the price-earnings ratio had expanded significantly since Sequoia’s initial purchase.',
#  'At the current share price, Elevance trades for approximately 15x expected EPS for 2023. We consider this an attractive valuation for a business that is highly entrenched, reasonably diversified, better run than in the past, and capable of growing earnings in economically insensitive fashion and at a teens rate for several years.',
#  'After nearly doubling in 2021, Credit Acceptance’s shares declined significantly this year, as tight supplies in the used car market impacted the lender’s ability to grow its loan book. For full-year 2022, revenues and earnings are expected to be roughly flat. Versus 2019, revenues and EPS are expected to have compounded an annual rates of approximately 6% and 14%, respectively.',
#  'The earnings of Credit Acceptance in any given year reflect the size and performance of its book of outstanding loans, which is driven by the pace of underwriting activity of the previous few years, and the collection experience in the current year. 2022 was highly unusual, with the global shortage of semiconductor chips triggering a shortage of new automobiles, which in turn drove used car prices up by almost 50% from January 2021 to January 2022. This tightness in the used car market drove affordability down and shifted dealers’ focus to prime borrowers, reducing demand for Credit Acceptance’s loans given its position as lender of last resort for subprime credits. At the same time, collections on outstanding loans exceeded expectations thanks to low unemployment and lingering benefits from aggressive fiscal stimulus policies.',
#  'In short, the environment was good for collections, which boosts current earnings, and bad for new underwriting, which powers future earnings. Credit Acceptance’s loan volume through the first nine months of 2022 was down approximately 22% from peak volumes in the first nine months of 2019, and we expect this stretch of anemic underwriting to have a temporary impact on future earnings. The good news is that the extraordinary tightness in the new and used car markets is already abating, and Credit Acceptance’s loan volumes should normalize in due course. Importantly, Credit Acceptance has maintained its disciplined underwriting standards during a very competitive time, rather than chase volume by pricing more aggressively.',
#  'Auto loan cycles come and go, and Credit Acceptance is expert at navigating them, usually growing market share when other lenders batten down the hatches. The more salient long-term risk to Credit Acceptance is regulatory intervention. Because it lends to a vulnerable population, Credit Acceptance attracts the attention of various regulators and enforcement agencies. While we welcome alert and astute regulation of the subprime auto market, we recognize that regulatory overreach is an ever-present risk.',
#  'A complaint from the Massachusetts Attorney General in August of 2020 drove the stock of Credit Acceptance down dramatically. The stock recovered when the suit was settled at a cost of roughly $2 per share in September of 2021. Today, Credit Acceptance faces a similar complaint from the attorney general of New York and the Consumer Finance Protection Bureau, and this has once again cast a pall over the stock. We expect this complaint to take years to resolve, and we anticipate similar complaints from other attorneys general in the future. It is part and parcel of the deep subprime lending business. Our research indicates that Credit Acceptance rigorously follows all existing lending laws, although enforcement agencies may attempt to broaden the interpretation of existing laws through litigation.',
#  'At the current share price, Credit Acceptance trades for approximately 8x expected EPS for 2023. We consider this an attractive price for a business that generates industry-leading returns through conservative underwriting, has reasonable prospects for growth and is run by a highly disciplined and extremely shareholder-friendly management team that has bought back over a third of outstanding shares over the past five years.',
#  'What we see here is a collection of very high-quality businesses that, again, collectively comprised 61.2% of Sequoia’s capital at year-end, that were generally purchased at attractive prices, and that are in the aggregate performing in-line with our high expectations. Over the period from pre-pandemic 2019 to 2022, this sub-portfolio increased its EPS at a compound annual rate of approximately 18%. Over this period, all ten businesses compounded EPS at a rate greater than 10%, and four of the ten did so at a rate greater than 20%. These businesses aren’t just good. They’re also growing profits quickly.',
#  'Of course, what matters is what happens from here. According to our calculations, this group of ten businesses currently trades for approximately 18x expected EPS for 2023. Like all businesses, each of these ten business faces its own set of opportunities and challenges. It is a near-certainty that some of them will perform below our expectations, while others will exceed them. But if in the aggregate they perform as we expect them to, the multiple of expected EPS for this sub-portfolio drops to approximately 12x looking out just three years.',
#  'In the long run, investment performance is all about the numbers. However, great track records aren’t built by spreadsheet alone. The qualitative matters immensely. When we look at these ten holdings as well as the rest of our holdings in a holistic manner, taking into account competitive position, operational prowess and likely earnings growth, we are excited by what we see.',
#  'The next generation of talent is the lifeblood of our investment team, which now numbers nearly thirty. This impressive group of individuals continues to grow and mature, as exemplified by our colleague Matt Cooper. Matt joined us in 2017 as a summer intern from Columbia University and quickly emerged as a valuable contributor to the firm’s investment activities. His creativity, incisiveness, and sound judgment are an enormous asset to the firm. To that end, we are delighted to announce that Matt was elected partner at the end of last year.',
#  None,
#  'Sincerely,',
#  'The Ruane Cunniff Investment Committee',
#  'Arman Gokgol-Kline | John Harris | Trevor Magyar | D. Chase Sheridan',
#  None,
#  None,
#  'Past performance does not guarantee future results.',
#  'Actual performance may vary in a client account due to account size, client-specific guidelines or restrictions, tax considerations, cash flows into and out of the account, the timing of transactions and other factors.',
#  'The S&P 500 Index is an unmanaged capitalization-weighted index of the common stocks of 500 major U.S. companies. The Index does not incur expenses. It is not possible to invest directly in the Index.',
#  None,
#  'Charles Schwab Corp.',
#  '7.4%',
#  'Liberty Media Corp.',
#  '6.9%',
#  'UnitedHealth Group, Inc.',
#  '6.8%',
#  'Universal Music Group NV',
#  '6.4%',
#  'Intercontinental Exchange, Inc.',
#  '6.2%',
#  'Eurofins Scientific SE',
#  '6.1%',
#  'Alphabet, Inc.',
#  '5.8%',
#  'Constellation Software, Inc.',
#  '5.8%',
#  'Elevance Health, Inc.',
#  '5.1%',
#  'Credit Acceptance Corp.',
#  '4.7%',
#  '* The holdings are those of a representative account that RCG believes closely reflects the Sequoia investment strategy. Client account holdings may differ from those of the representative account due to account size, client-specific guidelines or restrictions, tax considerations and other factors. The representative account’s holdings are subject to change and are not recommendations to buy or sell any security. The percentages are of total net assets.',
#  'The information herein reflects RCG’s views as of the date of this letter, and RCG’s views are subject to change without notice. RCG does not guarantee that any forecast, projection or opinion in this letter will be realized. This letter is provided for informational purposes only, and the information herein is not intended, and should not be construed, as investment advice or an offer or solicitation for the purchase or sale of any security.',
#  'References to specific securities should not be considered recommendations to purchase or sell such securities. RCG and its affiliates may have positions in, and may effect transactions in, the markets, sectors and securities discussed herein.',
#  'All investments involve risk and may lose value. Investments are subject to market risk, which is the risk that the market value of an investment will decline, perhaps sharply and unpredictably, or fail to rise, for various reasons including changes or potential or perceived changes in U.S. or foreign economies, financial markets, interest rates, the liquidity of investments and other factors. For a further discussion of risks, please see RCG’s Form ADV Brochure and refer to Item 8.',
#  'Certain statements herein are “forward looking statements.” Such forward-looking statements are subject to risks, uncertainties and other factors that could cause actual results to differ materially from future results expressed or implied by such forward-looking statements. RCG cautions readers to carefully consider such factors. Further, such forward-looking statements speak only as of the date on which such statements are made; RCG undertakes no obligation to update any forward-looking statements to reflect events or circumstances after the date of such statements.',
#  'This letter may not be reproduced in whole or in part in any form, or referred to in any publication, without the express written permission of RCG.',
#  'Original Post',
#  None,
#  "Editor's Note: This article discusses one or more securities that do not trade on a major U.S. exchange. Please be aware of the risks associated with these stocks.",
#  'This article was written by']

# %%
import nltk
newslist=[]
newslist = web_scraping_module.newsletter()

# %%
import re
from nltk.tokenize import word_tokenize

new_newsletter = []

for sentence in newslist:
    # Tokenize the sentence into words
    words = word_tokenize(sentence)
    # Remove words that contain digits
    filtered_words = [word for word in words if not re.search('\d', word)]
    # Append the filtered words to the list of new sentences
    new_newsletter.append(filtered_words)

new_newsletter
# Out:
# <>:10: DeprecationWarning: invalid escape sequence \d
# <>:10: DeprecationWarning: invalid escape sequence \d
# <ipython-input-18-5fac3dff505b>:10: DeprecationWarning: invalid escape sequence \d
#   filtered_words = [word for word in words if not re.search('\d', word)]
# [[],
#  ['aims',
#   'to',
#   'make',
#   'healthcare',
#   'accessible',
#   ',',
#   'understandable',
#   ',',
#   'and',
#   'affordable',
#   'for',
#   'all',
#   'Indians',
#   '.',
#   'It',
#   'offers',
#   'ePharmacy',
#   ',',
#   'eDiagnostics',
#   ',',
#   'and',
#   'health',
#   'information',
#   'to',
#   'enable',
#   'consumers',
#   'to',
#   'better',
#   'manage',
#   'their',
#   'health',
#   '.'],
#  ['Seconds'],
#  ['Seconds',
#   'is',
#   'the',
#   'world',
#   '’',
#   's',
#   'leading',
#   'cloud',
#   'video',
#   'production',
#   'platform',
#   ',',
#   'allowing',
#   'brands',
#   'to',
#   'purchase',
#   ',',
#   'plan',
#   ',',
#   'shoot',
#   ',',
#   'edit',
#   'and',
#   'review',
#   'video',
#   'anywhere',
#   'in',
#   'the',
#   'world',
#   ',',
#   'online',
#   'and',
#   'on',
#   'mobile',
#   '.'],
#  [],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'fastest-growing',
#   'property',
#   'search',
#   'companies',
#   'in',
#   'Southeast',
#   'Asia',
#   '.'],
#  ['Absolute', 'Foods'],
#  ['Absolute',
#   'Foods',
#   'intersects',
#   'technology',
#   ',',
#   'science',
#   ',',
#   'and',
#   'agriculture',
#   'to',
#   'go',
#   'beyond',
#   'organic',
#   'food',
#   '–',
#   'focusing',
#   'on',
#   'produce',
#   'that',
#   'is',
#   '%',
#   'natural',
#   'and',
#   'Non-GMO',
#   '.'],
#  ['Aerotime'],
#  ['Aerotime',
#   'helps',
#   'users',
#   'work',
#   'in',
#   'flow',
#   'state',
#   'by',
#   'streamlining',
#   'meetings',
#   'and',
#   'making',
#   'it',
#   'easier',
#   'to',
#   'prioritize',
#   'tasks',
#   '.'],
#  ['AI', 'Rudder'],
#  ['AI',
#   'Rudder',
#   'aims',
#   'to',
#   'increase',
#   'the',
#   'scale',
#   ',',
#   'speed',
#   'and',
#   'quality',
#   'of',
#   'customer',
#   'experience',
#   'with',
#   'a',
#   'human-like',
#   'AI',
#   'voice',
#   'assistant',
#   '.'],
#  ['Airmeet'],
#  ['Airmeet',
#   'is',
#   'the',
#   'fastest',
#   'growing',
#   'platform',
#   'for',
#   'hosting',
#   'a',
#   'rich',
#   'variety',
#   'of',
#   'online',
#   'events',
#   'by',
#   'crafting',
#   'a',
#   'virtual',
#   'space',
#   'for',
#   'the',
#   'world',
#   'to',
#   'connect',
#   'and',
#   'collaborate',
#   '.'],
#  ['Akulaku'],
#  ['Akulaku',
#   'is',
#   'a',
#   'Southeast',
#   'Asian',
#   'e-commerce',
#   'platform',
#   'that',
#   'allows',
#   'consumers',
#   'to',
#   'pay',
#   'for',
#   'products',
#   'in',
#   'instalments',
#   'without',
#   'a',
#   'credit',
#   'card',
#   '.'],
#  ['Akumentis', 'Healthcare'],
#  ['Akumentis',
#   'Healthcare',
#   'is',
#   'one',
#   'of',
#   'the',
#   'fastest-growing',
#   'branded',
#   'generics',
#   'companies',
#   'in',
#   'India',
#   '.',
#   'It',
#   'has',
#   'a',
#   'presence',
#   'across',
#   'multiple',
#   'therapeutic',
#   'areas',
#   'and',
#   'holds',
#   'a',
#   'strong',
#   'market',
#   'position',
#   'in',
#   'women',
#   '’',
#   's',
#   'health',
#   '.'],
#  ['Animall'],
#  ['Animall',
#   'aims',
#   'to',
#   'improve',
#   'the',
#   'lives',
#   'of',
#   'dairy',
#   'farmers',
#   'in',
#   'a',
#   'meaningful',
#   'way',
#   'by',
#   'making',
#   'dairy',
#   'farming',
#   'significantly',
#   'more',
#   'profitable',
#   '.'],
#  ['Apna'],
#  ['Apna',
#   'is',
#   'a',
#   'platform',
#   'that',
#   'creates',
#   'better',
#   'economic',
#   'opportunities',
#   'for',
#   'the',
#   'blue/grey',
#   'collar',
#   'workforce',
#   'globally',
#   '.'],
#  ['Appier'],
#  ['Appier',
#   'builds',
#   'AI-based',
#   'cross-screen',
#   'analytics',
#   'and',
#   'targeting',
#   'platforms',
#   'for',
#   'businesses',
#   'to',
#   'reach',
#   'and',
#   'engage',
#   'customers',
#   'across',
#   'multiple',
#   'smart',
#   'devices',
#   '.'],
#  ['Aptus'],
#  ['Aptus',
#   'Value',
#   'Housing',
#   'Finance',
#   'India',
#   'Ltd',
#   'is',
#   'a',
#   'home',
#   'loan',
#   'company',
#   'that',
#   'addresses',
#   'the',
#   'housing',
#   'finance',
#   'needs',
#   'of',
#   'self-employed',
#   'individuals',
#   'belonging',
#   'to',
#   'low',
#   'and',
#   'middle-income',
#   'families',
#   'from',
#   'semi-urban',
#   'and',
#   'rural',
#   'markets',
#   '.'],
#  ['Arbo', 'Works'],
#  ['Arbo',
#   'Works',
#   'is',
#   'determined',
#   'to',
#   'help',
#   'people',
#   'enjoy',
#   'more',
#   'successful',
#   'financial',
#   'lives',
#   '.'],
#  ['Arrow'],
#  ['Arrow',
#   'is',
#   'a',
#   'Singapore-based',
#   'eCommerce',
#   'solution',
#   'that',
#   'partners',
#   'with',
#   'merchants',
#   'to',
#   'create',
#   'a',
#   'fast',
#   'and',
#   'frictionless',
#   'checkout',
#   'experience',
#   'for',
#   'consumers',
#   '–',
#   'regardless',
#   'of',
#   'their',
#   'location',
#   'or',
#   'the',
#   'channel',
#   'they',
#   'are',
#   'buying',
#   'on',
#   '.'],
#  ['Aspire'],
#  ['Aspire',
#   'is',
#   'the',
#   'all-in-one',
#   'finance',
#   'operating',
#   'system',
#   'for',
#   'growing',
#   'businesses',
#   ',',
#   'helping',
#   'companies',
#   'pay',
#   ',',
#   'manage',
#   ',',
#   'and',
#   'earn',
#   'smarter',
#   '.'],
#  ['Astro'],
#  ['Astro',
#   'is',
#   'Indonesia',
#   '’',
#   's',
#   'first',
#   'and',
#   'fastest-growing',
#   'on-demand',
#   'platform',
#   'for',
#   'groceries',
#   'and',
#   'essentials',
#   '.'],
#  ['Atlan'],
#  ['Atlan',
#   'is',
#   'a',
#   'modern',
#   'data',
#   'collaboration',
#   'workspace',
#   ',',
#   'enabling',
#   'teams',
#   'to',
#   'create',
#   'a',
#   'single',
#   'source',
#   'of',
#   'truth',
#   'for',
#   'all',
#   'their',
#   'data',
#   'assets',
#   ',',
#   'and',
#   'collaborate',
#   'across',
#   'the',
#   'modern',
#   'data',
#   'stack',
#   '.'],
#  ['Avataar'],
#  ['Avataar',
#   'is',
#   'a',
#   'AI',
#   'company',
#   'that',
#   'helps',
#   'large',
#   'enterprise',
#   'customers',
#   'create',
#   'immersive',
#   'and',
#   'interactive',
#   'shopping',
#   'experiences',
#   'for',
#   'their',
#   'end',
#   'consumers',
#   '.'],
#  ['Awfis'],
#  ['Awfis',
#   'is',
#   'one',
#   'of',
#   'South',
#   'Asia',
#   '’',
#   's',
#   'largest',
#   'networks',
#   'of',
#   'collaborative',
#   'co-working',
#   'spaces',
#   '.'],
#  ['Band', 'Protocol'],
#  ['Band',
#   'Protocol',
#   'is',
#   'a',
#   'cross-chain',
#   'data',
#   'oracle',
#   'platform',
#   'that',
#   'aggregates',
#   'and',
#   'connects',
#   'real-world',
#   'data',
#   'and',
#   'APIs',
#   'to',
#   'smart',
#   'contracts',
#   'by',
#   'building',
#   'a',
#   'decentralized',
#   'bridge',
#   'that',
#   'enables',
#   'secure',
#   'inter-operabilities',
#   '.'],
#  ['BankBazaar'],
#  ['BankBazaar',
#   'helps',
#   'consumers',
#   'choose',
#   'the',
#   'right',
#   'financial',
#   'product',
#   'for',
#   'their',
#   'needs',
#   '.'],
#  ['Beam'],
#  ['Beam',
#   'offers',
#   'micro-mobility',
#   'solutions',
#   'to',
#   'urban',
#   'dwellers',
#   'across',
#   'APAC',
#   '.'],
#  ['Belong'],
#  ['Belong',
#   'is',
#   'a',
#   'predictive',
#   ',',
#   'outbound',
#   'recruitment',
#   'solution',
#   'that',
#   'helps',
#   'businesses',
#   'discover',
#   ',',
#   'engage',
#   'and',
#   'hire',
#   'talented',
#   'candidates',
#   '.'],
#  ['Beta', 'Finance'],
#  ['Beta',
#   'Finance',
#   'is',
#   'a',
#   'decentralized',
#   'finance',
#   'protocol',
#   'that',
#   'has',
#   'developed',
#   'a',
#   'one-click',
#   'solution',
#   'for',
#   'lending',
#   ',',
#   'borrowing',
#   'and',
#   'shorting',
#   'of',
#   'any',
#   'crypto',
#   'asset',
#   '.'],
#  ['BharatPe'],
#  ['BharatPe',
#   'is',
#   'a',
#   'FinTech',
#   'company',
#   'that',
#   'empowers',
#   'Indian',
#   'merchants',
#   'to',
#   'accept',
#   'UPI',
#   'payments',
#   'from',
#   'their',
#   'customers',
#   'for',
#   'free',
#   'through',
#   'the',
#   'BharatPe',
#   'QR',
#   '.'],
#  ['Bibit'],
#  ['Bibit',
#   'is',
#   'a',
#   'digital',
#   'investing',
#   'app',
#   'with',
#   'a',
#   'robo-advisory',
#   'service',
#   'that',
#   'helps',
#   'first-time',
#   'investors',
#   'invest',
#   'in',
#   'mutual',
#   'fund',
#   'products',
#   '.'],
#  ['Bifrost'],
#  ['Bifrost',
#   'replaces',
#   'the',
#   'tedious',
#   'process',
#   'of',
#   'data',
#   'collection',
#   ',',
#   'curation',
#   ',',
#   '&',
#   'labelling',
#   'by',
#   'generating',
#   'physically-accurate',
#   'worlds',
#   '&',
#   'capturing',
#   'perfectly',
#   'labelled',
#   'datasets',
#   '.'],
#  ['Bijnis'],
#  ['Bijnis',
#   'is',
#   'revolutionising',
#   'unorganised',
#   'manufacturing',
#   'industries',
#   'by',
#   'digitising',
#   'factories',
#   '.',
#   'Its',
#   'goal',
#   'is',
#   'to',
#   'make',
#   'the',
#   'factory',
#   'smarter',
#   ',',
#   'faster',
#   'and',
#   'cost',
#   'effective',
#   'that',
#   'will',
#   'enable',
#   'factory',
#   'owners',
#   'to',
#   'scale',
#   '&',
#   'grow',
#   'their',
#   'business',
#   '.'],
#  ['Bikayi'],
#  ['Bikayi',
#   'empowers',
#   'entrepreneurs',
#   'to',
#   'build',
#   'their',
#   'online',
#   'businesses',
#   'by',
#   'creating',
#   'an',
#   'online',
#   'store',
#   'with',
#   'a',
#   'fully',
#   'customizable',
#   'e-commerce',
#   'website',
#   'in',
#   'less',
#   'than',
#   'seconds',
#   '.'],
#  ['Biofourmis'],
#  ['Biofourmis',
#   'develops',
#   'and',
#   'delivers',
#   'clinically',
#   'validated',
#   'software-based',
#   'therapeutics',
#   '.'],
#  ['Bira'],
#  ['Beverages',
#   'is',
#   'a',
#   'fast-growing',
#   'craft',
#   'beer',
#   'brand',
#   ',',
#   'available',
#   'in',
#   'draft',
#   'and',
#   'bottle',
#   'formats',
#   '.']]

# %%
list_of_simple_preprocess_data = []
for i in list_of_sentence:
    list_of_simple_preprocess_data.append(gensim.utils.simple_preprocess(i, deacc=True, min_len=3))

list_of_simple_preprocess_data1 = []
for i in list_of_sentence1:
    list_of_simple_preprocess_data1.append(gensim.utils.simple_preprocess(i, deacc=True, min_len=3))

list_of_simple_preprocess_data2 = []
for i in list_of_sentence2:
    list_of_simple_preprocess_data2.append(gensim.utils.simple_preprocess(i, deacc=True, min_len=3))

list_of_simple_preprocess_data3 = []
for i in list_of_sentence3:
    list_of_simple_preprocess_data3.append(gensim.utils.simple_preprocess(i, deacc=True, min_len=3))

# %%
texts = list_of_simple_preprocess_data
texts1 = list_of_simple_preprocess_data1
texts2 = list_of_simple_preprocess_data2
texts3 = list_of_simple_preprocess_data3

# %%
texts
# Out:
# [['amendment',
#   'agreement',
#   'name',
#   'this',
#   'amendment',
#   'the',
#   'agreement',
#   'name',
#   'dated',
#   'effective',
#   'date',
#   'agreement',
#   'the',
#   'agreement',
#   'made',
#   'amendment',
#   'effective',
#   'date',
#   'between',
#   'party',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'with',
#   'its',
#   'principal',
#   'place',
#   'business',
#   'party',
#   'address',
#   'the',
#   'party',
#   'abbreviation',
#   'and',
#   'party',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'with',
#   'its',
#   'principal',
#   'place',
#   'business',
#   'party',
#   'address',
#   'the',
#   'party',
#   'abbreviation'],
#  [],
#  ['capitalized', 'terms'],
#  ['unless',
#   'otherwise',
#   'defined',
#   'this',
#   'amendment',
#   'capitalized',
#   'terms',
#   'used',
#   'this',
#   'amendment',
#   'will',
#   'have',
#   'the',
#   'same',
#   'meaning',
#   'they',
#   'the',
#   'agreement'],
#  [],
#  ['substance', 'amendment'],
#  ['the',
#   'parties',
#   'hereby',
#   'amend',
#   'the',
#   'agreement',
#   'follows',
#   'list',
#   'the',
#   'changes',
#   'additions',
#   'deletions',
#   'etc'],
#  ['made', 'the', 'underlying', 'agreement'],
#  ['continuing', 'effect'],
#  ['except',
#   'listed',
#   'section',
#   'substance',
#   'amendment',
#   'the',
#   'agreement',
#   'will',
#   'unaffected',
#   'and',
#   'continue',
#   'full',
#   'force',
#   'and',
#   'effect',
#   'under',
#   'its',
#   'terms'],
#  [],
#  ['conflicting', 'amendments'],
#  ['there',
#   'any',
#   'conflict',
#   'between',
#   'the',
#   'terms',
#   'this',
#   'amendment',
#   'and',
#   'those',
#   'any',
#   'earlier',
#   'amendment',
#   'the',
#   'agreement',
#   'the',
#   'terms',
#   'this',
#   'amendment',
#   'will',
#   'control'],
#  ['this', 'agreement', 'has', 'been', 'signed', 'the', 'parties'],
#  ['party',
#   'name',
#   'party',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'title',
#   'party',
#   'signatory',
#   'title',
#   'title',
#   'party',
#   'signatory',
#   'title']]

# %%
texts1
# Out:
# [['software',
#   'license',
#   'agreement',
#   'this',
#   'software',
#   'license',
#   'agreement',
#   'made',
#   'agreement',
#   'date',
#   'between',
#   'licensor',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'with',
#   'its',
#   'principal',
#   'place',
#   'business',
#   'licensor',
#   'address',
#   'party',
#   'and',
#   'licensee',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'with',
#   'its',
#   'principal',
#   'place',
#   'business',
#   'licensee',
#   'address',
#   'party'],
#  ['the', 'parties', 'agree', 'the', 'terms', 'this', 'agreement'],
#  [],
#  ['license', 'grant', 'software', 'license'],
#  ['party',
#   'hereby',
#   'grants',
#   'party',
#   'exclusive',
#   'non',
#   'exclusive',
#   'transferable',
#   'non',
#   'transferable',
#   'sublicensable',
#   'non',
#   'sublicensable',
#   'revocable',
#   'irrevocable',
#   'license',
#   'the',
#   'deliverable',
#   'use',
#   'the',
#   'software'],
#  ['other', 'rights'],
#  ['party',
#   'reserves',
#   'for',
#   'itself',
#   'all',
#   'other',
#   'rights',
#   'and',
#   'interest',
#   'not',
#   'explicitly',
#   'granted',
#   'under',
#   'this',
#   'agreement'],
#  ['software'],
#  ['software',
#   'means',
#   'short',
#   'description',
#   'software',
#   'the',
#   'software',
#   'described',
#   'the',
#   'attachment',
#   'attached',
#   'this',
#   'agreement'],
#  [],
#  ['make', 'software', 'available', 'for', 'download'],
#  ['the',
#   'later',
#   'the',
#   'effective',
#   'date',
#   'and',
#   'party',
#   'first',
#   'payment',
#   'for',
#   'the',
#   'software',
#   'party',
#   'will',
#   'make',
#   'the',
#   'software',
#   'available',
#   'party',
#   'electronic',
#   'downloadable',
#   'format',
#   'from',
#   'party',
#   'website',
#   'insert',
#   'url',
#   'website'],
#  [],
#  ['training', 'and', 'support', 'services', 'training'],
#  ['party',
#   'shall',
#   'party',
#   'expense',
#   'provide',
#   'party',
#   'employees',
#   'with',
#   'the',
#   'initial',
#   'training',
#   'services',
#   'necessary',
#   'and',
#   'desirable',
#   'operate',
#   'the',
#   'software',
#   'further',
#   'described',
#   'the',
#   'attachment',
#   'attached',
#   'this',
#   'agreement',
#   'party',
#   'offices',
#   'and',
#   'days',
#   'and',
#   'times',
#   'the',
#   'parties',
#   'agree',
#   'writing'],
#  ['support'],
#  ['initial', 'support'],
#  ['for',
#   'the',
#   'month',
#   'period',
#   'beginning',
#   'the',
#   'effective',
#   'date',
#   'and',
#   'party',
#   'own',
#   'expense',
#   'party',
#   'shall',
#   'provide',
#   'party',
#   'with',
#   'telephone',
#   'electronic',
#   'support',
#   'during',
#   'party',
#   'normal',
#   'business',
#   'hours',
#   'order',
#   'help',
#   'party',
#   'locate',
#   'and',
#   'correct',
#   'problems',
#   'with',
#   'the',
#   'software',
#   'and'],
#  ['internet',
#   'based',
#   'support',
#   'system',
#   'generally',
#   'available',
#   'seven',
#   'days',
#   'week',
#   'twenty',
#   'four',
#   'hours',
#   'day'],
#  [],
#  ['renewed', 'support'],
#  ['after',
#   'the',
#   'initial',
#   'month',
#   'support',
#   'period',
#   'party',
#   'may',
#   'elect',
#   'renew',
#   'party',
#   'support',
#   'services',
#   'under',
#   'this',
#   'paragraph',
#   'support',
#   'for',
#   'additional',
#   'month',
#   'periods',
#   'party',
#   'then',
#   'current',
#   'service',
#   'rates'],
#  [],
#  ['updates', 'and', 'maintenance', 'services', 'updates'],
#  ['party',
#   'shall',
#   'provide',
#   'party',
#   'party',
#   'sole',
#   'expense',
#   'with',
#   'all',
#   'updates',
#   'extensions',
#   'enhancement',
#   'modifications',
#   'and',
#   'other',
#   'changes',
#   'party',
#   'makes',
#   'adds',
#   'the',
#   'software',
#   'and',
#   'which',
#   'party',
#   'offers',
#   'other',
#   'licensees',
#   'the',
#   'software'],
#  ['fixes', 'and', 'patches'],
#  ['party',
#   'shall',
#   'provide',
#   'party',
#   'party',
#   'sole',
#   'expense',
#   'with',
#   'bug',
#   'fixes',
#   'and',
#   'code',
#   'corrections',
#   'correct',
#   'software',
#   'malfunctions',
#   'and',
#   'defects',
#   'order',
#   'bring',
#   'the',
#   'software',
#   'into',
#   'substantial',
#   'conformity',
#   'with',
#   'its',
#   'operating',
#   'specifications'],
#  ['exceptions'],
#  ['party',
#   'may',
#   'but',
#   'will',
#   'not',
#   'required',
#   'provide',
#   'these',
#   'maintenance',
#   'services',
#   'party',
#   'has',
#   'modified',
#   'the',
#   'software',
#   'default'],
#  [],
#  ['license', 'fees'],
#  ['party',
#   'will',
#   'pay',
#   'party',
#   'the',
#   'license',
#   'fee',
#   'license',
#   'fee',
#   'listed',
#   'attachment',
#   'the',
#   'license',
#   'fee'],
#  [],
#  ['license', 'fees', 'license', 'fee', 'paid', 'full'],
#  ['party',
#   'will',
#   'pay',
#   'the',
#   'license',
#   'fee',
#   'party',
#   'full',
#   'due',
#   'date',
#   'month',
#   'immediately',
#   'available',
#   'funds',
#   'and',
#   'the',
#   'account',
#   'party',
#   'lists',
#   'immediately',
#   'below',
#   'account',
#   'number',
#   'routing',
#   'number'],
#  ['taxes'],
#  ['payment',
#   'amounts',
#   'under',
#   'this',
#   'agreement',
#   'not',
#   'include',
#   'taxes'],
#  ['party',
#   'will',
#   'pay',
#   'all',
#   'taxes',
#   'applicable',
#   'payments',
#   'between',
#   'the',
#   'parties',
#   'under',
#   'this',
#   'agreement'],
#  [],
#  ['interest', 'late', 'payments'],
#  ['any',
#   'amount',
#   'not',
#   'paid',
#   'when',
#   'due',
#   'will',
#   'bear',
#   'interest',
#   'from',
#   'the',
#   'due',
#   'date',
#   'until',
#   'paid',
#   'rate',
#   'equal',
#   'per',
#   'month',
#   'annually',
#   'the',
#   'maximum',
#   'allowed',
#   'law',
#   'whichever',
#   'less'],
#  [],
#  ['user', 'obligations', 'hardware', 'obligations'],
#  ['party',
#   'shall',
#   'responsible',
#   'for',
#   'obtaining',
#   'and',
#   'maintaining',
#   'all',
#   'computer',
#   'hardware',
#   'software',
#   'and',
#   'communications',
#   'equipment',
#   'needed',
#   'internally',
#   'access',
#   'the',
#   'service',
#   'and',
#   'paying',
#   'all',
#   'third',
#   'party',
#   'access',
#   'charges',
#   'incurred',
#   'while',
#   'using',
#   'the',
#   'service'],
#  ['anti', 'virus', 'obligations'],
#  ['party',
#   'shall',
#   'responsible',
#   'for',
#   'implementing',
#   'maintaining',
#   'and',
#   'updating',
#   'all',
#   'necessary',
#   'and',
#   'proper',
#   'procedures',
#   'and',
#   'software',
#   'for',
#   'safeguarding',
#   'against',
#   'computer',
#   'infection',
#   'viruses',
#   'worms',
#   'trojan',
#   'horses',
#   'and',
#   'other',
#   'code',
#   'that',
#   'manifest',
#   'contaminating',
#   'destructive',
#   'properties',
#   'collectively',
#   'viruses'],
#  ['party', 'use', 'services'],
#  ['party',
#   'shall',
#   'abide',
#   'all',
#   'local',
#   'and',
#   'international',
#   'laws',
#   'and',
#   'regulations',
#   'applicable',
#   'its',
#   'use',
#   'the',
#   'service',
#   'use',
#   'the',
#   'service',
#   'only',
#   'for',
#   'legal',
#   'purposes',
#   'and',
#   'comply',
#   'with',
#   'all',
#   'regulations',
#   'policies',
#   'and',
#   'procedures',
#   'networks',
#   'connected',
#   'the',
#   'service'],
#  [],
#  ['restricted', 'uses'],
#  ['party',
#   'will',
#   'not',
#   'distribute',
#   'license',
#   'loan',
#   'sell',
#   'the',
#   'software',
#   'other',
#   'content',
#   'that',
#   'contained',
#   'displayed',
#   'modify',
#   'alter',
#   'create',
#   'any',
#   'derivative',
#   'works',
#   'from',
#   'the',
#   'software',
#   'reverse',
#   'engineer',
#   'decompile',
#   'decode',
#   'decrypt',
#   'disassemble',
#   'derive',
#   'any',
#   'source',
#   'code',
#   'from',
#   'the',
#   'software',
#   'remove',
#   'alter',
#   'obscure',
#   'any',
#   'copyright',
#   'trademark',
#   'other',
#   'proprietary',
#   'rights',
#   'notice',
#   'the',
#   'software'],
#  [],
#  ['permitted', 'uses', 'installation'],
#  ['party',
#   'may',
#   'install',
#   'and',
#   'use',
#   'the',
#   'software',
#   'solely',
#   'for',
#   'personal',
#   'noncommercial',
#   'internal',
#   'business',
#   'use'],
#  ['evaluation', 'use'],
#  ['party',
#   'has',
#   'ordered',
#   'evaluation',
#   'license',
#   'party',
#   'may',
#   'use',
#   'the',
#   'software',
#   'only',
#   'for',
#   'evaluation',
#   'purposes',
#   'and',
#   'only',
#   'during',
#   'the',
#   'applicable',
#   'evaluation',
#   'period'],
#  ['server', 'deployment'],
#  ['party',
#   'may',
#   'install',
#   'number',
#   'server',
#   'copies',
#   'copies',
#   'the',
#   'software',
#   'internal',
#   'file',
#   'server',
#   'for',
#   'purposes',
#   'downloading',
#   'and',
#   'installing',
#   'the',
#   'software',
#   'licensed',
#   'computers',
#   'within',
#   'the',
#   'same',
#   'internal',
#   'network'],
#  ['home', 'use'],
#  ['party',
#   'may',
#   'install',
#   'copy',
#   'the',
#   'software',
#   'personal',
#   'home',
#   'computer',
#   'provided',
#   'both',
#   'copies',
#   'the',
#   'software',
#   'are',
#   'not',
#   'used',
#   'the',
#   'same',
#   'time'],
#  ['backup', 'and', 'archival', 'copies'],
#  ['party',
#   'may',
#   'make',
#   'one',
#   'copy',
#   'the',
#   'software',
#   'solely',
#   'for',
#   'backup',
#   'archival',
#   'purposes'],
#  [],
#  ['term'],
#  ['this',
#   'agreement',
#   'begins',
#   'the',
#   'effective',
#   'date',
#   'date',
#   'month',
#   'and',
#   'will',
#   'continue',
#   'until',
#   'terminated',
#   'the',
#   'term'],
#  [],
#  ['representations', 'mutual', 'representations'],
#  ['existence'],
#  ['the',
#   'parties',
#   'are',
#   'corporations',
#   'incorporated',
#   'and',
#   'existing',
#   'under',
#   'the',
#   'laws',
#   'the',
#   'jurisdictions',
#   'their',
#   'respective',
#   'incorporation'],
#  [],
#  ['authority', 'and', 'capacity'],
#  ['the',
#   'parties',
#   'have',
#   'the',
#   'authority',
#   'and',
#   'capacity',
#   'enter',
#   'into',
#   'this',
#   'agreement'],
#  ['execution', 'and', 'delivery'],
#  ['the',
#   'parties',
#   'have',
#   'duly',
#   'executed',
#   'and',
#   'delivered',
#   'this',
#   'agreement'],
#  ['enforceability'],
#  ['this',
#   'agreement',
#   'constitutes',
#   'legal',
#   'valid',
#   'and',
#   'binding',
#   'obligation',
#   'enforceable',
#   'against',
#   'the',
#   'parties',
#   'according',
#   'its',
#   'terms'],
#  ['conflicts'],
#  ['neither',
#   'party',
#   'under',
#   'any',
#   'restriction',
#   'obligation',
#   'that',
#   'the',
#   'party',
#   'could',
#   'reasonably',
#   'expect',
#   'might',
#   'affect',
#   'the',
#   'party',
#   'performance',
#   'its',
#   'obligations',
#   'under',
#   'this',
#   'agreement'],
#  ['breach'],
#  ['neither',
#   'party',
#   'execution',
#   'delivery',
#   'performance',
#   'its',
#   'obligations',
#   'under',
#   'this',
#   'agreement',
#   'will',
#   'breach',
#   'result',
#   'default',
#   'under',
#   'its',
#   'articles',
#   'bylaws',
#   'any',
#   'unanimous',
#   'shareholders',
#   'agreement'],
#  ['any', 'law', 'which', 'subject', 'iii'],
#  ['any',
#   'judgment',
#   'order',
#   'decree',
#   'any',
#   'governmental',
#   'authority',
#   'which',
#   'subject'],
#  ['any', 'agreement', 'which', 'party', 'which', 'bound'],
#  ['permits', 'consents', 'and', 'other', 'authorizations'],
#  ['each',
#   'party',
#   'holds',
#   'all',
#   'permits',
#   'and',
#   'other',
#   'authorizations',
#   'necessary',
#   'own',
#   'lease',
#   'and',
#   'operate',
#   'its',
#   'properties',
#   'and'],
#  ['conduct', 'its', 'business', 'now', 'carried'],
#  ['disputes', 'proceedings'],
#  ['except',
#   'disclosed',
#   'the',
#   'parties',
#   'respective',
#   'disclosure',
#   'schedules',
#   'there',
#   'are',
#   'legal',
#   'proceedings',
#   'pending',
#   'threatened',
#   'foreseeable',
#   'against',
#   'either',
#   'party',
#   'which',
#   'would',
#   'affect',
#   'that',
#   'party',
#   'ability',
#   'complete',
#   'its',
#   'obligations',
#   'under',
#   'this',
#   'agreement'],
#  [],
#  ['bankruptcy'],
#  ['neither',
#   'party',
#   'has',
#   'taken',
#   'authorized',
#   'any',
#   'proceedings',
#   'related',
#   'that',
#   'party',
#   'bankruptcy',
#   'insolvency',
#   'liquidation',
#   'dissolution',
#   'winding'],
#  ['party', 'representations'],
#  ['disclosure', 'schedule'],
#  ['party',
#   'disclosure',
#   'schedule',
#   'lists',
#   'any',
#   'exceptions',
#   'its',
#   'representations'],
#  [],
#  ['ownership', 'intellectual', 'property'],
#  ['except',
#   'disclosed',
#   'party',
#   'disclosure',
#   'schedule',
#   'party',
#   'the',
#   'owner',
#   'all',
#   'intellectual',
#   'property',
#   'rights',
#   'included',
#   'the',
#   'software',
#   'and',
#   'granted',
#   'under',
#   'the',
#   'deliverable',
#   'and'],
#  ['has', 'the', 'exclusive', 'right', 'grant', 'the', 'deliverable'],
#  ['maintenance', 'intellectual', 'property'],
#  ['party',
#   'has',
#   'properly',
#   'maintained',
#   'all',
#   'its',
#   'intellectual',
#   'property',
#   'rights',
#   'licensed',
#   'under',
#   'the',
#   'deliverable',
#   'including',
#   'paying',
#   'all',
#   'applicable',
#   'registration',
#   'and',
#   'maintenance',
#   'fees'],
#  ['prior', 'grant', 'transfer'],
#  ['party',
#   'has',
#   'not',
#   'granted',
#   'and',
#   'not',
#   'obligated',
#   'grant',
#   'any',
#   'license',
#   'any',
#   'third',
#   'party',
#   'that',
#   'would',
#   'conflict',
#   'with',
#   'the',
#   'deliverable',
#   'under',
#   'this',
#   'agreement',
#   'infringement'],
#  ['party',
#   'knowledge',
#   'the',
#   'software',
#   'does',
#   'not',
#   'infringe',
#   'the',
#   'intellectual',
#   'property',
#   'rights',
#   'other',
#   'rights',
#   'any',
#   'third',
#   'party'],
#  ['third', 'party', 'infringement'],
#  ['except',
#   'disclosed',
#   'party',
#   'disclosure',
#   'schedule',
#   'party',
#   'knowledge',
#   'third',
#   'party',
#   'infringing',
#   'its',
#   'intellectual',
#   'property',
#   'rights',
#   'the',
#   'software'],
#  ['not', 'public', 'domain'],
#  ['the', 'software', 'not', 'the', 'public', 'domain'],
#  [],
#  ['warranty'],
#  ['the',
#   'licensed',
#   'software',
#   'provided',
#   'with',
#   'all',
#   'faults',
#   'defects',
#   'bugs',
#   'and',
#   'errors'],
#  ['warranty'],
#  ['unless', 'otherwise', 'listed', 'this', 'agreement'],
#  ['party',
#   'does',
#   'not',
#   'make',
#   'any',
#   'warranty',
#   'regarding',
#   'the',
#   'licensed',
#   'software',
#   'which',
#   'includes',
#   'that'],
#  ['party',
#   'disclaims',
#   'the',
#   'fullest',
#   'extent',
#   'authorized',
#   'law',
#   'any',
#   'and',
#   'all',
#   'other',
#   'warranties',
#   'whether',
#   'express',
#   'implied',
#   'including',
#   'any',
#   'implied',
#   'warranties',
#   'title',
#   'non',
#   'infringement',
#   'quiet',
#   'enjoyment',
#   'integration',
#   'merchantability',
#   'fitness',
#   'for',
#   'particular',
#   'purpose'],
#  [],
#  ['intellectual', 'property'],
#  ['party',
#   'will',
#   'retain',
#   'exclusive',
#   'interest',
#   'and',
#   'ownership',
#   'its',
#   'intellectual',
#   'property',
#   'rights',
#   'and',
#   'the',
#   'software',
#   'and',
#   'expressly',
#   'reserves',
#   'all',
#   'rights',
#   'not',
#   'expressly',
#   'granted',
#   'under',
#   'this',
#   'agreement'],
#  [],
#  ['government', 'end', 'users', 'commercial', 'software'],
#  ['licensed',
#   'software',
#   'and',
#   'related',
#   'documentation',
#   'are',
#   'supplied',
#   'purchased',
#   'behalf',
#   'the',
#   'united',
#   'states',
#   'government',
#   'that',
#   'licensed',
#   'software',
#   'will',
#   'deemed',
#   'commercial',
#   'software',
#   'that',
#   'term',
#   'used',
#   'the',
#   'federal',
#   'acquisition',
#   'regulation',
#   'system',
#   'and',
#   'the',
#   'rights',
#   'the',
#   'united',
#   'states',
#   'will',
#   'not',
#   'exceed',
#   'the',
#   'minimum',
#   'rights',
#   'listed',
#   'far',
#   'for',
#   'restricted',
#   'computer',
#   'software'],
#  ['all', 'other', 'terms', 'apply'],
#  ['all',
#   'other',
#   'terms',
#   'and',
#   'conditions',
#   'this',
#   'agreement',
#   'otherwise',
#   'apply'],
#  [],
#  ['party', 'data', 'collect', 'and', 'use', 'data'],
#  ['party',
#   'may',
#   'collect',
#   'and',
#   'use',
#   'technical',
#   'information',
#   'gathered',
#   'part',
#   'its',
#   'maintenance',
#   'support',
#   'and',
#   'training',
#   'services',
#   'only',
#   'for',
#   'the',
#   'purpose',
#   'improving',
#   'its',
#   'products',
#   'and',
#   'services'],
#  ['non', 'disclosure'],
#  ['party',
#   'will',
#   'not',
#   'disclose',
#   'this',
#   'any',
#   'this',
#   'information',
#   'form',
#   'that',
#   'personally',
#   'identifies',
#   'party',
#   'party',
#   'clients'],
#  [],
#  ['compliance', 'with', 'laws'],
#  ['each',
#   'party',
#   'will',
#   'comply',
#   'with',
#   'all',
#   'applicable',
#   'laws',
#   'relating',
#   'subject',
#   'matter',
#   'agreement',
#   'and',
#   'notify',
#   'the',
#   'other',
#   'party',
#   'becomes',
#   'aware',
#   'any',
#   'non',
#   'compliance',
#   'connection',
#   'with',
#   'this',
#   'section'],
#  [],
#  ['export', 'control', 'laws'],
#  ['each',
#   'party',
#   'shall',
#   'obtain',
#   'all',
#   'permits',
#   'necessary',
#   'and',
#   'otherwise',
#   'comply',
#   'with',
#   'all',
#   'laws',
#   'export',
#   'control',
#   'applicable',
#   'this',
#   'agreement',
#   'and',
#   'all',
#   'transactions',
#   'contemplated',
#   'under',
#   'this',
#   'agreement'],
#  [],
#  ['source', 'code', 'escrow'],
#  ['party',
#   'written',
#   'request',
#   'party',
#   'shall',
#   'place',
#   'the',
#   'source',
#   'code',
#   'for',
#   'the',
#   'software',
#   'into',
#   'escrow',
#   'with',
#   'escrow',
#   'company',
#   'name',
#   'the',
#   'escrow',
#   'company',
#   'for',
#   'party',
#   'benefit',
#   'subject',
#   'party',
#   'execution',
#   'and',
#   'the',
#   'terms',
#   'and',
#   'conditions',
#   'party',
#   'standard',
#   'form',
#   'software',
#   'escrow',
#   'agreement',
#   'with',
#   'escrow',
#   'company',
#   'and',
#   'party',
#   'payment',
#   'all',
#   'applicable',
#   'escrow',
#   'fees'],
#  [],
#  ['confidentiality', 'obligations'],
#  ['the',
#   'parties',
#   'continue',
#   'bound',
#   'the',
#   'terms',
#   'the',
#   'non',
#   'disclosure',
#   'agreement',
#   'between',
#   'the',
#   'parties',
#   'dated',
#   'date',
#   'and',
#   'attached',
#   'this',
#   'agreement',
#   'attachment'],
#  [],
#  ['publicity', 'consent'],
#  ['neither',
#   'party',
#   'will',
#   'use',
#   'the',
#   'other',
#   'party',
#   'name',
#   'logo',
#   'trademarks',
#   'issue',
#   'any',
#   'press',
#   'release',
#   'public',
#   'announcement',
#   'regarding',
#   'this',
#   'agreement',
#   'without',
#   'the',
#   'other',
#   'party',
#   'written',
#   'consent',
#   'unless',
#   'specifically',
#   'permitted',
#   'under',
#   'this',
#   'agreement',
#   'required',
#   'law'],
#  ['cooperation'],
#  ['the',
#   'parties',
#   'will',
#   'cooperate',
#   'draft',
#   'all',
#   'appropriate',
#   'press',
#   'releases',
#   'and',
#   'other',
#   'public',
#   'announcements',
#   'relating',
#   'the',
#   'subject',
#   'matter',
#   'this',
#   'agreement',
#   'and',
#   'the',
#   'relationship',
#   'between',
#   'the',
#   'parties'],
#  ['unreasonable', 'delay'],
#  ['the',
#   'parties',
#   'will',
#   'not',
#   'unreasonably',
#   'withhold',
#   'delay',
#   'their',
#   'consent',
#   'press',
#   'releases',
#   'public',
#   'announcements'],
#  [],
#  ['termination', 'termination', 'notice'],
#  ['either',
#   'party',
#   'may',
#   'terminate',
#   'this',
#   'agreement',
#   'for',
#   'any',
#   'reason',
#   'termination',
#   'notice',
#   'business',
#   'days',
#   'business',
#   'days',
#   'notice',
#   'the',
#   'other',
#   'party'],
#  ['termination', 'for', 'material', 'breach'],
#  ['each',
#   'party',
#   'may',
#   'terminate',
#   'this',
#   'agreement',
#   'with',
#   'immediate',
#   'effect',
#   'delivering',
#   'notice',
#   'the',
#   'termination',
#   'the',
#   'other',
#   'party',
#   'the',
#   'other',
#   'party',
#   'fails',
#   'perform',
#   'has',
#   'made',
#   'makes',
#   'any',
#   'inaccuracy',
#   'otherwise',
#   'materially',
#   'breaches',
#   'any',
#   'its',
#   'obligations',
#   'covenants',
#   'representations',
#   'and',
#   'the',
#   'failure',
#   'inaccuracy',
#   'breach',
#   'continues',
#   'for',
#   'period',
#   'breach',
#   'continuation',
#   'days',
#   'business',
#   'days',
#   'after',
#   'the',
#   'injured',
#   'party',
#   'delivers',
#   'notice',
#   'the',
#   'breaching',
#   'party',
#   'reasonably',
#   'detailing',
#   'the',
#   'breach'],
#  [],
#  ['effect', 'termination', 'payment', 'obligations'],
#  ['the',
#   'expiration',
#   'termination',
#   'this',
#   'agreement',
#   'each',
#   'party',
#   'shall',
#   'pay',
#   'any',
#   'amounts',
#   'owes',
#   'the',
#   'other',
#   'party',
#   'including',
#   'payment',
#   'obligations',
#   'for',
#   'services',
#   'already',
#   'rendered',
#   'work',
#   'already',
#   'performed',
#   'goods',
#   'already',
#   'delivered',
#   'expenses',
#   'already',
#   'incurred',
#   'and',
#   'refund',
#   'any',
#   'payments',
#   'received',
#   'but',
#   'not',
#   'yet',
#   'earned',
#   'including',
#   'payments',
#   'for',
#   'services',
#   'not',
#   'rendered',
#   'work',
#   'not',
#   'performed',
#   'goods',
#   'not',
#   'delivered',
#   'expenses',
#   'forwarded'],
#  ['termination', 'license', 'grant'],
#  ['the',
#   'expiration',
#   'termination',
#   'this',
#   'agreement',
#   'the',
#   'deliverable',
#   'granted',
#   'under',
#   'this',
#   'agreement',
#   'will',
#   'terminate',
#   'with',
#   'immediate',
#   'effect'],
#  [],
#  ['return', 'property'],
#  ['termination',
#   'expiration',
#   'this',
#   'agreement',
#   'party',
#   'request',
#   'party',
#   'will',
#   'return',
#   'party',
#   'all',
#   'originals',
#   'the',
#   'information',
#   'and',
#   'other',
#   'property',
#   'including',
#   'intellectual',
#   'property',
#   'received',
#   'from',
#   'party',
#   'destroy',
#   'all',
#   'copies',
#   'such',
#   'information',
#   'and',
#   'other',
#   'property',
#   'has',
#   'its',
#   'possession',
#   'control',
#   'and',
#   'party',
#   'request',
#   'certify',
#   'party',
#   'writing',
#   'that',
#   'destroyed',
#   'all',
#   'such',
#   'copies'],
#  [],
#  ['indemnification', 'indemnification', 'party'],
#  ['party',
#   'indemnifying',
#   'party',
#   'shall',
#   'indemnify',
#   'party',
#   'indemnified',
#   'party',
#   'against',
#   'all',
#   'losses',
#   'and',
#   'expenses',
#   'connection',
#   'with',
#   'any',
#   'proceeding',
#   'arising',
#   'out'],
#  ['party', 'use', 'the', 'software', 'and'],
#  ['party',
#   'unauthorized',
#   'customization',
#   'modification',
#   'other',
#   'alterations',
#   'the',
#   'software',
#   'including',
#   'claims',
#   'that',
#   'its',
#   'customization',
#   'modification',
#   'other',
#   'alterations',
#   'infringe',
#   'third',
#   'party',
#   'intellectual',
#   'property',
#   'rights',
#   'mutual',
#   'indemnification'],
#  ['each',
#   'party',
#   'indemnifying',
#   'party',
#   'shall',
#   'indemnify',
#   'the',
#   'other',
#   'indemnified',
#   'party',
#   'against',
#   'all',
#   'losses',
#   'connection',
#   'with',
#   'any',
#   'proceeding',
#   'arising',
#   'out',
#   'the',
#   'indemnifying',
#   'party',
#   'willful',
#   'misconduct',
#   'gross',
#   'negligence'],
#  ['notice', 'and', 'failure', 'notify'],
#  ['notice', 'requirement'],
#  ['before',
#   'bringing',
#   'claim',
#   'for',
#   'indemnification',
#   'the',
#   'indemnified',
#   'party',
#   'shall',
#   'notify',
#   'the',
#   'indemnifying',
#   'party',
#   'the',
#   'indemnifiable',
#   'proceeding',
#   'and'],
#  ['deliver',
#   'the',
#   'indemnifying',
#   'party',
#   'all',
#   'legal',
#   'pleadings',
#   'and',
#   'other',
#   'documents',
#   'reasonably',
#   'necessary',
#   'indemnify',
#   'defend',
#   'the',
#   'indemnifiable',
#   'proceeding'],
#  [],
#  ['failure', 'notify'],
#  ['the',
#   'indemnified',
#   'party',
#   'fails',
#   'notify',
#   'the',
#   'indemnifying',
#   'party',
#   'the',
#   'indemnifiable',
#   'proceeding',
#   'the',
#   'indemnifying',
#   'will',
#   'relieved',
#   'its',
#   'indemnification',
#   'obligations',
#   'the',
#   'extent',
#   'was',
#   'prejudiced',
#   'the',
#   'indemnified',
#   'party',
#   'failure'],
#  ['exclusive', 'remedy'],
#  ['the',
#   'parties',
#   'right',
#   'indemnification',
#   'the',
#   'exclusive',
#   'remedy',
#   'available',
#   'connection',
#   'with',
#   'the',
#   'indemnifiable',
#   'proceedings',
#   'described',
#   'this',
#   'section',
#   'indemnification'],
#  [],
#  ['limitation', 'liability'],
#  ['neither',
#   'party',
#   'will',
#   'liable',
#   'for',
#   'breach',
#   'contract',
#   'damages',
#   'that',
#   'are',
#   'remote',
#   'speculative',
#   'that',
#   'the',
#   'breaching',
#   'party',
#   'could',
#   'not',
#   'reasonably',
#   'have',
#   'foreseen',
#   'entry',
#   'into',
#   'this',
#   'agreement'],
#  [],
#  ['definitions',
#   'books',
#   'and',
#   'records',
#   'means',
#   'all',
#   'books',
#   'and',
#   'records',
#   'including',
#   'books',
#   'account',
#   'ledgers',
#   'and',
#   'general',
#   'financial',
#   'and',
#   'accounting',
#   'records',
#   'machinery',
#   'and',
#   'equipment',
#   'maintenance',
#   'files',
#   'lists',
#   'parties',
#   'and',
#   'prospects',
#   'for',
#   'franchise',
#   'agreements',
#   'supplier',
#   'lists',
#   'production',
#   'data',
#   'quality',
#   'control',
#   'records',
#   'and',
#   'procedures',
#   'customer',
#   'complaints',
#   'inquiry',
#   'files',
#   'research',
#   'development',
#   'files',
#   'records',
#   'data',
#   'including',
#   'all',
#   'correspondence',
#   'with',
#   'any',
#   'governmental',
#   'authority',
#   'sales',
#   'material',
#   'and',
#   'records',
#   'including',
#   'pricing',
#   'history',
#   'and',
#   'sales',
#   'and',
#   'pricing',
#   'policies',
#   'and',
#   'practices',
#   'strategic',
#   'plans',
#   'marketing',
#   'and',
#   'promotional',
#   'surveys',
#   'and',
#   'material',
#   'research',
#   'and',
#   'files',
#   'relating',
#   'intellectual',
#   'property'],
#  ['business',
#   'day',
#   'means',
#   'day',
#   'other',
#   'than',
#   'saturday',
#   'sunday',
#   'any',
#   'other',
#   'day',
#   'which',
#   'the',
#   'principal',
#   'banks',
#   'located',
#   'new',
#   'york',
#   'new',
#   'york',
#   'are',
#   'not',
#   'open',
#   'for',
#   'business'],
#  ['disclosure',
#   'schedule',
#   'means',
#   'the',
#   'schedules',
#   'delivered',
#   'before',
#   'the',
#   'execution',
#   'this',
#   'agreement',
#   'each',
#   'party',
#   'the',
#   'other',
#   'party',
#   'which',
#   'list',
#   'among',
#   'other',
#   'things',
#   'items',
#   'the',
#   'disclosure',
#   'which',
#   'necessary',
#   'appropriate',
#   'either',
#   'response',
#   'express',
#   'disclosure',
#   'requirement',
#   'contained',
#   'provision',
#   'this',
#   'agreement',
#   'exception',
#   'one',
#   'more',
#   'the',
#   'representations',
#   'warranties',
#   'made',
#   'the',
#   'party',
#   'one',
#   'more',
#   'the',
#   'covenants',
#   'the',
#   'party'],
#  ['effective', 'date', 'defined', 'the', 'introduction', 'this', 'agreement'],
#  ['escrow',
#   'company',
#   'defined',
#   'section',
#   'source',
#   'code',
#   'escrow',
#   'include',
#   'only',
#   'including',
#   'optional',
#   'source',
#   'code',
#   'escrow',
#   'clause',
#   'governmental',
#   'authority',
#   'means',
#   'any',
#   'federal',
#   'state',
#   'local',
#   'foreign',
#   'government',
#   'and',
#   'any',
#   'political',
#   'subdivision',
#   'any',
#   'them',
#   'any',
#   'agency',
#   'instrumentality',
#   'any',
#   'such',
#   'government',
#   'political',
#   'subdivision',
#   'any',
#   'self',
#   'regulated',
#   'organization',
#   'other',
#   'non',
#   'governmental',
#   'regulatory',
#   'authority',
#   'quasi',
#   'governmental',
#   'authority',
#   'the',
#   'extent',
#   'that',
#   'its',
#   'rules',
#   'regulations',
#   'orders',
#   'have',
#   'the',
#   'force',
#   'law',
#   'and',
#   'any',
#   'arbitrator',
#   'court',
#   'tribunal',
#   'competent',
#   'jurisdiction'],
#  ['intellectual',
#   'property',
#   'means',
#   'any',
#   'and',
#   'all',
#   'the',
#   'following',
#   'any',
#   'jurisdiction',
#   'throughout',
#   'the',
#   'world',
#   'trademarks',
#   'and',
#   'service',
#   'marks',
#   'including',
#   'all',
#   'applications',
#   'and',
#   'registrations',
#   'and',
#   'the',
#   'goodwill',
#   'connected',
#   'with',
#   'the',
#   'use',
#   'and',
#   'symbolized',
#   'the',
#   'foregoing',
#   'copyrights',
#   'including',
#   'all',
#   'applications',
#   'and',
#   'registrations',
#   'related',
#   'the',
#   'foregoing',
#   'trade',
#   'secrets',
#   'and',
#   'confidential',
#   'know',
#   'how',
#   'patents',
#   'and',
#   'patent',
#   'applications',
#   'websites',
#   'and',
#   'internet',
#   'domain',
#   'name',
#   'registrations',
#   'and',
#   'other',
#   'intellectual',
#   'property',
#   'and',
#   'related',
#   'proprietary',
#   'rights',
#   'interests',
#   'and',
#   'protections',
#   'including',
#   'all',
#   'rights',
#   'sue',
#   'and',
#   'recover',
#   'and',
#   'retain',
#   'damages',
#   'costs',
#   'and',
#   'attorneys',
#   'fees',
#   'for',
#   'past',
#   'present',
#   'and',
#   'future',
#   'infringement',
#   'and',
#   'any',
#   'other',
#   'rights',
#   'relating',
#   'any',
#   'the',
#   'foregoing'],
#  ['law',
#   'means',
#   'any',
#   'law',
#   'including',
#   'the',
#   'common',
#   'law',
#   'statute',
#   'bylaw',
#   'rule',
#   'regulation',
#   'order',
#   'ordinance',
#   'treaty',
#   'decree',
#   'judgment',
#   'and',
#   'any',
#   'official',
#   'directive',
#   'protocol',
#   'code',
#   'guideline',
#   'notice',
#   'approval',
#   'order',
#   'policy',
#   'other',
#   'requirement',
#   'any',
#   'governmental',
#   'authority',
#   'having',
#   'the',
#   'force',
#   'law'],
#  ['legal',
#   'proceeding',
#   'means',
#   'any',
#   'claim',
#   'investigation',
#   'hearing',
#   'legal',
#   'action',
#   'other',
#   'legal',
#   'administrative',
#   'arbitral',
#   'similar',
#   'proceeding',
#   'whether',
#   'civil',
#   'criminal',
#   'including',
#   'any',
#   'appeal',
#   'review',
#   'any',
#   'the',
#   'foregoing'],
#  ['license', 'fee', 'defined', 'section', 'license', 'fees'],
#  ['license', 'grant', 'defined', 'section', 'license', 'grant'],
#  ['order',
#   'means',
#   'any',
#   'decision',
#   'order',
#   'judgment',
#   'award',
#   'similar',
#   'order',
#   'any',
#   'court',
#   'competent',
#   'jurisdiction',
#   'arbitration',
#   'panel',
#   'governmental',
#   'authority',
#   'with',
#   'jurisdiction',
#   'over',
#   'the',
#   'subject',
#   'matter',
#   'whether',
#   'preliminary',
#   'final'],
#  ['permits',
#   'means',
#   'all',
#   'material',
#   'licenses',
#   'franchises',
#   'permits',
#   'certificates',
#   'approvals',
#   'and',
#   'authorizations',
#   'from',
#   'governmental',
#   'authorities',
#   'necessary',
#   'for',
#   'the',
#   'ownership',
#   'and',
#   'operation',
#   'the',
#   'party',
#   'business'],
#  ['person',
#   'includes',
#   'any',
#   'corporation',
#   'company',
#   'limited',
#   'liability',
#   'company',
#   'partnership',
#   'governmental',
#   'authority',
#   'joint',
#   'venture',
#   'fund',
#   'trust',
#   'association',
#   'syndicate',
#   'organization',
#   'other',
#   'entity',
#   'group',
#   'persons',
#   'whether',
#   'incorporated',
#   'not',
#   'and',
#   'any',
#   'individual'],
#  ['software', 'defined', 'section', 'license', 'grant'],
#  ['taxes',
#   'includes',
#   'all',
#   'taxes',
#   'assessments',
#   'charges',
#   'duties',
#   'fees',
#   'levies',
#   'and',
#   'other',
#   'charges',
#   'governmental',
#   'authority',
#   'including',
#   'income',
#   'franchise',
#   'capital',
#   'stock',
#   'real',
#   'property',
#   'personal',
#   'property',
#   'tangible',
#   'withholding',
#   'employment',
#   'payroll',
#   'social',
#   'security',
#   'social',
#   'contribution',
#   'unemployment',
#   'compensation',
#   'disability',
#   'transfer',
#   'sales',
#   'use',
#   'excise',
#   'gross',
#   'receipts',
#   'value',
#   'added',
#   'and',
#   'all',
#   'other',
#   'taxes',
#   'any',
#   'kind',
#   'for',
#   'which',
#   'party',
#   'may',
#   'have',
#   'any',
#   'liability',
#   'imposed',
#   'any',
#   'governmental',
#   'authority',
#   'whether',
#   'disputed',
#   'not',
#   'any',
#   'related',
#   'charges',
#   'interest',
#   'penalties',
#   'imposed',
#   'any',
#   'governmental',
#   'authority',
#   'and',
#   'any',
#   'liability',
#   'for',
#   'any',
#   'other',
#   'person',
#   'transferee',
#   'successor',
#   'law',
#   'contract',
#   'otherwise'],
#  ['term', 'defined', 'section', 'term'],
#  [],
#  ['general', 'provisions', 'entire', 'agreement'],
#  ['the',
#   'parties',
#   'intend',
#   'that',
#   'this',
#   'agreement',
#   'together',
#   'with',
#   'all',
#   'attachments',
#   'schedules',
#   'exhibits',
#   'and',
#   'other',
#   'documents',
#   'that',
#   'both',
#   'are',
#   'referenced',
#   'this',
#   'agreement',
#   'and',
#   'refer',
#   'this',
#   'agreement',
#   'represent',
#   'the',
#   'final',
#   'expression',
#   'the',
#   'parties',
#   'intent',
#   'relating',
#   'the',
#   'subject',
#   'matter',
#   'this',
#   'agreement',
#   'contain',
#   'all',
#   'the',
#   'terms',
#   'the',
#   'parties',
#   'agreed',
#   'relating',
#   'the',
#   'subject',
#   'matter',
#   'and',
#   'replace',
#   'all',
#   'the',
#   'parties',
#   'previous',
#   'discussions',
#   'understandings',
#   'and',
#   'agreements',
#   'relating',
#   'the',
#   'subject',
#   'matter',
#   'this',
#   'agreement'],
#  ['counterparts'],
#  ['signed', 'counterparts'],
#  ['this', 'agreement', 'may', 'signed', 'any', 'number', 'counterparts'],
#  [],
#  ['all', 'counterparts', 'original'],
#  ['each', 'counterpart', 'original'],
#  ['counterparts', 'form', 'one', 'document'],
#  ['together', 'all', 'counterparts', 'form', 'one', 'single', 'document'],
#  ['amendment'],
#  ['this',
#   'agreement',
#   'can',
#   'amended',
#   'only',
#   'writing',
#   'signed',
#   'both',
#   'parties'],
#  ['relationship', 'the', 'parties'],
#  ['relationship'],
#  ['nothing',
#   'this',
#   'agreement',
#   'creates',
#   'any',
#   'special',
#   'relationship',
#   'between',
#   'the',
#   'parties',
#   'such',
#   'partnership',
#   'joint',
#   'venture',
#   'employee',
#   'employer',
#   'relationship',
#   'between',
#   'the',
#   'parties'],
#  [],
#  ['authority'],
#  ['neither',
#   'party',
#   'has',
#   'the',
#   'authority',
#   'and',
#   'will',
#   'not',
#   'act',
#   'agent',
#   'for',
#   'behalf',
#   'the',
#   'other',
#   'party',
#   'represent',
#   'bind',
#   'the',
#   'other',
#   'party',
#   'any',
#   'manner'],
#  ['assignment'],
#  ['neither',
#   'party',
#   'may',
#   'assign',
#   'this',
#   'agreement',
#   'any',
#   'their',
#   'rights',
#   'obligations',
#   'under',
#   'this',
#   'agreement',
#   'without',
#   'the',
#   'other',
#   'party',
#   'written',
#   'consent'],
#  ['notices'],
#  ['method', 'notice'],
#  ['the',
#   'parties',
#   'will',
#   'give',
#   'all',
#   'notices',
#   'and',
#   'communications',
#   'between',
#   'the',
#   'parties',
#   'writing',
#   'personal',
#   'delivery',
#   'nationally',
#   'recognized',
#   'next',
#   'day',
#   'courier',
#   'service',
#   'iii',
#   'first',
#   'class',
#   'registered',
#   'certified',
#   'mail',
#   'postage',
#   'prepaid',
#   'the',
#   'address',
#   'that',
#   'party',
#   'has',
#   'notified',
#   'that',
#   'party',
#   'address',
#   'for',
#   'the',
#   'purposes',
#   'this',
#   'section'],
#  [],
#  ['receipt', 'notice'],
#  ['notice',
#   'given',
#   'under',
#   'this',
#   'agreement',
#   'will',
#   'effective',
#   'the',
#   'other',
#   'party',
#   'receipt'],
#  ['mailed',
#   'the',
#   'earlier',
#   'the',
#   'other',
#   'party',
#   'receipt',
#   'and',
#   'the',
#   'fifth',
#   'business',
#   'day',
#   'after',
#   'mailing'],
#  ['governing', 'law', 'and', 'consent', 'jurisdiction', 'and', 'venue'],
#  ['governing', 'law'],
#  ['this',
#   'agreement',
#   'and',
#   'any',
#   'dispute',
#   'arising',
#   'out',
#   'the',
#   'subject',
#   'matter',
#   'the',
#   'agreement',
#   'shall',
#   'governed',
#   'the',
#   'laws',
#   'the',
#   'state',
#   'governing',
#   'law',
#   'state'],
#  [],
#  ['consent', 'jurisdiction'],
#  ['each',
#   'party',
#   'hereby',
#   'irrevocably',
#   'consents',
#   'the',
#   'exclusive',
#   'nonexclusive',
#   'jurisdiction',
#   'and',
#   'venue',
#   'any',
#   'state',
#   'federal',
#   'court',
#   'located',
#   'within',
#   'venue',
#   'county',
#   'county',
#   'state',
#   'venue',
#   'state',
#   'connection',
#   'with',
#   'any',
#   'matter',
#   'arising',
#   'out',
#   'this',
#   'agreement',
#   'plan',
#   'the',
#   'transactions',
#   'contemplated',
#   'under',
#   'this',
#   'agreement',
#   'plan'],
#  ['consent', 'service'],
#  ['each',
#   'party',
#   'hereby',
#   'irrevocably',
#   'agrees',
#   'that',
#   'process',
#   'may',
#   'served',
#   'any',
#   'manner',
#   'authorized',
#   'the',
#   'laws',
#   'the',
#   'state',
#   'governing',
#   'law',
#   'state',
#   'and'],
#  ['waives',
#   'any',
#   'objection',
#   'which',
#   'might',
#   'otherwise',
#   'have',
#   'service',
#   'process',
#   'under',
#   'the',
#   'laws',
#   'the',
#   'state',
#   'governing',
#   'law',
#   'state'],
#  ['dispute', 'resolution'],
#  ['arbitration'],
#  ['any',
#   'dispute',
#   'controversy',
#   'arising',
#   'out',
#   'this',
#   'agreement',
#   'and',
#   'subject',
#   'matter',
#   'the',
#   'agreement',
#   'will',
#   'settled',
#   'arbitration',
#   'state',
#   'according',
#   'the',
#   'rules',
#   'the',
#   'american',
#   'arbitration',
#   'association',
#   'then',
#   'effect',
#   'and',
#   'number',
#   'arbitrators',
#   'arbitrators'],
#  [],
#  ['judgment'],
#  ['judgment',
#   'may',
#   'entered',
#   'the',
#   'arbitrator',
#   'award',
#   'any',
#   'court',
#   'having',
#   'jurisdiction'],
#  ['arbitrator', 'authority'],
#  ['the',
#   'arbitrator',
#   'will',
#   'not',
#   'have',
#   'the',
#   'power',
#   'award',
#   'any',
#   'punitive',
#   'consequential',
#   'damages'],
#  ['equitable', 'relief'],
#  ['acknowledgment', 'irreparable', 'harm'],
#  ['each',
#   'party',
#   'acknowledges',
#   'that',
#   'their',
#   'breach',
#   'threatened',
#   'breach',
#   'their',
#   'obligations',
#   'under',
#   'this',
#   'agreement',
#   'would',
#   'result',
#   'irreparable',
#   'harm',
#   'the',
#   'other',
#   'party',
#   'that',
#   'cannot',
#   'adequately',
#   'relieved',
#   'money',
#   'damages',
#   'alone'],
#  [],
#  ['intent', 'allow', 'for', 'equitable', 'remedies'],
#  ['accordingly',
#   'the',
#   'parties',
#   'hereby',
#   'acknowledge',
#   'their',
#   'mutual',
#   'intent',
#   'that',
#   'after',
#   'any',
#   'breach',
#   'the',
#   'obligations',
#   'listed',
#   'the',
#   'paragraph',
#   'directly',
#   'above',
#   'the',
#   'non',
#   'breaching',
#   'party',
#   'may',
#   'request',
#   'any',
#   'applicable',
#   'equitable',
#   'remedies',
#   'from',
#   'court',
#   'including',
#   'injunctive',
#   'relief',
#   'without',
#   'the',
#   'need',
#   'for',
#   'that',
#   'party',
#   'post',
#   'any',
#   'security'],
#  ['waiver'],
#  ['affirmative', 'waivers'],
#  ['neither',
#   'party',
#   'failure',
#   'neglect',
#   'enforce',
#   'any',
#   'rights',
#   'under',
#   'this',
#   'agreement',
#   'will',
#   'deemed',
#   'waiver',
#   'that',
#   'party',
#   'rights'],
#  [],
#  ['written', 'waivers'],
#  ['waiver',
#   'extension',
#   'only',
#   'effective',
#   'writing',
#   'and',
#   'signed',
#   'the',
#   'party',
#   'granting'],
#  ['general', 'waivers'],
#  ['party',
#   'failure',
#   'neglect',
#   'enforce',
#   'any',
#   'its',
#   'rights',
#   'under',
#   'this',
#   'agreement',
#   'will',
#   'not',
#   'deemed',
#   'waiver',
#   'that',
#   'any',
#   'other',
#   'its',
#   'rights'],
#  ['course', 'dealing'],
#  ['single',
#   'partial',
#   'exercise',
#   'any',
#   'right',
#   'remedy',
#   'will',
#   'preclude',
#   'any',
#   'other',
#   'further',
#   'exercise',
#   'any',
#   'right',
#   'remedy'],
#  ['force', 'majeure'],
#  ['neither',
#   'party',
#   'will',
#   'liable',
#   'for',
#   'performance',
#   'delays',
#   'nor',
#   'for',
#   'non',
#   'performance',
#   'due',
#   'causes',
#   'beyond',
#   'its',
#   'reasonable',
#   'control',
#   'except',
#   'for',
#   'payment',
#   'obligations'],
#  ['severability'],
#  ['any',
#   'part',
#   'this',
#   'agreement',
#   'declared',
#   'unenforceable',
#   'invalid',
#   'the',
#   'remainder',
#   'will',
#   'continue',
#   'valid',
#   'and',
#   'enforceable'],
#  ['survival'],
#  ['the',
#   'parties',
#   'obligations',
#   'under',
#   'sections',
#   'confidentiality',
#   'obligations',
#   'noncompetition',
#   'obligation',
#   'and',
#   'effect',
#   'termination',
#   'will',
#   'survive',
#   'the',
#   'termination',
#   'expiration',
#   'closing',
#   'date',
#   'this',
#   'agreement'],
#  ['headings'],
#  ['the',
#   'section',
#   'headings',
#   'contained',
#   'this',
#   'agreement',
#   'are',
#   'for',
#   'reference',
#   'purposes',
#   'only',
#   'and',
#   'shall',
#   'not',
#   'affect',
#   'the',
#   'meaning',
#   'interpretation',
#   'this',
#   'agreement'],
#  ['attorney', 'fees'],
#  ['either',
#   'party',
#   'brings',
#   'action',
#   'enforce',
#   'their',
#   'rights',
#   'under',
#   'this',
#   'agreement',
#   'the',
#   'prevailing',
#   'party',
#   'may',
#   'recover',
#   'its',
#   'expenses',
#   'including',
#   'reasonable',
#   'attorneys',
#   'fees',
#   'incurred',
#   'connection',
#   'with',
#   'the',
#   'action',
#   'and',
#   'any',
#   'appeal',
#   'from',
#   'the',
#   'losing',
#   'party'],
#  ['this', 'agreement', 'has', 'been', 'signed', 'the', 'parties'],
#  ['party',
#   'name',
#   'party',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'title',
#   'party',
#   'signatory',
#   'title',
#   'title',
#   'party',
#   'signatory',
#   'title']]

# %%
bigram = gensim.models.Phrases(list_of_simple_preprocess_data)

# %%
bigram

# %%
from nltk.corpus import stopwords

# %%
stops = set(stopwords.words('english')) 
stops
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
import re
# !pip install Pattern library
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pattern
#   Downloading Pattern-3.6.0.tar.gz (22.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 46.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting library
#   Downloading Library-0.0.0.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from Pattern) (0.18.3)
# Collecting backports.csv
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.1.1.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 KB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from Pattern) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from Pattern) (4.9.2)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 9.2 MB/s eta 0:00:00
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 63.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from Pattern) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from Pattern) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from Pattern) (3.8.1)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 104.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cherrypy
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.4/348.4 KB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from Pattern) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->Pattern) (2.4)
# Collecting zc.lockfile
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-9.0.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 KB 13.3 MB/s eta 0:00:00
# Collecting jaraco.collections
#   Downloading jaraco.collections-3.9.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from cherrypy->Pattern) (9.1.0)
# Collecting portend>=2.1.1
#   Downloading portend-3.1.0-py3-none-any.whl (5.3 kB)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->Pattern) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->Pattern) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->Pattern) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk->Pattern) (4.65.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six->Pattern) (39.0.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six->Pattern) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->Pattern) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->Pattern) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->Pattern) (1.26.15)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from cheroot>=8.2.1->cherrypy->Pattern) (1.16.0)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.6.0-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=36.0.0->pdfminer.six->Pattern) (1.15.1)
# Collecting tempora>=1.8
#   Downloading tempora-5.2.1-py3-none-any.whl (13 kB)
# Collecting jaraco.text
#   Downloading jaraco.text-3.11.1-py3-none-any.whl (11 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from zc.lockfile->cherrypy->Pattern) (67.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->Pattern) (2.21)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->Pattern) (2022.7.1)
# Collecting jaraco.context>=4.1
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting autocommand
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.9/dist-packages (from jaraco.text->jaraco.collections->cherrypy->Pattern) (6.0.2)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->Pattern) (1.10.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->Pattern) (4.5.0)
# Building wheels for collected packages: Pattern, library, mysqlclient, python-docx, sgmllib3k
#   Building wheel for Pattern (setup.py) ... done
#   Created wheel for Pattern: filename=Pattern-3.6-py3-none-any.whl size=22332718 sha256=5393dd406857a43a7e816dafee9db2563caa3d4961700e4394adc1840594e1bb
#   Stored in directory: /root/.cache/pip/wheels/50/33/f3/ea00b80d50c09f210588bda15ec60bdb38b289b452577cd5c3
#   Building wheel for library (setup.py) ... done
#   Created wheel for library: filename=Library-0.0.0-py3-none-any.whl size=2081 sha256=b10defba128843befd3eaf7336a99900a8ae3183f70113edb9fcd483cba90d3c
#   Stored in directory: /root/.cache/pip/wheels/52/cc/18/326d98d6504470bb5c6e275ddf218c212bdf0449d2944f34dc
#   Building wheel for mysqlclient (setup.py) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.1.1-cp39-cp39-linux_x86_64.whl size=107572 sha256=1ea94c2fb118d26da6ff8c681f3e498224e8407c48039c9324c37736add9b0d2
#   Stored in directory: /root/.cache/pip/wheels/f3/a5/27/c6312d8008951cfd5511684378a9e057b82006c70e1fea6107
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=4ae8f78a1399489bf57844e973f197d3727994d28082ad6ea03eb6d1f155b61b
#   Stored in directory: /root/.cache/pip/wheels/83/8b/7c/09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=0cc633ebaeb1f25288503c74a091d07428be7fa025aa403ca6e16e15ebe86f80
#   Stored in directory: /root/.cache/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built Pattern library mysqlclient python-docx sgmllib3k
# Installing collected packages: sgmllib3k, library, backports.csv, zc.lockfile, python-docx, mysqlclient, jaraco.functools, jaraco.context, jaraco.classes, feedparser, autocommand, tempora, cheroot, portend, pdfminer.six, jaraco.text, jaraco.collections, cherrypy, Pattern
# Successfully installed Pattern-3.6 autocommand-2.2.2 backports.csv-1.0.7 cheroot-9.0.0 cherrypy-18.8.0 feedparser-6.0.10 jaraco.classes-3.2.3 jaraco.collections-3.9.0 jaraco.context-4.3.0 jaraco.functools-3.6.0 jaraco.text-3.11.1 library-0.0.0 mysqlclient-2.1.1 pdfminer.six-20221105 portend-3.1.0 python-docx-0.8.11 sgmllib3k-1.0.0 tempora-5.2.1 zc.lockfile-3.0.post1

# %%
texts = [[word for word in line if word not in stops] for line in texts]
texts1 = [[word for word in line if word not in stops] for line in texts1]
texts2 = [[word for word in line if word not in stops] for line in texts2]
texts3 = [[word for word in line if word not in stops] for line in texts3]
new_newsletter=[[word for word in line if word not in stops] for line in new_newsletter]
texts_final = []
texts_final.extend(texts)
texts_final.extend(texts1)
texts_final.extend(texts2)
texts_final.extend(texts3)
texts_final.extend(new_newsletter)
texts_final
# Out:
# [['amendment',
#   'agreement',
#   'name',
#   'amendment',
#   'agreement',
#   'name',
#   'dated',
#   'effective',
#   'date',
#   'agreement',
#   'agreement',
#   'made',
#   'amendment',
#   'effective',
#   'date',
#   'party',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'principal',
#   'place',
#   'business',
#   'party',
#   'address',
#   'party',
#   'abbreviation',
#   'party',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'principal',
#   'place',
#   'business',
#   'party',
#   'address',
#   'party',
#   'abbreviation'],
#  [],
#  ['capitalized', 'terms'],
#  ['unless',
#   'otherwise',
#   'defined',
#   'amendment',
#   'capitalized',
#   'terms',
#   'used',
#   'amendment',
#   'meaning',
#   'agreement'],
#  [],
#  ['substance', 'amendment'],
#  ['parties',
#   'hereby',
#   'amend',
#   'agreement',
#   'follows',
#   'list',
#   'changes',
#   'additions',
#   'deletions',
#   'etc'],
#  ['made', 'underlying', 'agreement'],
#  ['continuing', 'effect'],
#  ['except',
#   'listed',
#   'section',
#   'substance',
#   'amendment',
#   'agreement',
#   'unaffected',
#   'continue',
#   'full',
#   'force',
#   'effect',
#   'terms'],
#  [],
#  ['conflicting', 'amendments'],
#  ['conflict',
#   'terms',
#   'amendment',
#   'earlier',
#   'amendment',
#   'agreement',
#   'terms',
#   'amendment',
#   'control'],
#  ['agreement', 'signed', 'parties'],
#  ['party',
#   'name',
#   'party',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'title',
#   'party',
#   'signatory',
#   'title',
#   'title',
#   'party',
#   'signatory',
#   'title'],
#  ['software',
#   'license',
#   'agreement',
#   'software',
#   'license',
#   'agreement',
#   'made',
#   'agreement',
#   'date',
#   'licensor',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'principal',
#   'place',
#   'business',
#   'licensor',
#   'address',
#   'party',
#   'licensee',
#   'name',
#   'corporate',
#   'jurisdiction',
#   'corporation',
#   'principal',
#   'place',
#   'business',
#   'licensee',
#   'address',
#   'party'],
#  ['parties', 'agree', 'terms', 'agreement'],
#  [],
#  ['license', 'grant', 'software', 'license'],
#  ['party',
#   'hereby',
#   'grants',
#   'party',
#   'exclusive',
#   'non',
#   'exclusive',
#   'transferable',
#   'non',
#   'transferable',
#   'sublicensable',
#   'non',
#   'sublicensable',
#   'revocable',
#   'irrevocable',
#   'license',
#   'deliverable',
#   'use',
#   'software'],
#  ['rights'],
#  ['party',
#   'reserves',
#   'rights',
#   'interest',
#   'explicitly',
#   'granted',
#   'agreement'],
#  ['software'],
#  ['software',
#   'means',
#   'short',
#   'description',
#   'software',
#   'software',
#   'described',
#   'attachment',
#   'attached',
#   'agreement'],
#  [],
#  ['make', 'software', 'available', 'download'],
#  ['later',
#   'effective',
#   'date',
#   'party',
#   'first',
#   'payment',
#   'software',
#   'party',
#   'make',
#   'software',
#   'available',
#   'party',
#   'electronic',
#   'downloadable',
#   'format',
#   'party',
#   'website',
#   'insert',
#   'url',
#   'website'],
#  [],
#  ['training', 'support', 'services', 'training'],
#  ['party',
#   'shall',
#   'party',
#   'expense',
#   'provide',
#   'party',
#   'employees',
#   'initial',
#   'training',
#   'services',
#   'necessary',
#   'desirable',
#   'operate',
#   'software',
#   'described',
#   'attachment',
#   'attached',
#   'agreement',
#   'party',
#   'offices',
#   'days',
#   'times',
#   'parties',
#   'agree',
#   'writing'],
#  ['support'],
#  ['initial', 'support'],
#  ['month',
#   'period',
#   'beginning',
#   'effective',
#   'date',
#   'party',
#   'expense',
#   'party',
#   'shall',
#   'provide',
#   'party',
#   'telephone',
#   'electronic',
#   'support',
#   'party',
#   'normal',
#   'business',
#   'hours',
#   'order',
#   'help',
#   'party',
#   'locate',
#   'correct',
#   'problems',
#   'software'],
#  ['internet',
#   'based',
#   'support',
#   'system',
#   'generally',
#   'available',
#   'seven',
#   'days',
#   'week',
#   'twenty',
#   'four',
#   'hours',
#   'day'],
#  [],
#  ['renewed', 'support'],
#  ['initial',
#   'month',
#   'support',
#   'period',
#   'party',
#   'may',
#   'elect',
#   'renew',
#   'party',
#   'support',
#   'services',
#   'paragraph',
#   'support',
#   'additional',
#   'month',
#   'periods',
#   'party',
#   'current',
#   'service',
#   'rates'],
#  [],
#  ['updates', 'maintenance', 'services', 'updates'],
#  ['party',
#   'shall',
#   'provide',
#   'party',
#   'party',
#   'sole',
#   'expense',
#   'updates',
#   'extensions',
#   'enhancement',
#   'modifications',
#   'changes',
#   'party',
#   'makes',
#   'adds',
#   'software',
#   'party',
#   'offers',
#   'licensees',
#   'software'],
#  ['fixes', 'patches'],
#  ['party',
#   'shall',
#   'provide',
#   'party',
#   'party',
#   'sole',
#   'expense',
#   'bug',
#   'fixes',
#   'code',
#   'corrections',
#   'correct',
#   'software',
#   'malfunctions',
#   'defects',
#   'order',
#   'bring',
#   'software',
#   'substantial',
#   'conformity',
#   'operating',
#   'specifications'],
#  ['exceptions'],
#  ['party',
#   'may',
#   'required',
#   'provide',
#   'maintenance',
#   'services',
#   'party',
#   'modified',
#   'software',
#   'default'],
#  [],
#  ['license', 'fees'],
#  ['party',
#   'pay',
#   'party',
#   'license',
#   'fee',
#   'license',
#   'fee',
#   'listed',
#   'attachment',
#   'license',
#   'fee'],
#  [],
#  ['license', 'fees', 'license', 'fee', 'paid', 'full'],
#  ['party',
#   'pay',
#   'license',
#   'fee',
#   'party',
#   'full',
#   'due',
#   'date',
#   'month',
#   'immediately',
#   'available',
#   'funds',
#   'account',
#   'party',
#   'lists',
#   'immediately',
#   'account',
#   'number',
#   'routing',
#   'number'],
#  ['taxes'],
#  ['payment', 'amounts', 'agreement', 'include', 'taxes'],
#  ['party', 'pay', 'taxes', 'applicable', 'payments', 'parties', 'agreement'],
#  [],
#  ['interest', 'late', 'payments'],
#  ['amount',
#   'paid',
#   'due',
#   'bear',
#   'interest',
#   'due',
#   'date',
#   'paid',
#   'rate',
#   'equal',
#   'per',
#   'month',
#   'annually',
#   'maximum',
#   'allowed',
#   'law',
#   'whichever',
#   'less'],
#  [],
#  ['user', 'obligations', 'hardware', 'obligations'],
#  ['party',
#   'shall',
#   'responsible',
#   'obtaining',
#   'maintaining',
#   'computer',
#   'hardware',
#   'software',
#   'communications',
#   'equipment',
#   'needed',
#   'internally',
#   'access',
#   'service',
#   'paying',
#   'third',
#   'party',
#   'access',
#   'charges',
#   'incurred',
#   'using',
#   'service'],
#  ['anti', 'virus', 'obligations'],
#  ['party',
#   'shall',
#   'responsible',
#   'implementing',
#   'maintaining',
#   'updating',
#   'necessary',
#   'proper',
#   'procedures',
#   'software',
#   'safeguarding',
#   'computer',
#   'infection',
#   'viruses',
#   'worms',
#   'trojan',
#   'horses',
#   'code',
#   'manifest',
#   'contaminating',
#   'destructive',
#   'properties',
#   'collectively',
#   'viruses'],
#  ['party', 'use', 'services'],
#  ['party',
#   'shall',
#   'abide',
#   'local',
#   'international',
#   'laws',
#   'regulations',
#   'applicable',
#   'use',
#   'service',
#   'use',
#   'service',
#   'legal',
#   'purposes',
#   'comply',
#   'regulations',
#   'policies',
#   'procedures',
#   'networks',
#   'connected',
#   'service'],
#  [],
#  ['restricted', 'uses'],
#  ['party',
#   'distribute',
#   'license',
#   'loan',
#   'sell',
#   'software',
#   'content',
#   'contained',
#   'displayed',
#   'modify',
#   'alter',
#   'create',
#   'derivative',
#   'works',
#   'software',
#   'reverse',
#   'engineer',
#   'decompile',
#   'decode',
#   'decrypt',
#   'disassemble',
#   'derive',
#   'source',
#   'code',
#   'software',
#   'remove',
#   'alter',
#   'obscure',
#   'copyright',
#   'trademark',
#   'proprietary',
#   'rights',
#   'notice',
#   'software'],
#  [],
#  ['permitted', 'uses', 'installation'],
#  ['party',
#   'may',
#   'install',
#   'use',
#   'software',
#   'solely',
#   'personal',
#   'noncommercial',
#   'internal',
#   'business',
#   'use'],
#  ['evaluation', 'use'],
#  ['party',
#   'ordered',
#   'evaluation',
#   'license',
#   'party',
#   'may',
#   'use',
#   'software',
#   'evaluation',
#   'purposes',
#   'applicable',
#   'evaluation',
#   'period'],
#  ['server', 'deployment'],
#  ['party',
#   'may',
#   'install',
#   'number',
#   'server',
#   'copies',
#   'copies',
#   'software',
#   'internal',
#   'file',
#   'server',
#   'purposes',
#   'downloading',
#   'installing',
#   'software',
#   'licensed',
#   'computers',
#   'within',
#   'internal',
#   'network'],
#  ['home', 'use'],
#  ['party',
#   'may',
#   'install',
#   'copy',
#   'software',
#   'personal',
#   'home',
#   'computer',
#   'provided',
#   'copies',
#   'software',
#   'used',
#   'time'],
#  ['backup', 'archival', 'copies'],
#  ['party',
#   'may',
#   'make',
#   'one',
#   'copy',
#   'software',
#   'solely',
#   'backup',
#   'archival',
#   'purposes'],
#  [],
#  ['term'],
#  ['agreement',
#   'begins',
#   'effective',
#   'date',
#   'date',
#   'month',
#   'continue',
#   'terminated',
#   'term'],
#  [],
#  ['representations', 'mutual', 'representations'],
#  ['existence'],
#  ['parties',
#   'corporations',
#   'incorporated',
#   'existing',
#   'laws',
#   'jurisdictions',
#   'respective',
#   'incorporation'],
#  [],
#  ['authority', 'capacity'],
#  ['parties', 'authority', 'capacity', 'enter', 'agreement'],
#  ['execution', 'delivery'],
#  ['parties', 'duly', 'executed', 'delivered', 'agreement'],
#  ['enforceability'],
#  ['agreement',
#   'constitutes',
#   'legal',
#   'valid',
#   'binding',
#   'obligation',
#   'enforceable',
#   'parties',
#   'according',
#   'terms'],
#  ['conflicts'],
#  ['neither',
#   'party',
#   'restriction',
#   'obligation',
#   'party',
#   'could',
#   'reasonably',
#   'expect',
#   'might',
#   'affect',
#   'party',
#   'performance',
#   'obligations',
#   'agreement'],
#  ['breach'],
#  ['neither',
#   'party',
#   'execution',
#   'delivery',
#   'performance',
#   'obligations',
#   'agreement',
#   'breach',
#   'result',
#   'default',
#   'articles',
#   'bylaws',
#   'unanimous',
#   'shareholders',
#   'agreement'],
#  ['law', 'subject', 'iii'],
#  ['judgment', 'order', 'decree', 'governmental', 'authority', 'subject'],
#  ['agreement', 'party', 'bound'],
#  ['permits', 'consents', 'authorizations'],
#  ['party',
#   'holds',
#   'permits',
#   'authorizations',
#   'necessary',
#   'lease',
#   'operate',
#   'properties'],
#  ['conduct', 'business', 'carried'],
#  ['disputes', 'proceedings'],
#  ['except',
#   'disclosed',
#   'parties',
#   'respective',
#   'disclosure',
#   'schedules',
#   'legal',
#   'proceedings',
#   'pending',
#   'threatened',
#   'foreseeable',
#   'either',
#   'party',
#   'would',
#   'affect',
#   'party',
#   'ability',
#   'complete',
#   'obligations',
#   'agreement'],
#  [],
#  ['bankruptcy'],
#  ['neither',
#   'party',
#   'taken',
#   'authorized',
#   'proceedings',
#   'related',
#   'party',
#   'bankruptcy',
#   'insolvency',
#   'liquidation',
#   'dissolution',
#   'winding'],
#  ['party', 'representations'],
#  ['disclosure', 'schedule'],
#  ['party', 'disclosure', 'schedule', 'lists', 'exceptions', 'representations'],
#  [],
#  ['ownership', 'intellectual', 'property'],
#  ['except',
#   'disclosed',
#   'party',
#   'disclosure',
#   'schedule',
#   'party',
#   'owner',
#   'intellectual',
#   'property',
#   'rights',
#   'included',
#   'software',
#   'granted',
#   'deliverable'],
#  ['exclusive', 'right', 'grant', 'deliverable'],
#  ['maintenance', 'intellectual', 'property'],
#  ['party',
#   'properly',
#   'maintained',
#   'intellectual',
#   'property',
#   'rights',
#   'licensed',
#   'deliverable',
#   'including',
#   'paying',
#   'applicable',
#   'registration',
#   'maintenance',
#   'fees'],
#  ['prior', 'grant', 'transfer'],
#  ['party',
#   'granted',
#   'obligated',
#   'grant',
#   'license',
#   'third',
#   'party',
#   'would',
#   'conflict',
#   'deliverable',
#   'agreement',
#   'infringement'],
#  ['party',
#   'knowledge',
#   'software',
#   'infringe',
#   'intellectual',
#   'property',
#   'rights',
#   'rights',
#   'third',
#   'party'],
#  ['third', 'party', 'infringement'],
#  ['except',
#   'disclosed',
#   'party',
#   'disclosure',
#   'schedule',
#   'party',
#   'knowledge',
#   'third',
#   'party',
#   'infringing',
#   'intellectual',
#   'property',
#   'rights',
#   'software'],
#  ['public', 'domain'],
#  ['software', 'public', 'domain'],
#  [],
#  ['warranty'],
#  ['licensed', 'software', 'provided', 'faults', 'defects', 'bugs', 'errors'],
#  ['warranty'],
#  ['unless', 'otherwise', 'listed', 'agreement'],
#  ['party',
#   'make',
#   'warranty',
#   'regarding',
#   'licensed',
#   'software',
#   'includes'],
#  ['party',
#   'disclaims',
#   'fullest',
#   'extent',
#   'authorized',
#   'law',
#   'warranties',
#   'whether',
#   'express',
#   'implied',
#   'including',
#   'implied',
#   'warranties',
#   'title',
#   'non',
#   'infringement',
#   'quiet',
#   'enjoyment',
#   'integration',
#   'merchantability',
#   'fitness',
#   'particular',
#   'purpose'],
#  [],
#  ['intellectual', 'property'],
#  ['party',
#   'retain',
#   'exclusive',
#   'interest',
#   'ownership',
#   'intellectual',
#   'property',
#   'rights',
#   'software',
#   'expressly',
#   'reserves',
#   'rights',
#   'expressly',
#   'granted',
#   'agreement'],
#  [],
#  ['government', 'end', 'users', 'commercial', 'software'],
#  ['licensed',
#   'software',
#   'related',
#   'documentation',
#   'supplied',
#   'purchased',
#   'behalf',
#   'united',
#   'states',
#   'government',
#   'licensed',
#   'software',
#   'deemed',
#   'commercial',
#   'software',
#   'term',
#   'used',
#   'federal',
#   'acquisition',
#   'regulation',
#   'system',
#   'rights',
#   'united',
#   'states',
#   'exceed',
#   'minimum',
#   'rights',
#   'listed',
#   'far',
#   'restricted',
#   'computer',
#   'software'],
#  ['terms', 'apply'],
#  ['terms', 'conditions', 'agreement', 'otherwise', 'apply'],
#  [],
#  ['party', 'data', 'collect', 'use', 'data'],
#  ['party',
#   'may',
#   'collect',
#   'use',
#   'technical',
#   'information',
#   'gathered',
#   'part',
#   'maintenance',
#   'support',
#   'training',
#   'services',
#   'purpose',
#   'improving',
#   'products',
#   'services'],
#  ['non', 'disclosure'],
#  ['party',
#   'disclose',
#   'information',
#   'form',
#   'personally',
#   'identifies',
#   'party',
#   'party',
#   'clients'],
#  [],
#  ['compliance', 'laws'],
#  ['party',
#   'comply',
#   'applicable',
#   'laws',
#   'relating',
#   'subject',
#   'matter',
#   'agreement',
#   'notify',
#   'party',
#   'becomes',
#   'aware',
#   'non',
#   'compliance',
#   'connection',
#   'section'],
#  [],
#  ['export', 'control', 'laws'],
#  ['party',
#   'shall',
#   'obtain',
#   'permits',
#   'necessary',
#   'otherwise',
#   'comply',
#   'laws',
#   'export',
#   'control',
#   'applicable',
#   'agreement',
#   'transactions',
#   'contemplated',
#   'agreement'],
#  [],
#  ['source', 'code', 'escrow'],
#  ['party',
#   'written',
#   'request',
#   'party',
#   'shall',
#   'place',
#   'source',
#   'code',
#   'software',
#   'escrow',
#   'escrow',
#   'company',
#   'name',
#   'escrow',
#   'company',
#   'party',
#   'benefit',
#   'subject',
#   'party',
#   'execution',
#   'terms',
#   'conditions',
#   'party',
#   'standard',
#   'form',
#   'software',
#   'escrow',
#   'agreement',
#   'escrow',
#   'company',
#   'party',
#   'payment',
#   'applicable',
#   'escrow',
#   'fees'],
#  [],
#  ['confidentiality', 'obligations'],
#  ['parties',
#   'continue',
#   'bound',
#   'terms',
#   'non',
#   'disclosure',
#   'agreement',
#   'parties',
#   'dated',
#   'date',
#   'attached',
#   'agreement',
#   'attachment'],
#  [],
#  ['publicity', 'consent'],
#  ['neither',
#   'party',
#   'use',
#   'party',
#   'name',
#   'logo',
#   'trademarks',
#   'issue',
#   'press',
#   'release',
#   'public',
#   'announcement',
#   'regarding',
#   'agreement',
#   'without',
#   'party',
#   'written',
#   'consent',
#   'unless',
#   'specifically',
#   'permitted',
#   'agreement',
#   'required',
#   'law'],
#  ['cooperation'],
#  ['parties',
#   'cooperate',
#   'draft',
#   'appropriate',
#   'press',
#   'releases',
#   'public',
#   'announcements',
#   'relating',
#   'subject',
#   'matter',
#   'agreement',
#   'relationship',
#   'parties'],
#  ['unreasonable', 'delay'],
#  ['parties',
#   'unreasonably',
#   'withhold',
#   'delay',
#   'consent',
#   'press',
#   'releases',
#   'public',
#   'announcements'],
#  [],
#  ['termination', 'termination', 'notice'],
#  ['either',
#   'party',
#   'may',
#   'terminate',
#   'agreement',
#   'reason',
#   'termination',
#   'notice',
#   'business',
#   'days',
#   'business',
#   'days',
#   'notice',
#   'party'],
#  ['termination', 'material', 'breach'],
#  ['party',
#   'may',
#   'terminate',
#   'agreement',
#   'immediate',
#   'effect',
#   'delivering',
#   'notice',
#   'termination',
#   'party',
#   'party',
#   'fails',
#   'perform',
#   'made',
#   'makes',
#   'inaccuracy',
#   'otherwise',
#   'materially',
#   'breaches',
#   'obligations',
#   'covenants',
#   'representations',
#   'failure',
#   'inaccuracy',
#   'breach',
#   'continues',
#   'period',
#   'breach',
#   'continuation',
#   'days',
#   'business',
#   'days',
#   'injured',
#   'party',
#   'delivers',
#   'notice',
#   'breaching',
#   'party',
#   'reasonably',
#   'detailing',
#   'breach'],
#  [],
#  ['effect', 'termination', 'payment', 'obligations'],
#  ['expiration',
#   'termination',
#   'agreement',
#   'party',
#   'shall',
#   'pay',
#   'amounts',
#   'owes',
#   'party',
#   'including',
#   'payment',
#   'obligations',
#   'services',
#   'already',
#   'rendered',
#   'work',
#   'already',
#   'performed',
#   'goods',
#   'already',
#   'delivered',
#   'expenses',
#   'already',
#   'incurred',
#   'refund',
#   'payments',
#   'received',
#   'yet',
#   'earned',
#   'including',
#   'payments',
#   'services',
#   'rendered',
#   'work',
#   'performed',
#   'goods',
#   'delivered',
#   'expenses',
#   'forwarded'],
#  ['termination', 'license', 'grant'],
#  ['expiration',
#   'termination',
#   'agreement',
#   'deliverable',
#   'granted',
#   'agreement',
#   'terminate',
#   'immediate',
#   'effect'],
#  [],
#  ['return', 'property'],
#  ['termination',
#   'expiration',
#   'agreement',
#   'party',
#   'request',
#   'party',
#   'return',
#   'party',
#   'originals',
#   'information',
#   'property',
#   'including',
#   'intellectual',
#   'property',
#   'received',
#   'party',
#   'destroy',
#   'copies',
#   'information',
#   'property',
#   'possession',
#   'control',
#   'party',
#   'request',
#   'certify',
#   'party',
#   'writing',
#   'destroyed',
#   'copies'],
#  [],
#  ['indemnification', 'indemnification', 'party'],
#  ['party',
#   'indemnifying',
#   'party',
#   'shall',
#   'indemnify',
#   'party',
#   'indemnified',
#   'party',
#   'losses',
#   'expenses',
#   'connection',
#   'proceeding',
#   'arising'],
#  ['party', 'use', 'software'],
#  ['party',
#   'unauthorized',
#   'customization',
#   'modification',
#   'alterations',
#   'software',
#   'including',
#   'claims',
#   'customization',
#   'modification',
#   'alterations',
#   'infringe',
#   'third',
#   'party',
#   'intellectual',
#   'property',
#   'rights',
#   'mutual',
#   'indemnification'],
#  ['party',
#   'indemnifying',
#   'party',
#   'shall',
#   'indemnify',
#   'indemnified',
#   'party',
#   'losses',
#   'connection',
#   'proceeding',
#   'arising',
#   'indemnifying',
#   'party',
#   'willful',
#   'misconduct',
#   'gross',
#   'negligence'],
#  ['notice', 'failure', 'notify'],
#  ['notice', 'requirement'],
#  ['bringing',
#   'claim',
#   'indemnification',
#   'indemnified',
#   'party',
#   'shall',
#   'notify',
#   'indemnifying',
#   'party',
#   'indemnifiable',
#   'proceeding'],
#  ['deliver',
#   'indemnifying',
#   'party',
#   'legal',
#   'pleadings',
#   'documents',
#   'reasonably',
#   'necessary',
#   'indemnify',
#   'defend',
#   'indemnifiable',
#   'proceeding'],
#  [],
#  ['failure', 'notify'],
#  ['indemnified',
#   'party',
#   'fails',
#   'notify',
#   'indemnifying',
#   'party',
#   'indemnifiable',
#   'proceeding',
#   'indemnifying',
#   'relieved',
#   'indemnification',
#   'obligations',
#   'extent',
#   'prejudiced',
#   'indemnified',
#   'party',
#   'failure'],
#  ['exclusive', 'remedy'],
#  ['parties',
#   'right',
#   'indemnification',
#   'exclusive',
#   'remedy',
#   'available',
#   'connection',
#   'indemnifiable',
#   'proceedings',
#   'described',
#   'section',
#   'indemnification'],
#  [],
#  ['limitation', 'liability'],
#  ['neither',
#   'party',
#   'liable',
#   'breach',
#   'contract',
#   'damages',
#   'remote',
#   'speculative',
#   'breaching',
#   'party',
#   'could',
#   'reasonably',
#   'foreseen',
#   'entry',
#   'agreement'],
#  [],
#  ['definitions',
#   'books',
#   'records',
#   'means',
#   'books',
#   'records',
#   'including',
#   'books',
#   'account',
#   'ledgers',
#   'general',
#   'financial',
#   'accounting',
#   'records',
#   'machinery',
#   'equipment',
#   'maintenance',
#   'files',
#   'lists',
#   'parties',
#   'prospects',
#   'franchise',
#   'agreements',
#   'supplier',
#   'lists',
#   'production',
#   'data',
#   'quality',
#   'control',
#   'records',
#   'procedures',
#   'customer',
#   'complaints',
#   'inquiry',
#   'files',
#   'research',
#   'development',
#   'files',
#   'records',
#   'data',
#   'including',
#   'correspondence',
#   'governmental',
#   'authority',
#   'sales',
#   'material',
#   'records',
#   'including',
#   'pricing',
#   'history',
#   'sales',
#   'pricing',
#   'policies',
#   'practices',
#   'strategic',
#   'plans',
#   'marketing',
#   'promotional',
#   'surveys',
#   'material',
#   'research',
#   'files',
#   'relating',
#   'intellectual',
#   'property'],
#  ['business',
#   'day',
#   'means',
#   'day',
#   'saturday',
#   'sunday',
#   'day',
#   'principal',
#   'banks',
#   'located',
#   'new',
#   'york',
#   'new',
#   'york',
#   'open',
#   'business'],
#  ['disclosure',
#   'schedule',
#   'means',
#   'schedules',
#   'delivered',
#   'execution',
#   'agreement',
#   'party',
#   'party',
#   'list',
#   'among',
#   'things',
#   'items',
#   'disclosure',
#   'necessary',
#   'appropriate',
#   'either',
#   'response',
#   'express',
#   'disclosure',
#   'requirement',
#   'contained',
#   'provision',
#   'agreement',
#   'exception',
#   'one',
#   'representations',
#   'warranties',
#   'made',
#   'party',
#   'one',
#   'covenants',
#   'party'],
#  ['effective', 'date', 'defined', 'introduction', 'agreement'],
#  ['escrow',
#   'company',
#   'defined',
#   'section',
#   'source',
#   'code',
#   'escrow',
#   'include',
#   'including',
#   'optional',
#   'source',
#   'code',
#   'escrow',
#   'clause',
#   'governmental',
#   'authority',
#   'means',
#   'federal',
#   'state',
#   'local',
#   'foreign',
#   'government',
#   'political',
#   'subdivision',
#   'agency',
#   'instrumentality',
#   'government',
#   'political',
#   'subdivision',
#   'self',
#   'regulated',
#   'organization',
#   'non',
#   'governmental',
#   'regulatory',
#   'authority',
#   'quasi',
#   'governmental',
#   'authority',
#   'extent',
#   'rules',
#   'regulations',
#   'orders',
#   'force',
#   'law',
#   'arbitrator',
#   'court',
#   'tribunal',
#   'competent',
#   'jurisdiction'],
#  ['intellectual',
#   'property',
#   'means',
#   'following',
#   'jurisdiction',
#   'throughout',
#   'world',
#   'trademarks',
#   'service',
#   'marks',
#   'including',
#   'applications',
#   'registrations',
#   'goodwill',
#   'connected',
#   'use',
#   'symbolized',
#   'foregoing',
#   'copyrights',
#   'including',
#   'applications',
#   'registrations',
#   'related',
#   'foregoing',
#   'trade',
#   'secrets',
#   'confidential',
#   'know',
#   'patents',
#   'patent',
#   'applications',
#   'websites',
#   'internet',
#   'domain',
#   'name',
#   'registrations',
#   'intellectual',
#   'property',
#   'related',
#   'proprietary',
#   'rights',
#   'interests',
#   'protections',
#   'including',
#   'rights',
#   'sue',
#   'recover',
#   'retain',
#   'damages',
#   'costs',
#   'attorneys',
#   'fees',
#   'past',
#   'present',
#   'future',
#   'infringement',
#   'rights',
#   'relating',
#   'foregoing'],
#  ['law',
#   'means',
#   'law',
#   'including',
#   'common',
#   'law',
#   'statute',
#   'bylaw',
#   'rule',
#   'regulation',
#   'order',
#   'ordinance',
#   'treaty',
#   'decree',
#   'judgment',
#   'official',
#   'directive',
#   'protocol',
#   'code',
#   'guideline',
#   'notice',
#   'approval',
#   'order',
#   'policy',
#   'requirement',
#   'governmental',
#   'authority',
#   'force',
#   'law'],
#  ['legal',
#   'proceeding',
#   'means',
#   'claim',
#   'investigation',
#   'hearing',
#   'legal',
#   'action',
#   'legal',
#   'administrative',
#   'arbitral',
#   'similar',
#   'proceeding',
#   'whether',
#   'civil',
#   'criminal',
#   'including',
#   'appeal',
#   'review',
#   'foregoing'],
#  ['license', 'fee', 'defined', 'section', 'license', 'fees'],
#  ['license', 'grant', 'defined', 'section', 'license', 'grant'],
#  ['order',
#   'means',
#   'decision',
#   'order',
#   'judgment',
#   'award',
#   'similar',
#   'order',
#   'court',
#   'competent',
#   'jurisdiction',
#   'arbitration',
#   'panel',
#   'governmental',
#   'authority',
#   'jurisdiction',
#   'subject',
#   'matter',
#   'whether',
#   'preliminary',
#   'final'],
#  ['permits',
#   'means',
#   'material',
#   'licenses',
#   'franchises',
#   'permits',
#   'certificates',
#   'approvals',
#   'authorizations',
#   'governmental',
#   'authorities',
#   'necessary',
#   'ownership',
#   'operation',
#   'party',
#   'business'],
#  ['person',
#   'includes',
#   'corporation',
#   'company',
#   'limited',
#   'liability',
#   'company',
#   'partnership',
#   'governmental',
#   'authority',
#   'joint',
#   'venture',
#   'fund',
#   'trust',
#   'association',
#   'syndicate',
#   'organization',
#   'entity',
#   'group',
#   'persons',
#   'whether',
#   'incorporated',
#   'individual'],
#  ['software', 'defined', 'section', 'license', 'grant'],
#  ['taxes',
#   'includes',
#   'taxes',
#   'assessments',
#   'charges',
#   'duties',
#   'fees',
#   'levies',
#   'charges',
#   'governmental',
#   'authority',
#   'including',
#   'income',
#   'franchise',
#   'capital',
#   'stock',
#   'real',
#   'property',
#   'personal',
#   'property',
#   'tangible',
#   'withholding',
#   'employment',
#   'payroll',
#   'social',
#   'security',
#   'social',
#   'contribution',
#   'unemployment',
#   'compensation',
#   'disability',
#   'transfer',
#   'sales',
#   'use',
#   'excise',
#   'gross',
#   'receipts',
#   'value',
#   'added',
#   'taxes',
#   'kind',
#   'party',
#   'may',
#   'liability',
#   'imposed',
#   'governmental',
#   'authority',
#   'whether',
#   'disputed',
#   'related',
#   'charges',
#   'interest',
#   'penalties',
#   'imposed',
#   'governmental',
#   'authority',
#   'liability',
#   'person',
#   'transferee',
#   'successor',
#   'law',
#   'contract',
#   'otherwise'],
#  ['term', 'defined', 'section', 'term'],
#  [],
#  ['general', 'provisions', 'entire', 'agreement'],
#  ['parties',
#   'intend',
#   'agreement',
#   'together',
#   'attachments',
#   'schedules',
#   'exhibits',
#   'documents',
#   'referenced',
#   'agreement',
#   'refer',
#   'agreement',
#   'represent',
#   'final',
#   'expression',
#   'parties',
#   'intent',
#   'relating',
#   'subject',
#   'matter',
#   'agreement',
#   'contain',
#   'terms',
#   'parties',
#   'agreed',
#   'relating',
#   'subject',
#   'matter',
#   'replace',
#   'parties',
#   'previous',
#   'discussions',
#   'understandings',
#   'agreements',
#   'relating',
#   'subject',
#   'matter',
#   'agreement'],
#  ['counterparts'],
#  ['signed', 'counterparts'],
#  ['agreement', 'may', 'signed', 'number', 'counterparts'],
#  [],
#  ['counterparts', 'original'],
#  ['counterpart', 'original'],
#  ['counterparts', 'form', 'one', 'document'],
#  ['together', 'counterparts', 'form', 'one', 'single', 'document'],
#  ['amendment'],
#  ['agreement', 'amended', 'writing', 'signed', 'parties'],
#  ['relationship', 'parties'],
#  ['relationship'],
#  ['nothing',
#   'agreement',
#   'creates',
#   'special',
#   'relationship',
#   'parties',
#   'partnership',
#   'joint',
#   'venture',
#   'employee',
#   'employer',
#   'relationship',
#   'parties'],
#  [],
#  ['authority'],
#  ['neither',
#   'party',
#   'authority',
#   'act',
#   'agent',
#   'behalf',
#   'party',
#   'represent',
#   'bind',
#   'party',
#   'manner'],
#  ['assignment'],
#  ['neither',
#   'party',
#   'may',
#   'assign',
#   'agreement',
#   'rights',
#   'obligations',
#   'agreement',
#   'without',
#   'party',
#   'written',
#   'consent'],
#  ['notices'],
#  ['method', 'notice'],
#  ['parties',
#   'give',
#   'notices',
#   'communications',
#   'parties',
#   'writing',
#   'personal',
#   'delivery',
#   'nationally',
#   'recognized',
#   'next',
#   'day',
#   'courier',
#   'service',
#   'iii',
#   'first',
#   'class',
#   'registered',
#   'certified',
#   'mail',
#   'postage',
#   'prepaid',
#   'address',
#   'party',
#   'notified',
#   'party',
#   'address',
#   'purposes',
#   'section'],
#  [],
#  ['receipt', 'notice'],
#  ['notice', 'given', 'agreement', 'effective', 'party', 'receipt'],
#  ['mailed',
#   'earlier',
#   'party',
#   'receipt',
#   'fifth',
#   'business',
#   'day',
#   'mailing'],
#  ['governing', 'law', 'consent', 'jurisdiction', 'venue'],
#  ['governing', 'law'],
#  ['agreement',
#   'dispute',
#   'arising',
#   'subject',
#   'matter',
#   'agreement',
#   'shall',
#   'governed',
#   'laws',
#   'state',
#   'governing',
#   'law',
#   'state'],
#  [],
#  ['consent', 'jurisdiction'],
#  ['party',
#   'hereby',
#   'irrevocably',
#   'consents',
#   'exclusive',
#   'nonexclusive',
#   'jurisdiction',
#   'venue',
#   'state',
#   'federal',
#   'court',
#   'located',
#   'within',
#   'venue',
#   'county',
#   'county',
#   'state',
#   'venue',
#   'state',
#   'connection',
#   'matter',
#   'arising',
#   'agreement',
#   'plan',
#   'transactions',
#   'contemplated',
#   'agreement',
#   'plan'],
#  ['consent', 'service'],
#  ['party',
#   'hereby',
#   'irrevocably',
#   'agrees',
#   'process',
#   'may',
#   'served',
#   'manner',
#   'authorized',
#   'laws',
#   'state',
#   'governing',
#   'law',
#   'state'],
#  ['waives',
#   'objection',
#   'might',
#   'otherwise',
#   'service',
#   'process',
#   'laws',
#   'state',
#   'governing',
#   'law',
#   'state'],
#  ['dispute', 'resolution'],
#  ['arbitration'],
#  ['dispute',
#   'controversy',
#   'arising',
#   'agreement',
#   'subject',
#   'matter',
#   'agreement',
#   'settled',
#   'arbitration',
#   'state',
#   'according',
#   'rules',
#   'american',
#   'arbitration',
#   'association',
#   'effect',
#   'number',
#   'arbitrators',
#   'arbitrators'],
#  [],
#  ['judgment'],
#  ['judgment',
#   'may',
#   'entered',
#   'arbitrator',
#   'award',
#   'court',
#   'jurisdiction'],
#  ['arbitrator', 'authority'],
#  ['arbitrator', 'power', 'award', 'punitive', 'consequential', 'damages'],
#  ['equitable', 'relief'],
#  ['acknowledgment', 'irreparable', 'harm'],
#  ['party',
#   'acknowledges',
#   'breach',
#   'threatened',
#   'breach',
#   'obligations',
#   'agreement',
#   'would',
#   'result',
#   'irreparable',
#   'harm',
#   'party',
#   'cannot',
#   'adequately',
#   'relieved',
#   'money',
#   'damages',
#   'alone'],
#  [],
#  ['intent', 'allow', 'equitable', 'remedies'],
#  ['accordingly',
#   'parties',
#   'hereby',
#   'acknowledge',
#   'mutual',
#   'intent',
#   'breach',
#   'obligations',
#   'listed',
#   'paragraph',
#   'directly',
#   'non',
#   'breaching',
#   'party',
#   'may',
#   'request',
#   'applicable',
#   'equitable',
#   'remedies',
#   'court',
#   'including',
#   'injunctive',
#   'relief',
#   'without',
#   'need',
#   'party',
#   'post',
#   'security'],
#  ['waiver'],
#  ['affirmative', 'waivers'],
#  ['neither',
#   'party',
#   'failure',
#   'neglect',
#   'enforce',
#   'rights',
#   'agreement',
#   'deemed',
#   'waiver',
#   'party',
#   'rights'],
#  [],
#  ['written', 'waivers'],
#  ['waiver',
#   'extension',
#   'effective',
#   'writing',
#   'signed',
#   'party',
#   'granting'],
#  ['general', 'waivers'],
#  ['party',
#   'failure',
#   'neglect',
#   'enforce',
#   'rights',
#   'agreement',
#   'deemed',
#   'waiver',
#   'rights'],
#  ['course', 'dealing'],
#  ['single',
#   'partial',
#   'exercise',
#   'right',
#   'remedy',
#   'preclude',
#   'exercise',
#   'right',
#   'remedy'],
#  ['force', 'majeure'],
#  ['neither',
#   'party',
#   'liable',
#   'performance',
#   'delays',
#   'non',
#   'performance',
#   'due',
#   'causes',
#   'beyond',
#   'reasonable',
#   'control',
#   'except',
#   'payment',
#   'obligations'],
#  ['severability'],
#  ['part',
#   'agreement',
#   'declared',
#   'unenforceable',
#   'invalid',
#   'remainder',
#   'continue',
#   'valid',
#   'enforceable'],
#  ['survival'],
#  ['parties',
#   'obligations',
#   'sections',
#   'confidentiality',
#   'obligations',
#   'noncompetition',
#   'obligation',
#   'effect',
#   'termination',
#   'survive',
#   'termination',
#   'expiration',
#   'closing',
#   'date',
#   'agreement'],
#  ['headings'],
#  ['section',
#   'headings',
#   'contained',
#   'agreement',
#   'reference',
#   'purposes',
#   'shall',
#   'affect',
#   'meaning',
#   'interpretation',
#   'agreement'],
#  ['attorney', 'fees'],
#  ['either',
#   'party',
#   'brings',
#   'action',
#   'enforce',
#   'rights',
#   'agreement',
#   'prevailing',
#   'party',
#   'may',
#   'recover',
#   'expenses',
#   'including',
#   'reasonable',
#   'attorneys',
#   'fees',
#   'incurred',
#   'connection',
#   'action',
#   'appeal',
#   'losing',
#   'party'],
#  ['agreement', 'signed', 'parties'],
#  ['party',
#   'name',
#   'party',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'name',
#   'party',
#   'signatory',
#   'name',
#   'title',
#   'party',
#   'signatory',
#   'title',
#   'title',
#   'party',
#   'signatory',
#   'title'],
#  ['company',
#   'name',
#   'board',
#   'resolution',
#   'meeting',
#   'board',
#   'directors',
#   'company',
#   'name',
#   'meeting',
#   'date',
#   'following',
#   'resolutions',
#   'proposed',
#   'approved',
#   'board'],
#  ['resolved',
#   'person',
#   'whose',
#   'name',
#   'set',
#   'forth',
#   'exhibit',
#   'shall',
#   'granted',
#   'option',
#   'option',
#   'collectively',
#   'options',
#   'purchase',
#   'number',
#   'shares',
#   'company',
#   'common',
#   'stock',
#   'listed',
#   'exhibit'],
#  ['resolved',
#   'option',
#   'grants',
#   'vesting',
#   'schedule',
#   'terms',
#   'conditions',
#   'grant',
#   'set',
#   'forth',
#   'company',
#   'stock',
#   'option',
#   'plan',
#   'dated',
#   'stock',
#   'option',
#   'agreement',
#   'executed',
#   'person',
#   'granted',
#   'option'],
#  ['whereas',
#   'board',
#   'considered',
#   'following',
#   'factors',
#   'determining',
#   'fair',
#   'market',
#   'value',
#   'company',
#   'common',
#   'stock',
#   'value',
#   'tangible',
#   'intangible',
#   'assets',
#   'company',
#   'present',
#   'value',
#   'future',
#   'cash',
#   'flows',
#   'public',
#   'trading',
#   'price',
#   'private',
#   'sale',
#   'price',
#   'comparable',
#   'companies',
#   'control',
#   'premiums',
#   'discounts',
#   'lack',
#   'marketability',
#   'whether',
#   'method',
#   'used',
#   'purposes',
#   'whether',
#   'available',
#   'information',
#   'taken',
#   'account',
#   'determining',
#   'value'],
#  ['whereas',
#   'accordance',
#   'factors',
#   'board',
#   'determined',
#   'fair',
#   'market',
#   'value',
#   'company',
#   'common',
#   'stock',
#   'stock',
#   'value',
#   'per',
#   'share'],
#  ['resolved',
#   'based',
#   'factors',
#   'board',
#   'analysis',
#   'detailed',
#   'fair',
#   'market',
#   'value',
#   'company',
#   'common',
#   'stock',
#   'date',
#   'hereof',
#   'hereby',
#   'determined',
#   'stock',
#   'value'],
#  ['resolved',
#   'unless',
#   'otherwise',
#   'set',
#   'forth',
#   'exhibit',
#   'exercise',
#   'price',
#   'options',
#   'shall',
#   'exercise',
#   'price',
#   'per',
#   'share'],
#  ['signed',
#   'president',
#   'chairman',
#   'exhibit',
#   'stock',
#   'option',
#   'grants',
#   'name',
#   'number',
#   'shares',
#   'stock',
#   'plan',
#   'vesting',
#   'schedule'],
#  ['commercial', 'lease', 'lease', 'made', 'lessor', 'tenant'],
#  ['tenant',
#   'hereby',
#   'offers',
#   'lease',
#   'lessor',
#   'real',
#   'property',
#   'located',
#   'city',
#   'state',
#   'california',
#   'common',
#   'address',
#   'real',
#   'property',
#   'upon',
#   'following',
#   'terms',
#   'conditions'],
#  ['document', 'shall', 'hereafter', 'referred', 'lease'],
#  ['terms', 'conditions'],
#  ['term', 'rent'],
#  ['lessor',
#   'leases',
#   'lessee',
#   'real',
#   'property',
#   'term',
#   'years',
#   'commencing',
#   'terminating',
#   'sooner',
#   'provided',
#   'herein',
#   'annual',
#   'rental',
#   'dollars',
#   'payable',
#   'equal',
#   'installments',
#   'advance',
#   'first',
#   'day',
#   'month',
#   'month',
#   'rental',
#   'term',
#   'lease'],
#  ['rental', 'payments', 'shall', 'made', 'lessor', 'address', 'specified'],
#  [],
#  ['option', 'renew'],
#  ['provided',
#   'tenant',
#   'default',
#   'performance',
#   'lease',
#   'tenant',
#   'shall',
#   'option',
#   'renew',
#   'lease',
#   'one',
#   'one',
#   'option',
#   'period',
#   'given',
#   'insert',
#   'number',
#   'additional',
#   'term',
#   'months',
#   'commencing',
#   'expiration',
#   'initial',
#   'lease',
#   'term'],
#  ['terms',
#   'conditions',
#   'lease',
#   'shall',
#   'apply',
#   'renewal',
#   'term',
#   'except',
#   'monthly',
#   'rent',
#   'shall',
#   'sum',
#   'subject',
#   'restrictions',
#   'paragraph'],
#  ['option',
#   'shall',
#   'exercised',
#   'written',
#   'notice',
#   'given',
#   'lessor',
#   'less',
#   'days',
#   'prior',
#   'expiration',
#   'prior',
#   'lease',
#   'term'],
#  ['time',
#   'inserted',
#   'notice',
#   'shall',
#   'given',
#   'ninety',
#   'days',
#   'prior',
#   'expiration',
#   'prior',
#   'lease',
#   'term'],
#  ['notice',
#   'given',
#   'manner',
#   'provided',
#   'herein',
#   'within',
#   'time',
#   'specified',
#   'option',
#   'shall',
#   'lapse',
#   'expire'],
#  [],
#  ['use'],
#  ['tenant',
#   'shall',
#   'use',
#   'occupy',
#   'real',
#   'property',
#   'commercial',
#   'purpose'],
#  ['real', 'property', 'shall', 'used', 'purpose'],
#  [],
#  ['sba', 'provisions'],
#  ['lease',
#   'executed',
#   'lessor',
#   'tenant',
#   'participating',
#   'small',
#   'business',
#   'administration',
#   'loan',
#   'program',
#   'parties',
#   'hereto',
#   'agree',
#   'acknowledge',
#   'lease',
#   'shall',
#   'construed',
#   'comply',
#   'requirements',
#   'program',
#   'including',
#   'limited',
#   'found',
#   'title',
#   'code',
#   'federal',
#   'regulations',
#   'sba',
#   'standard',
#   'operating',
#   'procedures',
#   'relevant',
#   'statutes',
#   'laws',
#   'codes',
#   'regulations',
#   'procedures'],
#  ['without',
#   'limiting',
#   'applicability',
#   'relevant',
#   'law',
#   'following',
#   'conditions',
#   'shall',
#   'apply',
#   'tenant',
#   'shall',
#   'lease',
#   'lessor',
#   'real',
#   'property',
#   'lease',
#   'shall',
#   'junior',
#   'subordinate',
#   'deeds',
#   'trust',
#   'favor',
#   'sba',
#   'relate',
#   'real',
#   'property',
#   'annual',
#   'rent',
#   'hereunder',
#   'shall',
#   'exceed',
#   'annual',
#   'payments',
#   'deed',
#   'trust',
#   'favor',
#   'sba',
#   'secured',
#   'real',
#   'property',
#   'annual',
#   'payments',
#   'deeds',
#   'trust',
#   'senior',
#   'sba',
#   'deed',
#   'trust',
#   'taxes',
#   'insurance',
#   'maintenance'],
#  ['lease', 'shall', 'assigned', 'collateral', 'purposes', 'sba'],
#  ['term',
#   'lease',
#   'shall',
#   'expire',
#   'prior',
#   'maturity',
#   'date',
#   'subject',
#   'sba',
#   'loan'],
#  ['provided',
#   'lease',
#   'term',
#   'may',
#   'include',
#   'options',
#   'renew',
#   'lease',
#   'long',
#   'options',
#   'exercisable',
#   'solely',
#   'tenant'],
#  ['leases',
#   'real',
#   'property',
#   'tenant',
#   'shall',
#   'tenant',
#   'third',
#   'party',
#   'subtenant'],
#  [],
#  ['care', 'maintenance', 'real', 'property'],
#  ['tenant',
#   'acknowledges',
#   'real',
#   'property',
#   'good',
#   'order',
#   'repair',
#   'unless',
#   'otherwise',
#   'indicated',
#   'herein'],
#  ['tenant',
#   'shall',
#   'expense',
#   'times',
#   'maintain',
#   'real',
#   'property',
#   'good',
#   'safe',
#   'condition',
#   'including',
#   'plate',
#   'glass',
#   'electrical',
#   'wiring',
#   'plumbing',
#   'heating',
#   'installations',
#   'system',
#   'equipment',
#   'upon',
#   'real',
#   'property',
#   'shall',
#   'surrender',
#   'termination',
#   'hereof',
#   'good',
#   'condition',
#   'received',
#   'normal',
#   'wear',
#   'tear',
#   'excepted'],
#  ['check', 'provision', 'applies'],
#  ['tenant',
#   'shall',
#   'responsible',
#   'repairs',
#   'required',
#   'excepting',
#   'roof',
#   'exterior',
#   'walls',
#   'structural',
#   'foundations',
#   'shall',
#   'maintained',
#   'lessor'],
#  ['tenant',
#   'shall',
#   'also',
#   'maintain',
#   'good',
#   'condition',
#   'portions',
#   'adjacent',
#   'real',
#   'property',
#   'sidewalks',
#   'driveways',
#   'lawns',
#   'shrubbery',
#   'would',
#   'otherwise',
#   'required',
#   'maintained',
#   'lessor'],
#  [],
#  ['alterations'],
#  ['tenant',
#   'shall',
#   'without',
#   'first',
#   'obtaining',
#   'written',
#   'consent',
#   'lessor',
#   'make',
#   'alternations',
#   'additions',
#   'improvements',
#   'real',
#   'property'],
#  [],
#  ['ordinances', 'statutes'],
#  ['tenant',
#   'shall',
#   'comply',
#   'statutes',
#   'ordinances',
#   'regulations',
#   'covenants',
#   'conditions',
#   'requirements',
#   'municipal',
#   'state',
#   'federal',
#   'authorities',
#   'including',
#   'owner',
#   'association',
#   'similar',
#   'entities',
#   'force',
#   'may',
#   'hereafter',
#   'force',
#   'pertaining',
#   'real',
#   'property',
#   'occasioned',
#   'affecting',
#   'use',
#   'thereof',
#   'tenant'],
#  [],
#  ['assignment', 'subletting'],
#  ['tenant',
#   'shall',
#   'assign',
#   'lease',
#   'sublet',
#   'portion',
#   'real',
#   'property',
#   'without',
#   'prior',
#   'written',
#   'consent',
#   'lessor',
#   'shall',
#   'unreasonably',
#   'withheld'],
#  ['assignment',
#   'subletting',
#   'without',
#   'consent',
#   'shall',
#   'void',
#   'option',
#   'lessor',
#   'may',
#   'terminate',
#   'lease'],
#  [],
#  ['utilities'],
#  ['applications',
#   'connections',
#   'necessary',
#   'utility',
#   'services',
#   'real',
#   'property',
#   'shall',
#   'made',
#   'name',
#   'tenant',
#   'tenant',
#   'shall',
#   'solely',
#   'liable',
#   'utility',
#   'charges',
#   'become',
#   'due',
#   'including',
#   'sewer',
#   'water',
#   'gas',
#   'electricity',
#   'telephone',
#   'services'],
#  [],
#  ['entry', 'inspection'],
#  ['tenant',
#   'shall',
#   'permit',
#   'lessor',
#   'lessor',
#   'agents',
#   'lessor',
#   'lenders',
#   'agents',
#   'representatives',
#   'enter',
#   'upon',
#   'real',
#   'property',
#   'reasonable',
#   'times',
#   'upon',
#   'reasonable',
#   'notice',
#   'purpose',
#   'inspecting',
#   'permit',
#   'lessor',
#   'time',
#   'within',
#   'ninety',
#   'days',
#   'prior',
#   'expiration',
#   'lease',
#   'place',
#   'upon',
#   'real',
#   'property',
#   'usual',
#   'let',
#   'lease',
#   'signs',
#   'permit',
#   'persons',
#   'desiring',
#   'lease',
#   'inspect',
#   'real',
#   'property',
#   'thereafter'],
#  [],
#  ['possession'],
#  ['lessor',
#   'unable',
#   'deliver',
#   'possession',
#   'real',
#   'property',
#   'commencement',
#   'hereof',
#   'lessor',
#   'shall',
#   'liable',
#   'damage',
#   'caused',
#   'thereby',
#   'shall',
#   'lease',
#   'void',
#   'voidable',
#   'tenant',
#   'shall',
#   'liable',
#   'rent',
#   'possession',
#   'delivered'],
#  ['tenant',
#   'may',
#   'terminate',
#   'lease',
#   'possession',
#   'delivered',
#   'within',
#   'one',
#   'hundred',
#   'twenty',
#   'days',
#   'commencement',
#   'term',
#   'hereof'],
#  [],
#  ['indemnification', 'lessor'],
#  ['lessor',
#   'shall',
#   'liable',
#   'damage',
#   'injury',
#   'tenant',
#   'person',
#   'property',
#   'occurring',
#   'real',
#   'property',
#   'part',
#   'thereof',
#   'tenant',
#   'agrees',
#   'indemnify',
#   'hold',
#   'lessor',
#   'harmless',
#   'claims',
#   'damages',
#   'matter',
#   'caused',
#   'except',
#   'caused',
#   'sole',
#   'negligence',
#   'sole',
#   'unlawful',
#   'conduct',
#   'lessor'],
#  [],
#  ['insurance'],
#  ['tenant',
#   'tenant',
#   'expense',
#   'shall',
#   'maintain',
#   'plate',
#   'glass',
#   'public',
#   'liability',
#   'insurance',
#   'including',
#   'bodily',
#   'injury',
#   'property',
#   'damage',
#   'insuring',
#   'tenant',
#   'lessor',
#   'minimum',
#   'coverage',
#   'follows',
#   'tenant',
#   'shall',
#   'provide',
#   'lessor',
#   'certificate',
#   'insurance',
#   'showing',
#   'lessor',
#   'additional',
#   'insured'],
#  ['certificate',
#   'shall',
#   'provide',
#   'ten',
#   'day',
#   'written',
#   'notice',
#   'lessor',
#   'event',
#   'cancellation',
#   'material',
#   'change',
#   'coverage'],
#  ['maximum',
#   'extent',
#   'permitted',
#   'insurance',
#   'policies',
#   'may',
#   'owned',
#   'lessor',
#   'tenant',
#   'tenant',
#   'lessor',
#   'benefit',
#   'waive',
#   'rights',
#   'subrogation',
#   'might',
#   'otherwise',
#   'exist'],
#  [],
#  ['eminent', 'domain'],
#  ['real',
#   'property',
#   'part',
#   'thereof',
#   'estate',
#   'therein',
#   'part',
#   'building',
#   'materially',
#   'affecting',
#   'tenant',
#   'use',
#   'real',
#   'property',
#   'shall',
#   'taken',
#   'eminent',
#   'domain',
#   'lease',
#   'shall',
#   'terminate',
#   'date',
#   'title',
#   'vests',
#   'pursuant',
#   'taking'],
#  ['rent',
#   'additional',
#   'rent',
#   'shall',
#   'apportioned',
#   'termination',
#   'date',
#   'rent',
#   'paid',
#   'period',
#   'beyond',
#   'date',
#   'shall',
#   'repaid',
#   'tenant'],
#  ['tenant',
#   'shall',
#   'entitled',
#   'part',
#   'award',
#   'taking',
#   'payment',
#   'lieu',
#   'thereof',
#   'tenant',
#   'may',
#   'file',
#   'claim',
#   'taking',
#   'fixtures',
#   'improvements',
#   'owned',
#   'tenant',
#   'moving',
#   'expenses'],
#  [],
#  ['destruction', 'real', 'property'],
#  ['event',
#   'partial',
#   'destruction',
#   'real',
#   'property',
#   'term',
#   'hereof',
#   'cause',
#   'lessor',
#   'shall',
#   'forthwith',
#   'repair',
#   'provided',
#   'repairs',
#   'made',
#   'within',
#   'sixty',
#   'days',
#   'existing',
#   'governmental',
#   'laws',
#   'regulations',
#   'partial',
#   'destruction',
#   'shall',
#   'terminate',
#   'lease',
#   'except',
#   'tenant',
#   'shall',
#   'entitled',
#   'proportionate',
#   'reduction',
#   'rent',
#   'repairs',
#   'made',
#   'based',
#   'upon',
#   'extent',
#   'making',
#   'repairs',
#   'shall',
#   'interfere',
#   'business',
#   'tenant',
#   'real',
#   'property'],
#  ['repairs',
#   'cannot',
#   'made',
#   'within',
#   'said',
#   'sixty',
#   'days',
#   'lessor',
#   'lessor',
#   'sole',
#   'discretion',
#   'option',
#   'may',
#   'make',
#   'repairs',
#   'within',
#   'reasonable',
#   'time',
#   'lease',
#   'continuing',
#   'effect',
#   'rent',
#   'proportionately',
#   'abated',
#   'provided',
#   'preceding',
#   'sentence',
#   'event',
#   'lessor',
#   'shall',
#   'elect',
#   'make',
#   'repairs',
#   'cannot',
#   'made',
#   'within',
#   'sixty',
#   'days',
#   'lease',
#   'may',
#   'terminated',
#   'option',
#   'either',
#   'party'],
#  ['event',
#   'building',
#   'real',
#   'property',
#   'may',
#   'situated',
#   'destroyed',
#   'extent',
#   'less',
#   'one',
#   'third',
#   'replacement',
#   'costs',
#   'thereof',
#   'lessor',
#   'may',
#   'elect',
#   'terminate',
#   'lease',
#   'whether',
#   'real',
#   'property',
#   'injured'],
#  ['total',
#   'destruction',
#   'building',
#   'real',
#   'property',
#   'may',
#   'situated',
#   'shall',
#   'terminate',
#   'lease'],
#  [],
#  ['lessor', 'remedies', 'default'],
#  ['tenant',
#   'defaults',
#   'payment',
#   'rent',
#   'additional',
#   'rent',
#   'defaults',
#   'performance',
#   'covenants',
#   'conditions',
#   'hereof',
#   'lessor',
#   'may',
#   'give',
#   'tenant',
#   'notice',
#   'default',
#   'tenant',
#   'cure',
#   'default',
#   'within',
#   'shall',
#   'fifteen',
#   'number',
#   'filled',
#   'days',
#   'giving',
#   'notice',
#   'default',
#   'nature',
#   'cannot',
#   'completely',
#   'cured',
#   'within',
#   'period',
#   'tenant',
#   'commence',
#   'curing',
#   'within',
#   'shall',
#   'fifteen',
#   'number',
#   'filled',
#   'days',
#   'thereafter',
#   'proceed',
#   'reasonable',
#   'diligence',
#   'good',
#   'faith',
#   'cure',
#   'default',
#   'lessor',
#   'may',
#   'terminate',
#   'lease',
#   'rights',
#   'lessee',
#   'lease',
#   'written',
#   'notice'],
#  ['terminates',
#   'date',
#   'specified',
#   'notice',
#   'term',
#   'lease',
#   'shall',
#   'terminate',
#   'tenant',
#   'shall',
#   'quit',
#   'surrender',
#   'real',
#   'property',
#   'lessor',
#   'tenant',
#   'shall',
#   'remain',
#   'liable',
#   'hereinafter',
#   'provided'],
#  ['lease',
#   'shall',
#   'terminated',
#   'lessor',
#   'lessor',
#   'may',
#   'time',
#   'thereafter',
#   'resume',
#   'possession',
#   'real',
#   'property',
#   'lawful',
#   'means',
#   'remove',
#   'tenant',
#   'occupants',
#   'effects'],
#  ['failure', 'enforce', 'term', 'shall', 'deemed', 'waiver'],
#  ['act',
#   'lessor',
#   'shall',
#   'construed',
#   'terminating',
#   'lease',
#   'except',
#   'written',
#   'notice',
#   'given',
#   'lessor',
#   'tenant',
#   'advising',
#   'tenant',
#   'lessor',
#   'elects',
#   'terminate',
#   'lease'],
#  ['event',
#   'lessor',
#   'elects',
#   'terminate',
#   'lease',
#   'lessor',
#   'may',
#   'recover',
#   'tenant',
#   'worth',
#   'time',
#   'award',
#   'unpaid',
#   'rent',
#   'earned',
#   'time',
#   'termination',
#   'lease',
#   'worth',
#   'time',
#   'award',
#   'amount',
#   'unpaid',
#   'rent',
#   'would',
#   'earned',
#   'termination',
#   'lease',
#   'time',
#   'award',
#   'exceeds',
#   'amount',
#   'rental',
#   'loss',
#   'tenant',
#   'proves',
#   'could',
#   'reasonably',
#   'avoided',
#   'worth',
#   'time',
#   'award',
#   'amount',
#   'unpaid',
#   'rent',
#   'balance',
#   'term',
#   'lease',
#   'time',
#   'award',
#   'exceeds',
#   'amount',
#   'rental',
#   'loss',
#   'tenant',
#   'proves',
#   'could',
#   'reasonably',
#   'avoided',
#   'amount',
#   'necessary',
#   'compensate',
#   'lessor',
#   'detrimental',
#   'proximately',
#   'caused',
#   'tenant',
#   'failure',
#   'perform',
#   'obligations',
#   'lease'],
#  ['term',
#   'rent',
#   'used',
#   'lease',
#   'shall',
#   'mean',
#   'rent',
#   'sums',
#   'required',
#   'paid',
#   'tenant',
#   'pursuant',
#   'terms',
#   'lease'],
#  ['security', 'deposit'],
#  ['tenant',
#   'shall',
#   'deposit',
#   'lessor',
#   'signing',
#   'lease',
#   'sum',
#   'dollars',
#   'security',
#   'performance',
#   'tenant',
#   'obligations',
#   'lease',
#   'including',
#   'without',
#   'limitation',
#   'surrender',
#   'possession',
#   'real',
#   'property',
#   'lessor',
#   'herein',
#   'provided'],
#  ['lessor',
#   'applies',
#   'part',
#   'deposit',
#   'cure',
#   'default',
#   'tenant',
#   'tenant',
#   'shall',
#   'demand',
#   'deposit',
#   'lessor',
#   'amount',
#   'applied',
#   'lessor',
#   'shall',
#   'full',
#   'deposit',
#   'hand',
#   'times',
#   'term',
#   'lease'],
#  [],
#  ['tax', 'increase'],
#  ['event',
#   'increase',
#   'year',
#   'term',
#   'lease',
#   'real',
#   'property',
#   'taxes',
#   'amount',
#   'taxes',
#   'assessed',
#   'tax',
#   'year',
#   'term',
#   'lease',
#   'commences',
#   'whether',
#   'increased',
#   'rate',
#   'valuation',
#   'otherwise',
#   'tenant',
#   'shall',
#   'pay',
#   'lessor',
#   'upon',
#   'presentation',
#   'paid',
#   'tax',
#   'bills',
#   'amount',
#   'equal',
#   'increase',
#   'taxes',
#   'upon',
#   'land',
#   'building',
#   'real',
#   'property',
#   'situated'],
#  ['event',
#   'taxes',
#   'assessed',
#   'tax',
#   'year',
#   'extending',
#   'beyond',
#   'term',
#   'lease',
#   'obligation',
#   'tenant',
#   'shall',
#   'proportionate',
#   'portion',
#   'lease',
#   'term',
#   'included',
#   'year'],
#  ['tax',
#   'obligations',
#   'lessee',
#   'hereunder',
#   'shall',
#   'added',
#   'become',
#   'part',
#   'rent',
#   'paid',
#   'lease'],
#  [],
#  ['common', 'area', 'expenses'],
#  ['event',
#   'real',
#   'property',
#   'situated',
#   'shopping',
#   'center',
#   'commercial',
#   'building',
#   'complex',
#   'common',
#   'areas',
#   'tenant',
#   'agrees',
#   'pay',
#   'tenant',
#   'pro',
#   'rata',
#   'share',
#   'maintenance',
#   'taxes',
#   'insurance',
#   'common',
#   'area'],
#  ['obligations',
#   'tenant',
#   'hereafter',
#   'shall',
#   'added',
#   'become',
#   'part',
#   'rent',
#   'paid',
#   'lease'],
#  [],
#  ['attorney', 'fees'],
#  ['case',
#   'suit',
#   'brought',
#   'recovery',
#   'real',
#   'property',
#   'sum',
#   'due',
#   'hereunder',
#   'act',
#   'may',
#   'arise',
#   'possession',
#   'real',
#   'property',
#   'either',
#   'party',
#   'prevailing',
#   'party',
#   'shall',
#   'entitled',
#   'costs',
#   'incurred',
#   'connection',
#   'action',
#   'including',
#   'reasonable',
#   'attorney',
#   'fee'],
#  [],
#  ['waiver'],
#  ['failure',
#   'lessor',
#   'enforce',
#   'term',
#   'hereof',
#   'shall',
#   'deemed',
#   'waiver'],
#  [],
#  ['notices'],
#  ['notice',
#   'either',
#   'party',
#   'may',
#   'required',
#   'give',
#   'shall',
#   'given',
#   'personal',
#   'delivery',
#   'mailing',
#   'postage',
#   'prepaid',
#   'tenant',
#   'real',
#   'property',
#   'address',
#   'indicated',
#   'lessor',
#   'address',
#   'specified',
#   'places',
#   'may',
#   'designated',
#   'parties',
#   'time',
#   'time'],
#  [],
#  ['heirs', 'assigns', 'successors'],
#  ['lease',
#   'binding',
#   'upon',
#   'inures',
#   'benefit',
#   'heirs',
#   'assigns',
#   'successors',
#   'interest',
#   'parties'],
#  [],
#  ['subordination'],
#  ['lease',
#   'shall',
#   'subordinated',
#   'existing',
#   'future',
#   'liens',
#   'mortgages',
#   'deeds',
#   'trust',
#   'ground',
#   'leases',
#   'hypothecations',
#   'security',
#   'devices',
#   'encumbrances',
#   'security',
#   'instruments',
#   'real',
#   'property',
#   'hereafter',
#   'placed',
#   'upon',
#   'real',
#   'property',
#   'advances',
#   'made',
#   'said',
#   'security',
#   'instruments'],
#  ['tenant',
#   'covenants',
#   'agrees',
#   'execute',
#   'deliver',
#   'upon',
#   'demand',
#   'instruments',
#   'reasonably',
#   'necessary',
#   'effect',
#   'subordination'],
#  ['self',
#   'executing',
#   'agreements',
#   'contained',
#   'paragraph',
#   'shall',
#   'effective',
#   'without',
#   'execution',
#   'documents',
#   'power',
#   'given',
#   'herein',
#   'coupled',
#   'interest',
#   'irrevocable'],
#  ['provided',
#   'upon',
#   'written',
#   'request',
#   'lender',
#   'lessor',
#   'connection',
#   'sale',
#   'financing',
#   'refinancing',
#   'premises',
#   'lessee',
#   'lessor',
#   'shall',
#   'execute',
#   'writings',
#   'may',
#   'reasonably',
#   'required',
#   'separately',
#   'document',
#   'subordination',
#   'attornment',
#   'relevant',
#   'terms',
#   'provided',
#   'herein'],
#  [],
#  ['time', 'essence'],
#  ['time', 'essence', 'performance', 'agreement'],
#  [],
#  ['entire', 'agreement'],
#  ['foregoing',
#   'constitutes',
#   'entire',
#   'agreement',
#   'parties',
#   'may',
#   'modified',
#   'writing',
#   'signed',
#   'parties'],
#  ['following',
#   'exhibits',
#   'made',
#   'part',
#   'lease',
#   'parties',
#   'execution',
#   'hereof'],
#  ['signed', 'day'],
#  ['lessor',
#   'tenant',
#   'print',
#   'name',
#   'title',
#   'print',
#   'name',
#   'title',
#   'address',
#   'address',
#   'different',
#   'real',
#   'property',
#   'address',
#   'wpfiles',
#   'closing',
#   'forms',
#   'workbook',
#   'documents',
#   'real',
#   'property',
#   'commercial',
#   'lease',
#   'epc',
#   'doc'],
#  [],
#  ['aims',
#   'make',
#   'healthcare',
#   'accessible',
#   ',',
#   'understandable',
#   ',',
#   'affordable',
#   'Indians',
#   '.',
#   'It',
#   'offers',
#   'ePharmacy',
#   ',',
#   'eDiagnostics',
#   ',',
#   'health',
#   'information',
#   'enable',
#   'consumers',
#   'better',
#   'manage',
#   'health',
#   '.'],
#  ['Seconds'],
#  ['Seconds',
#   'world',
#   '’',
#   'leading',
#   'cloud',
#   'video',
#   'production',
#   'platform',
#   ',',
#   'allowing',
#   'brands',
#   'purchase',
#   ',',
#   'plan',
#   ',',
#   'shoot',
#   ',',
#   'edit',
#   'review',
#   'video',
#   'anywhere',
#   'world',
#   ',',
#   'online',
#   'mobile',
#   '.'],
#  [],
#  ['one',
#   'fastest-growing',
#   'property',
#   'search',
#   'companies',
#   'Southeast',
#   'Asia',
#   '.'],
#  ['Absolute', 'Foods'],
#  ['Absolute',
#   'Foods',
#   'intersects',
#   'technology',
#   ',',
#   'science',
#   ',',
#   'agriculture',
#   'go',
#   'beyond',
#   'organic',
#   'food',
#   '–',
#   'focusing',
#   'produce',
#   '%',
#   'natural',
#   'Non-GMO',
#   '.'],
#  ['Aerotime'],
#  ['Aerotime',
#   'helps',
#   'users',
#   'work',
#   'flow',
#   'state',
#   'streamlining',
#   'meetings',
#   'making',
#   'easier',
#   'prioritize',
#   'tasks',
#   '.'],
#  ['AI', 'Rudder'],
#  ['AI',
#   'Rudder',
#   'aims',
#   'increase',
#   'scale',
#   ',',
#   'speed',
#   'quality',
#   'customer',
#   'experience',
#   'human-like',
#   'AI',
#   'voice',
#   'assistant',
#   '.'],
#  ['Airmeet'],
#  ['Airmeet',
#   'fastest',
#   'growing',
#   'platform',
#   'hosting',
#   'rich',
#   'variety',
#   'online',
#   'events',
#   'crafting',
#   'virtual',
#   'space',
#   'world',
#   'connect',
#   'collaborate',
#   '.'],
#  ['Akulaku'],
#  ['Akulaku',
#   'Southeast',
#   'Asian',
#   'e-commerce',
#   'platform',
#   'allows',
#   'consumers',
#   'pay',
#   'products',
#   'instalments',
#   'without',
#   'credit',
#   'card',
#   '.'],
#  ['Akumentis', 'Healthcare'],
#  ['Akumentis',
#   'Healthcare',
#   'one',
#   'fastest-growing',
#   'branded',
#   'generics',
#   'companies',
#   'India',
#   '.',
#   'It',
#   'presence',
#   'across',
#   'multiple',
#   'therapeutic',
#   'areas',
#   'holds',
#   'strong',
#   'market',
#   'position',
#   'women',
#   '’',
#   'health',
#   '.'],
#  ['Animall'],
#  ['Animall',
#   'aims',
#   'improve',
#   'lives',
#   'dairy',
#   'farmers',
#   'meaningful',
#   'way',
#   'making',
#   'dairy',
#   'farming',
#   'significantly',
#   'profitable',
#   '.'],
#  ['Apna'],
#  ['Apna',
#   'platform',
#   'creates',
#   'better',
#   'economic',
#   'opportunities',
#   'blue/grey',
#   'collar',
#   'workforce',
#   'globally',
#   '.'],
#  ['Appier'],
#  ['Appier',
#   'builds',
#   'AI-based',
#   'cross-screen',
#   'analytics',
#   'targeting',
#   'platforms',
#   'businesses',
#   'reach',
#   'engage',
#   'customers',
#   'across',
#   'multiple',
#   'smart',
#   'devices',
#   '.'],
#  ['Aptus'],
#  ['Aptus',
#   'Value',
#   'Housing',
#   'Finance',
#   'India',
#   'Ltd',
#   'home',
#   'loan',
#   'company',
#   'addresses',
#   'housing',
#   'finance',
#   'needs',
#   'self-employed',
#   'individuals',
#   'belonging',
#   'low',
#   'middle-income',
#   'families',
#   'semi-urban',
#   'rural',
#   'markets',
#   '.'],
#  ['Arbo', 'Works'],
#  ['Arbo',
#   'Works',
#   'determined',
#   'help',
#   'people',
#   'enjoy',
#   'successful',
#   'financial',
#   'lives',
#   '.'],
#  ['Arrow'],
#  ['Arrow',
#   'Singapore-based',
#   'eCommerce',
#   'solution',
#   'partners',
#   'merchants',
#   'create',
#   'fast',
#   'frictionless',
#   'checkout',
#   'experience',
#   'consumers',
#   '–',
#   'regardless',
#   'location',
#   'channel',
#   'buying',
#   '.'],
#  ['Aspire'],
#  ['Aspire',
#   'all-in-one',
#   'finance',
#   'operating',
#   'system',
#   'growing',
#   'businesses',
#   ',',
#   'helping',
#   'companies',
#   'pay',
#   ',',
#   'manage',
#   ',',
#   'earn',
#   'smarter',
#   '.'],
#  ['Astro'],
#  ['Astro',
#   'Indonesia',
#   '’',
#   'first',
#   'fastest-growing',
#   'on-demand',
#   'platform',
#   'groceries',
#   'essentials',
#   '.'],
#  ['Atlan'],
#  ['Atlan',
#   'modern',
#   'data',
#   'collaboration',
#   'workspace',
#   ',',
#   'enabling',
#   'teams',
#   'create',
#   'single',
#   'source',
#   'truth',
#   'data',
#   'assets',
#   ',',
#   'collaborate',
#   'across',
#   'modern',
#   'data',
#   'stack',
#   '.'],
#  ['Avataar'],
#  ['Avataar',
#   'AI',
#   'company',
#   'helps',
#   'large',
#   'enterprise',
#   'customers',
#   'create',
#   'immersive',
#   'interactive',
#   'shopping',
#   'experiences',
#   'end',
#   'consumers',
#   '.'],
#  ['Awfis'],
#  ['Awfis',
#   'one',
#   'South',
#   'Asia',
#   '’',
#   'largest',
#   'networks',
#   'collaborative',
#   'co-working',
#   'spaces',
#   '.'],
#  ['Band', 'Protocol'],
#  ['Band',
#   'Protocol',
#   'cross-chain',
#   'data',
#   'oracle',
#   'platform',
#   'aggregates',
#   'connects',
#   'real-world',
#   'data',
#   'APIs',
#   'smart',
#   'contracts',
#   'building',
#   'decentralized',
#   'bridge',
#   'enables',
#   'secure',
#   'inter-operabilities',
#   '.'],
#  ['BankBazaar'],
#  ['BankBazaar',
#   'helps',
#   'consumers',
#   'choose',
#   'right',
#   'financial',
#   'product',
#   'needs',
#   '.'],
#  ['Beam'],
#  ['Beam',
#   'offers',
#   'micro-mobility',
#   'solutions',
#   'urban',
#   'dwellers',
#   'across',
#   'APAC',
#   '.'],
#  ['Belong'],
#  ['Belong',
#   'predictive',
#   ',',
#   'outbound',
#   'recruitment',
#   'solution',
#   'helps',
#   'businesses',
#   'discover',
#   ',',
#   'engage',
#   'hire',
#   'talented',
#   'candidates',
#   '.'],
#  ['Beta', 'Finance'],
#  ['Beta',
#   'Finance',
#   'decentralized',
#   'finance',
#   'protocol',
#   'developed',
#   'one-click',
#   'solution',
#   'lending',
#   ',',
#   'borrowing',
#   'shorting',
#   'crypto',
#   'asset',
#   '.'],
#  ['BharatPe'],
#  ['BharatPe',
#   'FinTech',
#   'company',
#   'empowers',
#   'Indian',
#   'merchants',
#   'accept',
#   'UPI',
#   'payments',
#   'customers',
#   'free',
#   'BharatPe',
#   'QR',
#   '.'],
#  ['Bibit'],
#  ['Bibit',
#   'digital',
#   'investing',
#   'app',
#   'robo-advisory',
#   'service',
#   'helps',
#   'first-time',
#   'investors',
#   'invest',
#   'mutual',
#   'fund',
#   'products',
#   '.'],
#  ['Bifrost'],
#  ['Bifrost',
#   'replaces',
#   'tedious',
#   'process',
#   'data',
#   'collection',
#   ',',
#   'curation',
#   ',',
#   '&',
#   'labelling',
#   'generating',
#   'physically-accurate',
#   'worlds',
#   '&',
#   'capturing',
#   'perfectly',
#   'labelled',
#   'datasets',
#   '.'],
#  ['Bijnis'],
#  ['Bijnis',
#   'revolutionising',
#   'unorganised',
#   'manufacturing',
#   'industries',
#   'digitising',
#   'factories',
#   '.',
#   'Its',
#   'goal',
#   'make',
#   'factory',
#   'smarter',
#   ',',
#   'faster',
#   'cost',
#   'effective',
#   'enable',
#   'factory',
#   'owners',
#   'scale',
#   '&',
#   'grow',
#   'business',
#   '.'],
#  ['Bikayi'],
#  ['Bikayi',
#   'empowers',
#   'entrepreneurs',
#   'build',
#   'online',
#   'businesses',
#   'creating',
#   'online',
#   'store',
#   'fully',
#   'customizable',
#   'e-commerce',
#   'website',
#   'less',
#   'seconds',
#   '.'],
#  ['Biofourmis'],
#  ['Biofourmis',
#   'develops',
#   'delivers',
#   'clinically',
#   'validated',
#   'software-based',
#   'therapeutics',
#   '.'],
#  ['Bira'],
#  ['Beverages',
#   'fast-growing',
#   'craft',
#   'beer',
#   'brand',
#   ',',
#   'available',
#   'draft',
#   'bottle',
#   'formats',
#   '.']]

# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary

# %%
dictionary=Dictionary(texts_final)
corpus = [dictionary.doc2bow(text) for text in texts_final]

# %%
print(dictionary)
# Out:
# Dictionary<1462 unique tokens: ['abbreviation', 'address', 'agreement', 'amendment', 'business']...>

# %%
print(corpus)
# Out:
# [[(0, 2), (1, 2), (2, 4), (3, 3), (4, 2), (5, 2), (6, 2), (7, 2), (8, 1), (9, 2), (10, 2), (11, 1), (12, 4), (13, 6), (14, 2), (15, 2)], [], [(16, 1), (17, 1)], [(2, 1), (3, 2), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1)], [], [(3, 1), (23, 1)], [(2, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1)], [(2, 1), (11, 1), (33, 1)], [(34, 1), (35, 1)], [(2, 1), (3, 1), (17, 1), (23, 1), (35, 1), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1)], [], [(43, 1), (44, 1)], [(2, 1), (3, 3), (17, 2), (45, 1), (46, 1), (47, 1)], [(2, 1), (32, 1), (48, 1)], [(12, 6), (13, 6), (49, 4), (50, 4)], [(1, 2), (2, 3), (4, 2), (5, 2), (6, 2), (7, 1), (10, 2), (11, 1), (12, 2), (13, 2), (14, 2), (15, 2), (51, 2), (52, 2), (53, 2), (54, 2)], [(2, 1), (17, 1), (32, 1), (55, 1)], [], [(51, 2), (54, 1), (56, 1)], [(13, 2), (30, 1), (51, 1), (54, 1), (57, 1), (58, 2), (59, 1), (60, 1), (61, 3), (62, 1), (63, 2), (64, 2), (65, 1)], [(66, 1)], [(2, 1), (13, 1), (66, 1), (67, 1), (68, 1), (69, 1), (70, 1)], [(54, 1)], [(2, 1), (54, 3), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1)], [], [(54, 1), (77, 1), (78, 1), (79, 1)], [(7, 1), (9, 1), (13, 4), (54, 2), (77, 1), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 2)], [], [(89, 1), (90, 1), (91, 2)], [(2, 1), (13, 4), (32, 1), (54, 1), (55, 1), (71, 1), (72, 1), (73, 1), (89, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1), (97, 1), (98, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1)], [(90, 1)], [(90, 1), (96, 1)], [(4, 1), (7, 1), (9, 1), (13, 5), (54, 1), (81, 1), (90, 1), (95, 1), (100, 1), (101, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 1), (111, 1), (112, 1), (113, 1), (114, 1)], [(77, 1), (90, 1), (92, 1), (107, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 1), (120, 1), (121, 1), (122, 1), (123, 1)], [], [(90, 1), (124, 1)], [(13, 3), (89, 1), (90, 3), (96, 1), (109, 2), (112, 1), (125, 1), (126, 1), (127, 1), (128, 1), (129, 1), (130, 1), (131, 1), (132, 1), (133, 1)], [], [(89, 1), (134, 1), (135, 2)], [(13, 5), (26, 1), (54, 2), (95, 1), (100, 1), (101, 1), (135, 1), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1)], [(144, 1), (145, 1)], [(13, 3), (54, 2), (95, 1), (100, 1), (101, 1), (105, 1), (111, 1), (143, 1), (144, 1), (146, 1), (147, 1), (148, 1), (149, 1), (150, 1), (151, 1), (152, 1), (153, 1), (154, 1), (155, 1)], [(156, 1)], [(13, 2), (54, 1), (89, 1), (100, 1), (128, 1), (134, 1), (157, 1), (158, 1), (159, 1)], [], [(51, 1), (160, 1)], [(13, 2), (40, 1), (51, 3), (72, 1), (161, 3), (162, 1)], [], [(39, 1), (51, 2), (160, 1), (161, 1), (163, 1)], [(7, 1), (13, 3), (39, 1), (51, 1), (77, 1), (109, 1), (161, 1), (162, 1), (164, 2), (165, 1), (166, 1), (167, 2), (168, 1), (169, 2), (170, 1)], [(171, 1)], [(2, 1), (86, 1), (171, 1), (172, 1), (173, 1)], [(2, 1), (13, 1), (32, 1), (162, 1), (171, 1), (174, 1), (175, 1)], [], [(69, 1), (175, 1), (176, 1)], [(7, 1), (69, 1), (109, 1), (163, 2), (165, 2), (177, 1), (178, 1), (179, 1), (180, 1), (181, 1), (182, 1), (183, 1), (184, 1), (185, 1), (186, 1), (187, 1)], [], [(188, 1), (189, 2), (190, 1)], [(13, 2), (54, 1), (101, 1), (133, 2), (188, 1), (191, 2), (192, 1), (193, 1), (194, 1), (195, 1), (196, 1), (197, 1), (198, 1), (199, 1), (200, 1), (201, 1), (202, 1), (203, 1), (204, 1)], [(189, 1), (205, 1), (206, 1)], [(13, 1), (54, 1), (97, 1), (101, 1), (148, 1), (194, 1), (198, 1), (202, 1), (207, 1), (208, 1), (209, 1), (210, 1), (211, 1), (212, 1), (213, 1), (214, 1), (215, 1), (216, 1), (217, 1), (218, 1), (219, 1), (220, 2), (221, 1)], [(13, 1), (65, 1), (89, 1)], [(13, 1), (65, 2), (101, 1), (133, 3), (174, 1), (214, 1), (222, 1), (223, 1), (224, 1), (225, 1), (226, 1), (227, 1), (228, 1), (229, 1), (230, 1), (231, 1), (232, 2)], [], [(233, 1), (234, 1)], [(13, 1), (51, 1), (54, 4), (66, 1), (148, 1), (235, 2), (236, 1), (237, 1), (238, 1), (239, 1), ...

# %%
ldamodel = LdaModel(corpus=corpus, num_topics=7, id2word=dictionary)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
ldamodel.show_topics()
# Out:
# [(0,
#   '0.024*"property" + 0.021*"real" + 0.020*"lease" + 0.016*"tenant" + 0.014*"software" + 0.011*"agreement" + 0.010*"shall" + 0.010*"lessor" + 0.009*"term" + 0.008*"license"'),
#  (1,
#   '0.042*"party" + 0.028*"shall" + 0.021*"agreement" + 0.018*"property" + 0.011*"tenant" + 0.010*"parties" + 0.010*"lessor" + 0.010*"real" + 0.008*"including" + 0.007*"lease"'),
#  (2,
#   '0.018*"agreement" + 0.014*"party" + 0.009*"shall" + 0.009*"value" + 0.009*"notice" + 0.009*"." + 0.008*"company" + 0.008*"stock" + 0.008*"option" + 0.007*"failure"'),
#  (3,
#   '0.025*"party" + 0.017*"agreement" + 0.010*"lessor" + 0.009*"obligations" + 0.009*"days" + 0.009*"parties" + 0.008*"rights" + 0.008*"lease" + 0.008*"waiver" + 0.008*"property"'),
#  (4,
#   '0.026*"tenant" + 0.018*"," + 0.017*"lessor" + 0.017*"party" + 0.016*"lease" + 0.015*"." + 0.012*"shall" + 0.009*"license" + 0.009*"may" + 0.007*"use"'),
#  (5,
#   '0.053*"party" + 0.019*"shall" + 0.016*"name" + 0.010*"software" + 0.010*"lease" + 0.010*"title" + 0.010*"may" + 0.009*"lessor" + 0.009*"business" + 0.009*"property"'),
#  (6,
#   '0.045*"party" + 0.020*"agreement" + 0.016*"software" + 0.010*"law" + 0.010*"may" + 0.009*"parties" + 0.008*"shall" + 0.008*"services" + 0.007*"property" + 0.007*"month"')]

# %%
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

# %%
vis = pyLDAvis.gensim_models.prepare(ldamodel, corpus, dictionary)
vis
# Out:
# /usr/local/lib/python3.9/dist-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.017152 -0.030987       1        1  19.958702
# 0      0.104877 -0.078402       2        1  19.402761
# 5     -0.035551 -0.037258       3        1  17.746456
# 4      0.067975  0.107036       4        1  14.079175
# 6     -0.087819 -0.027741       5        1  11.968798
# 2     -0.043641  0.035539       6        1   8.837465
# 3     -0.022993  0.031812       7        1   8.006642, topic_info=           Term        Freq       Total Category  logprob  loglift
# 13        party  134.000000  134.000000  Default  30.0000  30.0000
# 1167          ,   18.000000   18.000000  Default  29.0000  29.0000
# 883      tenant   49.000000   49.000000  Default  28.0000  28.0000
# 2     agreement   61.000000   61.000000  Default  27.0000  27.0000
# 364    property   51.000000   51.000000  Default  26.0000  26.0000
# ...         ...         ...         ...      ...      ...      ...
# 101       shall    2.761955   66.932643   Topic7  -4.8612  -0.6628
# 286        term    2.046653   21.610954   Topic7  -5.1609   0.1679
# 883      tenant    2.500579   49.814054   Topic7  -4.9606  -0.4669
# 128         may    1.685169   28.467388   Topic7  -5.3552  -0.3020
# 453     consent    1.462262    8.279090   Topic7  -5.4971   0.7911
#
# [474 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 1413      4  0.691110        &
# 1413      7  0.345555        &
# 1167      2  0.054425        ,
# 1167      3  0.108849        ,
# 1167      4  0.653095        ,
# ...     ...       ...      ...
# 451       4  0.112673  written
# 451       5  0.112673  written
# 451       7  0.225347  written
# 1118      2  0.952321     year
# 584       3  0.877800     york
#
# [822 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 6, 5, 7, 3, 4])
